# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 271~280 타이타닉

# %%
train=pd.read_csv('train.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
import seaborn as sns

titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic['embark_town'].value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
titanic.groupby('pclass')[['fare']].mean()
# Out:
#              fare
# pclass
# 1       84.154687
# 2       20.662183
# 3       13.675550

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
round(titanic[titanic['sex']=='female']['survived'].value_counts(normalize=True) * 100, 1)
# Out:
# 1    74.2
# 0    25.8
# Name: survived, dtype: float64

# %%
titanic.groupby('sex')['survived'].mean() * 100
# Out:
# sex
# female    74.203822
# male      18.890815
# Name: survived, dtype: float64

# %%
titanic.groupby('pclass')['survived'].mean() * 100
# Out:
# pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: survived, dtype: float64

# %%
titanic['age'].isnull().sum()
# Out:
# 177

# %%
titanic.dropna(subset='age', inplace=True)

# %%
titanic['age'].isnull().sum()
# Out:
# 0

# %%
titanic['age_group'] = np.where(titanic['age'] <18, '미성년자',
                       np.where(titanic['age'] <60, '성인', '노인'))

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone age_group
# 0      man        True  NaN  Southampton    no  False        성인
# 1    woman       False    C    Cherbourg   yes  False        성인
# 2    woman       False  NaN  Southampton   yes   True        성인
# 3    woman       False    C  Southampton   yes  False        성인
# 4      man        True  NaN  Southampton    no   True        성인
# ..     ...         ...  ...          ...   ...    ...       ...
# 885  woman       False  NaN   Queenstown    no  False        성인
# 886    man        True  NaN  Southampton    no   True        성인
# 887  woman       False    B  Southampton   yes   True        성인
# 889    man        True    C    Cherbourg   yes   True        성인
# 890    man        True  NaN   Queenstown    no   True        성인
#
# [714 rows x 16 columns]

# %%
titanic['age_group'].value_counts()
# Out:
# 성인      575
# 미성년자    113
# 노인       26
# Name: age_group, dtype: int64

# %%
titanic.groupby(['age_group','sex'])[['survived']].mean() * 100
# Out:
#                     survived
# age_group sex
# 노인        female  100.000000
#           male     13.636364
# 미성년자      female   69.090909
#           male     39.655172
# 성인        female   76.732673
#           male     17.962466

# %%
pd.pivot_table(data= titanic, values='survived', index='class', columns='sex')
# Out:
# sex       female      male
# class
# First   0.964706  0.396040
# Second  0.918919  0.151515
# Third   0.460784  0.150198

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone age_group
# 0      man        True  NaN  Southampton    no  False        성인
# 1    woman       False    C    Cherbourg   yes  False        성인
# 2    woman       False  NaN  Southampton   yes   True        성인
# 3    woman       False    C  Southampton   yes  False        성인
# 4      man        True  NaN  Southampton    no   True        성인
# ..     ...         ...  ...          ...   ...    ...       ...
# 885  woman       False  NaN   Queenstown    no  False        성인
# 886    man        True  NaN  Southampton    no   True        성인
# 887  woman       False    B  Southampton   yes   True        성인
# 889    man        True    C    Cherbourg   yes   True        성인
# 890    man        True  NaN   Queenstown    no   True        성인
#
# [714 rows x 16 columns]

# %% [markdown]
# ## 281~290 코스피지수

# %%
import FinanceDataReader as fdr

kospi = fdr.DataReader("KS11", "2001")

# %%
kospi
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2001-01-02   503.309998   521.340027   500.970001   520.950012   520.950012
# 2001-01-03   512.739990   524.580017   510.700012   521.429993   521.429993
# 2001-01-04   551.530029   567.159973   550.909973   558.020020   558.020020
# 2001-01-05   559.539978   581.409973   555.400024   580.849976   580.849976
# 2001-01-08   573.719971   587.909973   572.479980   586.650024   586.650024
# ...                 ...          ...          ...          ...          ...
# 2022-11-23  2424.360107  2427.280029  2407.580078  2418.010010  2418.010010
# 2022-11-24  2437.510010  2441.330078  2428.120117  2441.330078  2441.330078
# 2022-11-25  2442.209961  2449.659912  2433.570068  2437.860107  2437.860107
# 2022-11-28  2425.050049  2425.649902  2401.949951  2408.270020  2408.270020
# 2022-11-29  2405.540039  2433.870117  2401.100098  2433.389893  2433.389893
#
#               Volume
# Date
# 2001-01-02  231000.0
# 2001-01-03  324600.0
# 2001-01-04  444500.0
# 2001-01-05  578300.0
# 2001-01-08  558600.0
# ...              ...
# 2022-11-23  474800.0
# 2022-11-24  481200.0
# 2022-11-25  438400.0
# 2022-11-28  350100.0
# 2022-11-29  550174.0
#
# [5490 rows x 6 columns]

# %%
kospi['High'].sort_values(ascending=False).index[0]
# Out:
# Timestamp('2021-06-25 00:00:00')

# %%
kospi['High'].idxmax()
# Out:
# Timestamp('2021-06-25 00:00:00')

# %%
kospi['Low'].min()
# Out:
# 463.540009

# %%
kospi['Low'].sort_values().index[0]
# Out:
# Timestamp('2001-09-21 00:00:00')

# %%
kospi['Change']=kospi['High'] - kospi['Low']

# %%
kospi
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2001-01-02   503.309998   521.340027   500.970001   520.950012   520.950012
# 2001-01-03   512.739990   524.580017   510.700012   521.429993   521.429993
# 2001-01-04   551.530029   567.159973   550.909973   558.020020   558.020020
# 2001-01-05   559.539978   581.409973   555.400024   580.849976   580.849976
# 2001-01-08   573.719971   587.909973   572.479980   586.650024   586.650024
# ...                 ...          ...          ...          ...          ...
# 2022-11-23  2424.360107  2427.280029  2407.580078  2418.010010  2418.010010
# 2022-11-24  2437.510010  2441.330078  2428.120117  2441.330078  2441.330078
# 2022-11-25  2442.209961  2449.659912  2433.570068  2437.860107  2437.860107
# 2022-11-28  2425.050049  2425.649902  2401.949951  2408.270020  2408.270020
# 2022-11-29  2405.540039  2433.870117  2401.100098  2433.389893  2433.389893
#
#               Volume     Change
# Date
# 2001-01-02  231000.0  20.370026
# 2001-01-03  324600.0  13.880005
# 2001-01-04  444500.0  16.250000
# 2001-01-05  578300.0  26.009949
# 2001-01-08  558600.0  15.429993
# ...              ...        ...
# 2022-11-23  474800.0  19.699951
# 2022-11-24  481200.0  13.209961
# 2022-11-25  438400.0  16.089844
# 2022-11-28  350100.0  23.699951
# 2022-11-29  550174.0  32.770019
#
# [5490 rows x 7 columns]

# %%
kospi['Change'].sort_values(ascending=False).head(5)
# Out:
# Date
# 2020-03-19    186.659912
# 2021-01-11    170.040039
# 2008-10-29    157.979980
# 2011-08-09    143.949951
# 2011-08-08    139.920044
# Name: Change, dtype: float64

# %%
for i in range (len(kospi['Close'])) :
    if kospi['Adj Close'] != kospi['Close'] :
        print(kospi['Close'].index)
    else :
        pass
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
#       1 for i in range (len(kospi['Close'])) :
# ----> 2     if kospi['Adj Close'] != kospi['Close'] :
#       3         print(kospi['Close'].index)
#       4     else :
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
kospi
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2001-01-02   503.309998   521.340027   500.970001   520.950012   520.950012
# 2001-01-03   512.739990   524.580017   510.700012   521.429993   521.429993
# 2001-01-04   551.530029   567.159973   550.909973   558.020020   558.020020
# 2001-01-05   559.539978   581.409973   555.400024   580.849976   580.849976
# 2001-01-08   573.719971   587.909973   572.479980   586.650024   586.650024
# ...                 ...          ...          ...          ...          ...
# 2022-11-23  2424.360107  2427.280029  2407.580078  2418.010010  2418.010010
# 2022-11-24  2437.510010  2441.330078  2428.120117  2441.330078  2441.330078
# 2022-11-25  2442.209961  2449.659912  2433.570068  2437.860107  2437.860107
# 2022-11-28  2425.050049  2425.649902  2401.949951  2408.270020  2408.270020
# 2022-11-29  2405.540039  2433.870117  2401.100098  2433.389893  2433.389893
#
#               Volume     Change
# Date
# 2001-01-02  231000.0  20.370026
# 2001-01-03  324600.0  13.880005
# 2001-01-04  444500.0  16.250000
# 2001-01-05  578300.0  26.009949
# 2001-01-08  558600.0  15.429993
# ...              ...        ...
# 2022-11-23  474800.0  19.699951
# 2022-11-24  481200.0  13.209961
# 2022-11-25  438400.0  16.089844
# 2022-11-28  350100.0  23.699951
# 2022-11-29  550174.0  32.770019
#
# [5490 rows x 7 columns]

# %%
kospi[kospi['Close'] > 3000].index
# Out:
# DatetimeIndex(['2021-01-07', '2021-01-08', '2021-01-11', '2021-01-12',
#                '2021-01-13', '2021-01-14', '2021-01-15', '2021-01-18',
#                '2021-01-19', '2021-01-20',
#                ...
#                '2021-11-02', '2021-11-22', '2021-12-08', '2021-12-09',
#                '2021-12-10', '2021-12-13', '2021-12-16', '2021-12-17',
#                '2021-12-24', '2021-12-28'],
#               dtype='datetime64[ns]', name='Date', length=197, freq=None)

# %%
df = fdr.DataReader('KS11', "2001")
df['up'] = df['Change'] > 0
df['grp'] = (df['up'] != df['up'].shift()).cumsum()
df['up_cnt'] = df['grp'].groupby(df['grp'].values).cumcount() + 1
df['up_cnt'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Change'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [35], in <cell line: 2>()
#       1 df = fdr.DataReader('KS11', "2001")
# ----> 2 df['up'] = df['Change'] > 0
#       3 df['grp'] = (df['up'] != df['up'].shift()).cumsum()
#       4 df['up_cnt'] = df['grp'].groupby(df['grp'].values).cumcount() + 1
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Change'

# %% [markdown]
# ## 291~300 부동산

# %%
import pandas as pd

df_m = pd.read_excel("https://drive.google.com/u/0/uc?id=1gVEEFn46Q9DBlgp2e8cTlCXOjbujj_A7&export=download", index_col=0)
df_m.head()
# Out:
#      거래금액  거래유형  건축년도     년  법정동     아파트  월  일    전용면적  중개사소재지    지번   지역코드  \
# 0  68,000   NaN  2006  2021  성남동   금호어울림  1  2   59.93     NaN  3126  41133
# 1  29,500   NaN  2004  2021  성남동   SR하이원  1  2   45.31     NaN  3755  41133
# 2  49,000   NaN  2006  2021  성남동  동부브리앙뜨  1  3   80.49     NaN  2163  41133
# 3  40,800   NaN  1992  2021  성남동      현대  1  7   42.62     NaN  3121  41133
# 4  53,000   NaN  2004  2021  성남동     띠아모  1  7  116.56     NaN  3753  41133
#
#     층 해제사유발생일 해제여부
# 0   9     NaN  NaN
# 1   5     NaN  NaN
# 2   3     NaN  NaN
# 3  10     NaN  NaN
# 4   9     NaN  NaN

# %%
df_m
# Out:
#         거래금액  거래유형  건축년도     년  법정동         아파트  월   일    전용면적  중개사소재지    지번  \
# 0     68,000   NaN  2006  2021  성남동       금호어울림  1   2   59.93     NaN  3126
# 1     29,500   NaN  2004  2021  성남동       SR하이원  1   2   45.31     NaN  3755
# 2     49,000   NaN  2006  2021  성남동      동부브리앙뜨  1   3   80.49     NaN  2163
# 3     40,800   NaN  1992  2021  성남동          현대  1   7   42.62     NaN  3121
# 4     53,000   NaN  2004  2021  성남동         띠아모  1   7  116.56     NaN  3753
# ..       ...   ...   ...   ...  ...         ... ..  ..     ...     ...   ...
# 119  100,000   NaN  2012  2021  중앙동  중앙동힐스테이트1차  1  17  120.97     NaN   578
# 120   83,000   NaN  2014  2021  중앙동  중앙동힐스테이트2차  1  21   59.98     NaN   577
# 121   88,000   NaN  2012  2021  중앙동        롯데캐슬  1  23   59.93     NaN   710
# 122   82,500   NaN  2014  2021  중앙동  중앙동힐스테이트2차  1  25   59.98     NaN   577
# 123   79,000   NaN  2012  2021  중앙동  중앙동힐스테이트1차  1  30   59.98     NaN   578
#
#       지역코드   층 해제사유발생일 해제여부
# 0    41133   9     NaN  NaN
# 1    41133   5     NaN  NaN
# 2    41133   3     NaN  NaN
# 3    41133  10     NaN  NaN
# 4    41133   9     NaN  NaN
# ..     ...  ..     ...  ...
# 119  41133   2     NaN  NaN
# 120  41133   7     NaN  NaN
# 121  41133   6     NaN  NaN
# 122  41133   3     NaN  NaN
# 123  41133   1     NaN  NaN
#
# [124 rows x 15 columns]

# %%
df_m['거래금액']=df_m['거래금액'].str.replace(',','').astype('int')

# %%
df_m.dtypes
# Out:
# 거래금액         int32
# 거래유형       float64
# 건축년도         int64
# 년            int64
# 법정동         object
# 아파트         object
# 월            int64
# 일            int64
# 전용면적       float64
# 중개사소재지     float64
# 지번          object
# 지역코드         int64
# 층            int64
# 해제사유발생일     object
# 해제여부        object
# 매매평단가      float64
# dtype: object

# %%
df_m['매매평단가'] = df_m['거래금액']/ ((df_m['전용면적']) / 3.3)
# Out:
#   Input In [49]
#     df_m['매매평단가'] = df_m['거래금액']/ (df_m['전용면적']) / 3.3)
#                                                       ^
# SyntaxError: unmatched ')'

# %%
df_m
# Out:
#        거래금액  거래유형  건축년도     년  법정동         아파트  월   일    전용면적  중개사소재지    지번  \
# 0     68000   NaN  2006  2021  성남동       금호어울림  1   2   59.93     NaN  3126
# 1     29500   NaN  2004  2021  성남동       SR하이원  1   2   45.31     NaN  3755
# 2     49000   NaN  2006  2021  성남동      동부브리앙뜨  1   3   80.49     NaN  2163
# 3     40800   NaN  1992  2021  성남동          현대  1   7   42.62     NaN  3121
# 4     53000   NaN  2004  2021  성남동         띠아모  1   7  116.56     NaN  3753
# ..      ...   ...   ...   ...  ...         ... ..  ..     ...     ...   ...
# 119  100000   NaN  2012  2021  중앙동  중앙동힐스테이트1차  1  17  120.97     NaN   578
# 120   83000   NaN  2014  2021  중앙동  중앙동힐스테이트2차  1  21   59.98     NaN   577
# 121   88000   NaN  2012  2021  중앙동        롯데캐슬  1  23   59.93     NaN   710
# 122   82500   NaN  2014  2021  중앙동  중앙동힐스테이트2차  1  25   59.98     NaN   577
# 123   79000   NaN  2012  2021  중앙동  중앙동힐스테이트1차  1  30   59.98     NaN   578
#
#       지역코드   층 해제사유발생일 해제여부        매매평단가
# 0    41133   9     NaN  NaN  3744.368430
# 1    41133   5     NaN  NaN  2148.532333
# 2    41133   3     NaN  NaN  2008.945211
# 3    41133  10     NaN  NaN  3159.080244
# 4    41133   9     NaN  NaN  1500.514756
# ..     ...  ..     ...  ...          ...
# 119  41133   2     NaN  NaN  2727.949078
# 120  41133   7     NaN  NaN  4566.522174
# 121  41133   6     NaN  NaN  4845.653262
# 122  41133   3     NaN  NaN  4539.013004
# 123  41133   1     NaN  NaN  4346.448816
#
# [124 rows x 16 columns]

# %%
df_m.groupby('법정동')[['매매평단가']].mean()
# Out:
#             매매평단가
# 법정동
# 금광동   3240.974040
# 도촌동   3231.935513
# 상대원동  2789.911981
# 성남동   2387.478986
# 여수동   4445.978156
# 은행동   3268.274510
# 중앙동   4094.691326
# 하대원동  2592.894990

# %%
df_m[df_m['법정동'] =='하대원동']['매매평단가']
# Out:
# 94     3007.417874
# 95     1814.562002
# 96     3021.181454
# 97     3117.896223
# 98     3564.594099
# 99     2834.451112
# 100    2206.619860
# 101    1992.753623
# 102    2051.744886
# 103    3106.247794
# 104    2209.554832
# 105    2373.814499
# 106    2373.814499
# 107    2059.178744
# 108    2030.401737
# 109    2186.541613
# 110    2031.889290
# 111    3470.205308
# 112    3812.135356
# Name: 매매평단가, dtype: float64

# %%
import numpy as np

# %%
df_m.loc[ df_m['법정동'] == "하대원동" ].groupby('아파트').agg({"매매평단가": [np.mean, len]})
# Out:
#               매매평단가
#                mean len
# 아파트
# 삼남      2027.155016   7
# 성남자이    2991.761913   5
# 성원초원    2206.619860   1
# 아튼빌     3144.589731   5
# 태연스카이빌  2186.541613   1

# %%
df_m = df_m.astype({ 
    "년" : str,
    "월" : str,
    "일" : str
})
df_m['날짜'] = df_m['년'] + df_m['월'] + df_m['일']
df_m['날짜'] = pd.to_datetime(df_m['날짜'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: month must be in 1..12
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:536, in pandas._libs.tslib.array_to_datetime()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: month must be in 1..12: 202112
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:547, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: month must be in 1..12
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# Input In [59], in <cell line: 7>()
#       1 df_m = df_m.astype({
#       2     "년" : str,
#       3     "월" : str,
#       4     "일" : str
#       5 })
#       6 df_m['날짜'] = df_m['년'] + df_m['월'] + df_m['일']
# ----> 7 df_m['날짜'] = pd.to_datetime(df_m['날짜'])
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1045             result = arg.tz_localize(tz)
#    1046 elif isinstance(arg, ABCSeries):
# -> 1047     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1048     if not cache_array.empty:
#    1049         result = arg.map(cache_array)
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:197, in _maybe_cache(arg, format, cache, convert_listlike)
#     195 unique_dates = unique(arg)
#     196 if len(unique_dates) < len(arg):
# --> 197     cache_dates = convert_listlike(unique_dates, format)
#     198     cache_array = Series(cache_dates, index=unique_dates)
#     199     # GH#39882 and GH#35888 in case of None and NaT we get duplicates
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:402, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     400 assert format is None or infer_datetime_format
#     401 utc = tz == "utc"
# --> 402 result, tz_parsed = objects_to_datetime64ns(
#     403     arg,
#     404     dayfirst=dayfirst,
#     405     yearfirst=yearfirst,
#     406     utc=utc,
#     407     errors=errors,
#     408     require_iso8601=require_iso8601,
#     409     allow_object=True,
#     410 )
#     412 if tz_parsed is not None:
#     413     # We can take a shortcut since the datetime64 numpy array
#     414     # is in UTC
#     415     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2217, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2215         return values.view("i8"), tz_parsed
#    2216     except (ValueError, TypeError):
# -> 2217         raise err
#    2219 if tz_parsed is not None:
#    2220     # We can take a shortcut since the datetime64 numpy array
#    2221     #  is in UTC
#    2222     # Return i8 values to denote unix timestamps
#    2223     return result.view("i8"), tz_parsed
#
# File ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2199, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2197 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2198 try:
# -> 2199     result, tz_parsed = tslib.array_to_datetime(
#    2200         data.ravel("K"),
#    2201         errors=errors,
#    2202         utc=utc,
#    2203         dayfirst=dayfirst,
#    2204         yearfirst=yearfirst,
#    2205         require_iso8601=require_iso8601,
#    2206         allow_mixed=allow_mixed,
#    2207     )
#    2208     result = result.reshape(data.shape, order=order)
#    2209 except ValueError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:381, in pandas._libs.tslib.array_to_datetime()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:613, in pandas._libs.tslib.array_to_datetime()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:751, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:742, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#     654     ret = self._build_tzaware(ret, res, tzinfos)
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: month must be in 1..12: 202112

# %%
def f(x):
    if len(x) == 1:
        return f"0{x}"
    else:
        return x

df_m['월'] = df_m['월'].map(f)
df_m['일'] = df_m['일'].map(f)

df_m['날짜'] = df_m['년'] + df_m['월'] + df_m['일'] 
df_m['날짜'] = pd.to_datetime(df_m['날짜'])

temp = df_m[ ["날짜", "법정동", "아파트", "매매평단가"] ]
temp.head(2)
# Out:
#           날짜  법정동    아파트        매매평단가
# 0 2021-01-02  성남동  금호어울림  3744.368430
# 1 2021-01-02  성남동  SR하이원  2148.532333

# %%
df_s = pd.read_excel("https://drive.google.com/u/0/uc?id=1akAI69X1J8VL5R0azoGQeEKJ5ttEPrTx&export=download", index_col=0)
df_s.head(2)
# Out:
#    갱신요구권사용  건축년도  계약구분  계약기간     년  법정동    보증금액     아파트  월  월세금액  일   전용면적  \
# 0      NaN  2003   NaN   NaN  2021  성남동  13,000  보미리전빌3  1     0  6  34.10
# 1      NaN  1992   NaN   NaN  2021  성남동  30,000      현대  1     0  9  51.53
#
#    종전계약보증금  종전계약월세    지번   지역코드  층
# 0      NaN     NaN  2508  41133  7
# 1      NaN     NaN  3121  41133  6

# %%
df_s['보증금액']=df_s['보증금액'].str.replace(',','').astype(int)

# %%
df_s['전세평단가']=df_s['보증금액'] / (df_s['전용면적']/3.3)

# %%
round(df_s.groupby('법정동')['전세평단가'].mean(),2)
# Out:
# 법정동
# 금광동     1534.07
# 도촌동      893.73
# 상대원동     978.20
# 성남동     1101.45
# 여수동     1978.92
# 은행동     1043.05
# 중앙동     1942.57
# 하대원동    1351.37
# Name: 전세평단가, dtype: float64

# %%
df_s['전세평단가']=(df_s['보증금액'] + df_s['월세금액'] / 40* 10000 )/ (df_s['전용면적']/3.3)
df_s.groupby('법정동').agg( {'전세평단가': np.mean} )
# Out:
#             전세평단가
# 법정동
# 금광동   1812.794434
# 도촌동   1206.960357
# 상대원동  1172.104840
# 성남동   1497.833997
# 여수동   2199.143954
# 은행동   1098.786101
# 중앙동   2077.201451
# 하대원동  1639.282252

# %%
df_s
# Out:
#      갱신요구권사용  건축년도  계약구분  계약기간     년  법정동   보증금액         아파트  월  월세금액   일  \
# 0        NaN  2003   NaN   NaN  2021  성남동  13000      보미리전빌3  1     0   6
# 1        NaN  1992   NaN   NaN  2021  성남동  30000          현대  1     0   9
# 2        NaN  1992   NaN   NaN  2021  성남동  21000          현대  1     0   9
# 3        NaN  2006   NaN   NaN  2021  성남동  35000         그린빌  1     0  12
# 4        NaN  2006   NaN   NaN  2021  성남동  65000       금호어울림  1     0  12
# ..       ...   ...   ...   ...   ...  ...    ...         ... ..   ...  ..
# 187      NaN  2014   NaN   NaN  2021  중앙동  36700  중앙동힐스테이트2차  1     0  23
# 188      NaN  2014   NaN   NaN  2021  중앙동  25000  중앙동힐스테이트2차  1   150  28
# 189      NaN  2014   NaN   NaN  2021  중앙동  59900  중앙동힐스테이트2차  1     0  29
# 190      NaN  2014   NaN   NaN  2021  중앙동  42000  중앙동힐스테이트2차  1     0  29
# 191      NaN  2012   NaN   NaN  2021  중앙동  60000        롯데캐슬  1     0  31
#
#          전용면적  종전계약보증금  종전계약월세    지번   지역코드   층        전세평단가
# 0     34.1000      NaN     NaN  2508  41133   7  1258.064516
# 1     51.5300      NaN     NaN  3121  41133   6  1921.210945
# 2     51.5300      NaN     NaN  3121  41133   1  1344.847662
# 3     84.7832      NaN     NaN  2493  41133   6  1362.298191
# 4     84.9600      NaN     NaN  3126  41133   7  2524.717514
# ..        ...      ...     ...   ...    ...  ..          ...
# 187   59.9800      NaN     NaN   577  41133  13  2019.173058
# 188  120.6000      NaN     NaN   577  41133  12  1710.199005
# 189   84.9800      NaN     NaN   577  41133   2  2326.076724
# 190   84.9800      NaN     NaN   577  41133   2  1630.971993
# 191   59.9300      NaN     NaN   710  41133   6  3303.854497
#
# [192 rows x 18 columns]

# %%
t0 = df_m.groupby('법정동').agg( {'매매평단가': np.mean} )
t1 = df_s.groupby('법정동').agg( {'전세평단가': np.mean} )
t0['전세평단가'] / t0['매매평단가']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '전세평단가'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [75], in <cell line: 3>()
#       1 t0 = df_m.groupby('법정동').agg( {'매매평단가': np.mean} )
#       2 t1 = df_s.groupby('법정동').agg( {'전세평단가': np.mean} )
# ----> 3 t0['전세평단가'] / t0['매매평단가']
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: '전세평단가'

# %%
d1=df_s.groupby('법정동')[['전세평단가']].mean()

# %%
d2=df_m.groupby('법정동')[['매매평단가']].mean()

# %%
d1
# Out:
#             전세평단가
# 법정동
# 금광동   1812.794434
# 도촌동   1206.960357
# 상대원동  1172.104840
# 성남동   1497.833997
# 여수동   2199.143954
# 은행동   1098.786101
# 중앙동   2077.201451
# 하대원동  1639.282252

# %%
d2
# Out:
#             매매평단가
# 법정동
# 금광동   3240.974040
# 도촌동   3231.935513
# 상대원동  2789.911981
# 성남동   2387.478986
# 여수동   4445.978156
# 은행동   3268.274510
# 중앙동   4094.691326
# 하대원동  2592.894990

# %%
d1['전세평단가']/d2['매매평단가']
# Out:
# 법정동
# 금광동     0.559336
# 도촌동     0.373448
# 상대원동    0.420123
# 성남동     0.627371
# 여수동     0.494637
# 은행동     0.336198
# 중앙동     0.507291
# 하대원동    0.632221
# dtype: float64
