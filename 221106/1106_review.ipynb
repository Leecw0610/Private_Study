# %%
#pip install emoji

# %%
import emoji as e

# %%
print(e.emojize('Hello world! :thumbs_up:'))
# Out:
# Hello world! 👍

# %%
pip install pydataset
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pydataset as pds

# %%
data= pds.data()

# %%
data.head(1)
# Out:
#       dataset_id                                        title
# 0  AirPassengers  Monthly Airline Passenger Numbers 1949-1960

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dataset_id  757 non-null    object
#  1   title       757 non-null    object
# dtypes: object(2)
# memory usage: 12.0+ KB

# %%
data[data['dataset_id'] =='mtcars']
# Out:
#    dataset_id                       title
# 47     mtcars  Motor Trend Car Road Tests

# %%
df= pds.data('mtcars')

# %%
df
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
df.shape
# Out:
# (32, 11)

# %%
df['am'].value_counts()
# Out:
# 0    19
# 1    13
# Name: am, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, Mazda RX4 to Volvo 142E
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 3.0+ KB

# %%
df['gear'].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
df[(df['am']==0 ) & (df['gear']==4)] # 특정 변수의 요건을 만족하는 행찾기!
# Out:
#             mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# Merc 240D  24.4    4  146.7   62  3.69  3.19  20.0   1   0     4     2
# Merc 230   22.8    4  140.8   95  3.92  3.15  22.9   1   0     4     2
# Merc 280   19.2    6  167.6  123  3.92  3.44  18.3   1   0     4     4
# Merc 280C  17.8    6  167.6  123  3.92  3.44  18.9   1   0     4     4

# %%
df2 = pds.data('HairEyeColor')

# %%
df2
# Out:
#      Hair    Eye     Sex  Freq
# 1   Black  Brown    Male    32
# 2   Brown  Brown    Male    53
# 3     Red  Brown    Male    10
# 4   Blond  Brown    Male     3
# 5   Black   Blue    Male    11
# 6   Brown   Blue    Male    50
# 7     Red   Blue    Male    10
# 8   Blond   Blue    Male    30
# 9   Black  Hazel    Male    10
# 10  Brown  Hazel    Male    25
# 11    Red  Hazel    Male     7
# 12  Blond  Hazel    Male     5
# 13  Black  Green    Male     3
# 14  Brown  Green    Male    15
# 15    Red  Green    Male     7
# 16  Blond  Green    Male     8
# 17  Black  Brown  Female    36
# 18  Brown  Brown  Female    66
# 19    Red  Brown  Female    16
# 20  Blond  Brown  Female     4
# 21  Black   Blue  Female     9
# 22  Brown   Blue  Female    34
# 23    Red   Blue  Female     7
# 24  Blond   Blue  Female    64
# 25  Black  Hazel  Female     5
# 26  Brown  Hazel  Female    29
# 27    Red  Hazel  Female     7
# 28  Blond  Hazel  Female     5
# 29  Black  Green  Female     2
# ...

# %%
data = pds.data()

# %%
df3 = pds.data('cake')

# %%
df3
# Out:
#      replicate recipe  temperature  angle  temp
# 1            1      A          175     42   175
# 2            1      A          185     46   185
# 3            1      A          195     47   195
# 4            1      A          205     39   205
# 5            1      A          215     53   215
# ..         ...    ...          ...    ...   ...
# 266         15      C          185     28   185
# 267         15      C          195     25   195
# 268         15      C          205     25   205
# 269         15      C          215     31   215
# 270         15      C          225     25   225
#
# [270 rows x 5 columns]

# %%
df3[df3['recipe']=='C']['temp'].mean()
# Out:
# 200.0

# %%
df5 = pds.data('volcano')

# %%
df5
# Out:
#      V1   V2   V3   V4   V5   V6   V7   V8   V9  V10  ...  V52  V53  V54  V55  \
# 1   100  100  101  101  101  101  101  100  100  100  ...  107  107  107  106
# 2   101  101  102  102  102  102  102  101  101  101  ...  108  108  107  107
# 3   102  102  103  103  103  103  103  102  102  102  ...  109  108  108  107
# 4   103  103  104  104  104  104  104  103  103  103  ...  109  109  108  108
# 5   104  104  105  105  105  105  105  104  104  103  ...  110  109  109  108
# 6   105  105  105  106  106  106  106  105  105  104  ...  110  110  109  108
# 7   105  106  106  107  107  107  107  106  106  105  ...  110  111  110  109
# 8   106  107  107  108  108  108  108  107  107  106  ...  113  112  110  110
# 9   107  108  108  109  109  109  109  108  108  107  ...  115  114  112  110
# 10  108  109  109  110  110  110  110  109  109  108  ...  117  115  113  111
# 11  109  110  110  111  111  111  111  110  110  110  ...  118  116  114  112
# ...

# %%
data.iloc[151]['dataset_id']
# Out:
# 'airmay'

# %%
df
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
df2
# Out:
#      Hair    Eye     Sex  Freq
# 1   Black  Brown    Male    32
# 2   Brown  Brown    Male    53
# 3     Red  Brown    Male    10
# 4   Blond  Brown    Male     3
# 5   Black   Blue    Male    11
# 6   Brown   Blue    Male    50
# 7     Red   Blue    Male    10
# 8   Blond   Blue    Male    30
# 9   Black  Hazel    Male    10
# 10  Brown  Hazel    Male    25
# 11    Red  Hazel    Male     7
# 12  Blond  Hazel    Male     5
# 13  Black  Green    Male     3
# 14  Brown  Green    Male    15
# 15    Red  Green    Male     7
# 16  Blond  Green    Male     8
# 17  Black  Brown  Female    36
# 18  Brown  Brown  Female    66
# 19    Red  Brown  Female    16
# 20  Blond  Brown  Female     4
# 21  Black   Blue  Female     9
# 22  Brown   Blue  Female    34
# 23    Red   Blue  Female     7
# 24  Blond   Blue  Female    64
# 25  Black  Hazel  Female     5
# 26  Brown  Hazel  Female    29
# 27    Red  Hazel  Female     7
# 28  Blond  Hazel  Female     5
# 29  Black  Green  Female     2
# ...

# %%
df2.columns
# Out:
# Index(['Hair', 'Eye', 'Sex', 'Freq'], dtype='object')

# %%
df2[(df2['Hair']=='Black') & (df2['Eye']=='Brown') &\
(df2['Sex']=='Male')]
# Out:
#     Hair    Eye   Sex  Freq
# 1  Black  Brown  Male    32

# %%
df2.groupby(['Hair','Eye','Sex']).count()
# Out:
#                     Freq
# Hair  Eye   Sex
# Black Blue  Female     1
#             Male       1
#       Brown Female     1
#             Male       1
#       Green Female     1
#             Male       1
#       Hazel Female     1
#             Male       1
# Blond Blue  Female     1
#             Male       1
#       Brown Female     1
#             Male       1
#       Green Female     1
#             Male       1
#       Hazel Female     1
#             Male       1
# Brown Blue  Female     1
#             Male       1
#       Brown Female     1
#             Male       1
#       Green Female     1
#             Male       1
#       Hazel Female     1
#             Male       1
# Red   Blue  Female     1
#             Male       1
#       Brown Female     1
#             Male       1
#       Green Female     1
#             Male       1
#       Hazel Female     1
#             Male       1

# %%
import pandas as pd

# %%
df = pd.DataFrame({'name' : ['김지훈','이유진','박동현','김민지'],
                 'english': [90, 80, 60, 70],
                 'math' : [50, 60, 100, 20]})

# %%
df
# Out:
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
df = df.rename({'name':'이름'}, axis=1)

# %%
df
# Out:
#     이름  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
df2 = df

# %%
df2
# Out:
#     이름  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
df3 = df.copy()

# %%
df3
# Out:
#     이름  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
df['name'] = '예진'

# %%
df
# Out:
#     이름  english  math name
# 0  김지훈       90    50   예진
# 1  이유진       80    60   예진
# 2  박동현       60   100   예진
# 3  김민지       70    20   예진

# %%
df3
# Out:
#     이름  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
import pydataset as pds

# %%
mpg = pds.data('mpg')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
mpg['total']= (mpg['cty'] + mpg['hwy']) /2

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  total
# 1    compact   23.5
# 2    compact   25.0
# 3    compact   25.5
# ...

# %%
mpg['total'].mean()
# Out:
# 20.14957264957265

# %%
len(mpg[mpg['total']>20])
# Out:
# 123

# %%
def isPass(t) : 
    if t>20 :
        return 'Pass'
    else : 
        return 'Fail'

# %%
mpg['test'] = mpg['total'].apply(isPass)

# %%
mpg['test'].value_counts()
# Out:
# Pass    123
# Fail    111
# Name: test, dtype: int64

# %%
mpg['test']
# Out:
# 1      Pass
# 2      Pass
# 3      Pass
# 4      Pass
# 5      Pass
#        ...
# 230    Pass
# 231    Pass
# 232    Pass
# 233    Pass
# 234    Pass
# Name: test, Length: 234, dtype: object

# %% [raw]
# mpg['grade'] = \
# mpg['total'] >= 30 'A'
# mpg['total'] >= 20 'B'
# else 'C'

# %%
def grade_(t) : 
    if t >= 30 :
        return 'A'
    elif t >= 20 :
        return 'B'
    else :
        return 'C'

# %%
mpg['grade'] = mpg['total'].apply(grade_)

# %%
mpg['grade']
# Out:
# 1      B
# 2      B
# 3      B
# 4      B
# 5      B
#       ..
# 230    B
# 231    B
# 232    B
# 233    B
# 234    B
# Name: grade, Length: 234, dtype: object

# %%
mpg['grade'].value_counts().sort_values(ascending=False)
# Out:
# B    118
# C    106
# A     10
# Name: grade, dtype: int64

# %%
mpg2=mpg['grade'].value_counts().sort_index().reset_index()

# %%
mpg2
# Out:
#   index  grade
# 0     A     10
# 1     B    118
# 2     C    106

# %%
import seaborn as sns

# %%
sns.barplot(data=mpg2, x='index', y='grade', order=['B','C','A'])
# Out:
# <AxesSubplot:xlabel='index', ylabel='grade'>

# %%
import numpy as np

# %%
type(np.where(mpg['total'] >30, 'A',
np.where(mpg['total'] >20, 'B', 'Fail')))
# Out:
# numpy.ndarray

# %%
mpg['class'].unique()
# Out:
# array(['compact', 'midsize', 'suv', '2seater', 'minivan', 'pickup',
#        'subcompact'], dtype=object)

# %%
def isSize(c) :
    l = ['compact' , 'subcompact' , '2seater']
    if c in l :
        return 'small'
    return 'large'

# %%
mpg['size'] = mpg['class'].apply(isSize)

# %%
mpg['size'].value_counts()
# Out:
# large    147
# small     87
# Name: size, dtype: int64

# %%
import pandas as pd

# %%
train = pd.read_csv('../../22102728/titanic/train.csv')

# %%
train.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train['Survived'].value_counts()[0]
# Out:
# 549

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.shape
# Out:
# (891, 12)

# %%
Sex_surv=train.groupby(['Sex', 'Survived'], as_index=False)['Pclass'].count()

# %%
Sex_surv.sort_values(['Survived','Sex','Pclass'])
# Out:
#       Sex  Survived  Pclass
# 0  female         0      81
# 2    male         0     468
# 1  female         1     233
# 3    male         1     109

# %%
Sex_surv = Sex_surv[['Survived','Sex','Pclass']]

# %%
Sex_surv
# Out:
#    Survived     Sex  Pclass
# 0         0  female      81
# 1         1  female     233
# 2         0    male     468
# 3         1    male     109

# %%
Sex_surv['name'] = Sex_surv['Sex'] + Sex_surv['Survived'].astype(str)

# %%
Sex_surv
# Out:
#    Survived     Sex  Pclass     name
# 0         0  female      81  female0
# 1         1  female     233  female1
# 2         0    male     468    male0
# 3         1    male     109    male1

# %%
train_S=train.groupby(['Survived','Sex'], as_index=False)[['Survived']].count()

# %%
train_S
# Out:
#       Sex  Survived
# 0  female        81
# 1    male       468
# 2  female       233
# 3    male       109

# %%
import seaborn as sns

# %%
sns.barplot(data=train_S, x='Sex',y='Survived')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
sns.barplot(data=Sex_surv, x='name',y='Pclass')
# Out:
# <AxesSubplot:xlabel='name', ylabel='Pclass'>

# %%
sns.barplot(data=Sex_surv, x='Survived',y='Pclass', hue='Sex')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Pclass'>

# %%
train['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
train['Sex'].str.lower()
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
surv_sex=train.groupby('Sex',as_index=False)[['Survived']].mean()

# %%
surv_sex
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
train.groupby(['Pclass','Sex'])['Survived'].mean().sort_values(ascending=False)
# Out:
# Pclass  Sex
# 1       female    0.968085
# 2       female    0.921053
# 3       female    0.500000
# 1       male      0.368852
# 2       male      0.157407
# 3       male      0.135447
# Name: Survived, dtype: float64

# %%
train_Pc=train.groupby('Pclass', as_index=False)[['Fare']].mean()

# %%
train_Pc
# Out:
#    Pclass       Fare
# 0       1  84.154687
# 1       2  20.662183
# 2       3  13.675550

# %%
train_Pc.rename(columns={'Fare' : 'Fare_mean','Pclass' : 'PC'})
# Out:
#    PC  Fare_mean
# 0   1  84.154687
# 1   2  20.662183
# 2   3  13.675550

# %%
train_gb=train.groupby(['Pclass','Sex'], as_index=False)[['Survived','Fare']].mean()

# %%
train_gb
# Out:
#    Pclass     Sex  Survived        Fare
# 0       1  female  0.968085  106.125798
# 1       1    male  0.368852   67.226127
# 2       2  female  0.921053   21.970121
# 3       2    male  0.157407   19.741782
# 4       3  female  0.500000   16.118810
# 5       3    male  0.135447   12.661633

# %% [raw]
# train에 원본 전처리하는 과정 ~까지함
#
# 이어서 하기!!

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ...

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train['Age'].median()
# Out:
# 28.0

# %%
train.groupby('Sex')['Age'].median()
# Out:
# Sex
# female    27.0
# male      29.0
# Name: Age, dtype: float64

# %%
train.groupby('Sex',as_index=False)['Age'].transform('median')
# Out:
#       Age
# 0    29.0
# 1    27.0
# 2    27.0
# 3    27.0
# 4    29.0
# ..    ...
# 886  29.0
# 887  27.0
# 888  27.0
# 889  29.0
# 890  29.0
#
# [891 rows x 1 columns]

# %%
train2=train.copy()

# %%
train2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ...

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train['Name']
# Out:
# 0                                  Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# 2                                   Heikkinen, Miss. Laina
# 3             Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                                 Allen, Mr. William Henry
#                               ...
# 886                                  Montvila, Rev. Juozas
# 887                           Graham, Miss. Margaret Edith
# 888               Johnston, Miss. Catherine Helen "Carrie"
# 889                                  Behr, Mr. Karl Howell
# 890                                    Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
train['Name'].str.lower()
# Out:
# 0                                  braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs thayer)
# 2                                   heikkinen, miss. laina
# 3             futrelle, mrs. jacques heath (lily may peel)
# 4                                 allen, mr. william henry
#                               ...
# 886                                  montvila, rev. juozas
# 887                           graham, miss. margaret edith
# 888               johnston, miss. catherine helen "carrie"
# 889                                  behr, mr. karl howell
# 890                                    dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %% [raw]
# train['Name'].str.lower().str.contains('mr.', 'mrs.', 'miss', 'rev.')

# %%
train['Title']= train['Name'].str.extract('([a-zA-Z]+)\.')

# %%
train['Name'].str.extract('\S\S([a-zA-Z]+),')
# Out:
#            0
# 0       aund
# 1      mings
# 2    ikkinen
# 3     trelle
# 4        len
# ..       ...
# 886   ntvila
# 887     aham
# 888   hnston
# 889       hr
# 890     oley
#
# [891 rows x 1 columns]

# %%
train['Name'].str.lower().str.extract('([a-zA-Z]+)\.')
# Out:
#         0
# 0      mr
# 1     mrs
# 2    miss
# 3     mrs
# 4      mr
# ..    ...
# 886   rev
# 887  miss
# 888  miss
# 889    mr
# 890    mr
#
# [891 rows x 1 columns]

# %% [raw]
# train['Name'].str.extract('([H]a-zA-Z)+')

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Countess      1
# Capt          1
# Ms            1
# Sir           1
# Lady          1
# Mme           1
# Don           1
# Jonkheer      1
# Name: Title, dtype: int64

# %% [raw]
# def title2(i) :
#     for i in range (len(train['Title'])) :
#         if train['Title'][i] == 'Mr' :
#             train['Title'] = 0
#         elif train['Title'][i] == 'Miss' :
#             train['Title'] = 1
#         elif train['Title'][i] == 'Mrs' :
#             train['Title'] = 2
#         else :
#             train['Title'] = 3
#         #print (train['Title'])
#         return train['Title']

# %% [raw]
# title2(1)

# %%
##3가지 방법

# %%
train['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'Countess',
#        'Jonkheer'], dtype=object)

# %%
title_map={}
for value, key in enumerate(train['Title'].unique()):
    if value >=3 :
        title_map[key] =3
    else :
        title_map[key] =value

# %%
title_map
# Out:
# {'Mr': 0,
#  'Mrs': 1,
#  'Miss': 2,
#  'Master': 3,
#  'Don': 3,
#  'Rev': 3,
#  'Dr': 3,
#  'Mme': 3,
#  'Ms': 3,
#  'Major': 3,
#  'Lady': 3,
#  'Sir': 3,
#  'Mlle': 3,
#  'Col': 3,
#  'Capt': 3,
#  'Countess': 3,
#  'Jonkheer': 3}

# %%
train['Title2']= train['Title'].map(title_map)

# %%
train.groupby('Title2')['Age'].median()
# Out:
# Title2
# 0    30.0
# 1    35.0
# 2    21.0
# 3     9.0
# Name: Age, dtype: float64

# %%
train.groupby('Title2', as_index=False)['Age'].transform('median')
# Out:
#       Age
# 0    30.0
# 1    35.0
# 2    21.0
# 3    35.0
# 4    30.0
# ..    ...
# 886   9.0
# 887  21.0
# 888  21.0
# 889  30.0
# 890  30.0
#
# [891 rows x 1 columns]

# %%
train['Title2'].value_counts()
# Out:
# 0    517
# 2    182
# 1    125
# 3     67
# Name: Title2, dtype: int64

# %%
train['Age'][-5:]
# Out:
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, dtype: float64

# %%
train['Age'] = train['Age'].fillna(train.groupby('Title2')['Age'].transform('median'))

# %%
train['Age'][-5:]
# Out:
# 886    27.0
# 887    19.0
# 888    21.0
# 889    26.0
# 890    32.0
# Name: Age, dtype: float64

# %%
train['Age'].isnull().sum()
# Out:
# 0

# %%
train['Age'].describe()
# Out:
# count    891.000000
# mean      29.372806
# std       13.227346
# min        0.420000
# 25%       21.000000
# 50%       30.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# 연령별 생존자의 변화 추이 살펴보기 (시각화)

# %%
import seaborn as sns

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)  #한줄씩 실행시켜서 변화확인!!
facet.map(sns.kdeplot, 'Age', shade=True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()

# %%
train['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    21.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
train['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
train['Cabin'].value_counts()
# Out:
# B96 B98            4
# G6                 4
# C23 C25 C27        4
# C22 C26            3
# F33                3
# F2                 3
# E101               3
# D                  3
# C78                2
# C93                2
# E8                 2
# D36                2
# B77                2
# C123               2
# E121               2
# E44                2
# D35                2
# C125               2
# E67                2
# B35                2
# B18                2
# E24                2
# B49                2
# C65                2
# B20                2
# B5                 2
# B57 B59 B63 B66    2
# C126               2
# B51 B53 B55        2
# F4                 2
# C124               2
# F G73              2
# B58 B60            2
# C52                2
# D33                2
# C68                2
# D20                2
# D26                2
# B28                2
# C83                2
# E25                2
# D17                2
# B22                2
# ...

# %%
train['Cabin'] = train['Cabin'].str[0]

# %% [raw]
# train['Cabin2'] = np.where(train['Cabin']=='A', 0.0,
#                   np.where(train['Cabin']=='B', 0.4,
#                   np.where(train['Cabin']=='C', 0.8,
#                   np.where(train['Cabin']=='D', 1.2,
#                   np.where(train['Cabin']=='E', 1.6,
#                   np.where(train['Cabin']=='F', 2.0,
#                   np.where(train['Cabin']=='G', 2.4, 2.8)))))))

# %%
train['Cabin2'] = train['Cabin'].map({'A':0, 'B':0.4,'C':0.8, 'D':1.2, 'E':1.6, 'F':2.0, 'G':2.4, 'T':2.8})
train['Cabin2'].value_counts()
# Out:
# 0.8    59
# 0.4    47
# 1.2    33
# 1.6    32
# 0.0    15
# 2.0    13
# 2.4     4
# 2.8     1
# Name: Cabin2, dtype: int64

# %%
train['Cabin2']
# Out:
# 0      NaN
# 1      0.8
# 2      NaN
# 3      0.8
# 4      NaN
#       ...
# 886    NaN
# 887    0.4
# 888    NaN
# 889    0.8
# 890    NaN
# Name: Cabin2, Length: 891, dtype: float64

# %%
train.groupby('Pclass')['Cabin2'].median()
# Out:
# Pclass
# 1    0.8
# 2    1.8
# 3    2.0
# Name: Cabin2, dtype: float64

# %%
train['Cabin2'].fillna(train.groupby('Pclass')['Cabin2'].transform('median'), inplace = True)

# %%
train['Cabin2'].value_counts()
# Out:
# 2.0    492
# 1.8    168
# 0.8     99
# 0.4     47
# 1.2     33
# 1.6     32
# 0.0     15
# 2.4      4
# 2.8      1
# Name: Cabin2, dtype: int64

# %%
import numpy as np

# %%
train['Sex2']=np.where(train['Sex'].str.lower() =='male',0, 1)

# %%
train['Sex2'].value_counts()
# Out:
# 0    577
# 1    314
# Name: Sex2, dtype: int64

# %%
train['FamilySize'] = train['SibSp'] + train['Parch'] +1

# %%
train['FamilySize2'] = train['FamilySize'].map({'1':0, '2':0.4,'3':0.8, '4':1.2, '5':1.6, '6':2.0, '7':2.4, '8':2.8, '11' :4.0})

# %%
family_mapping = {}
for value, key in enumerate(range(1, 12)) :
    #print (round(value * 0.4,1), key)
    family_mapping[key] = round(value*0.4, 1)

# %%
train['FamilySize2']= train['FamilySize'].map(family_mapping)

# %%
train['FamilySize2']
# Out:
# 0      0.4
# 1      0.4
# 2      0.0
# 3      0.4
# 4      0.0
#       ...
# 886    0.0
# 887    0.0
# 888    1.2
# 889    0.0
# 890    0.0
# Name: FamilySize2, Length: 891, dtype: float64

# %%
test = pd.read_csv('../../22102728/titanic/test.csv')

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test.groupby('Pclass')['Fare'].mean
# Out:
# <bound method GroupBy.mean of <pandas.core.groupby.generic.SeriesGroupBy object at 0x0000018BE46C4490>>

# %%
test1

# %%
test['Fare'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0        7.8292
# 1        7.0000
# 2        9.6875
# 3        8.6625
# 4       12.2875
#          ...
# 413      8.0500
# 414    108.9000
# 415      7.2500
# 416      8.0500
# 417     22.3583
# Name: Fare, Length: 418, dtype: float64>
