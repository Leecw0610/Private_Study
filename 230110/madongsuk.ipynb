# %%
# 한글 폰트 설치하기 (꼭! 설치가 완료되면 [런타임 다시 시작]을 누르고 다시 실행하기)
# !apt install fonts-nanum -y

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 설정하기
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
plt.rc('font', family='NanumBarunGothic')
matplotlib.font_manager._rebuild()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.

# %%
# 필요한 라이브러리 설치하기
# !git clone https://github.com/ndb796/bing_image_downloader
# Out:
# Cloning into 'bing_image_downloader'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 86 (delta 17), reused 10 (delta 10), pack-reused 64
# Unpacking objects: 100% (86/86), done.

# %%
import os
import shutil
from bing_image_downloader.bing_image_downloader import downloader


directory_list = [
    './custom_dataset/train/',
    './custom_dataset/test/',
]

# 초기 디렉토리 만들기
for directory in directory_list:
    if not os.path.isdir(directory):
        os.makedirs(directory)

# 수집한 이미지를 학습 데이터와 평가 데이터로 구분하는 함수
def dataset_split(query, train_cnt):
    # 학습 및 평가 데이터셋 디렉토리 만들기
    for directory in directory_list:
        if not os.path.isdir(directory + '/' + query):
            os.makedirs(directory + '/' + query)
    # 학습 및 평가 데이터셋 준비하기
    cnt = 0
    for file_name in os.listdir(query):
        if cnt < train_cnt:
            print(f'[Train Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './custom_dataset/train/' + query + '/' + file_name)
        else:
            print(f'[Test Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './custom_dataset/test/' + query + '/' + file_name)
        cnt += 1
    shutil.rmtree(query)

# %%
query = '마동석'
downloader.download(query, limit=40,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 30)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ===============================================
# #1 이미지 다운로드 (http://newsroom.etomato.com/userfiles/DSC05069.jpg)
# #1 파일 다운로드가 완료되었습니다.
# #2 이미지 다운로드 (http://newsroom.etomato.com/userfiles/DSC05084.jpg)
# #2 파일 다운로드가 완료되었습니다.
# #3 이미지 다운로드 (https://img.hankyung.com/photo/201904/03.18208318.1.jpg)
# #3 파일 다운로드가 완료되었습니다.
# #4 이미지 다운로드 (https://image.ytn.co.kr/osen/2019/11/6e8ef36b-36c7-4d1c-896f-19499d54ca7d.jpg)
# [Error] Invalid image, not saving https://image.ytn.co.kr/osen/2019/11/6e8ef36b-36c7-4d1c-896f-19499d54ca7d.jpg
# [Info] Issue getting: https://image.ytn.co.kr/osen/2019/11/6e8ef36b-36c7-4d1c-896f-19499d54ca7d.jpg
# [Error] No active exception to reraise
# #4 이미지 다운로드 (http://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2019/05/14/l4yYxJN2K5lV636934516594025060.jpg)
# #4 파일 다운로드가 완료되었습니다.
# #5 이미지 다운로드 (https://img.hankyung.com/photo/201905/2019050912182051313-540x810.jpg)
# #5 파일 다운로드가 완료되었습니다.
# #6 이미지 다운로드 (https://image.ytn.co.kr/osen/2017/10/20171018_1508288101_52105800_1.jpg)
# #6 파일 다운로드가 완료되었습니다.
# #7 이미지 다운로드 (http://cfile28.uf.tistory.com/image/992C20335A0A0E513BA0E3)
# #7 파일 다운로드가 완료되었습니다.
# #8 이미지 다운로드 (http://img.etoday.co.kr/pto_db/2018/04/20180402120558_1200699_600_818.jpg)
# #8 파일 다운로드가 완료되었습니다.
# #9 이미지 다운로드 (http://cdnweb01.wikitree.co.kr/webdata/editor/201905/24/img_20190524092307_6e428fc2.jpg)
# #9 파일 다운로드가 완료되었습니다.
# #10 이미지 다운로드 (https://opgg-com-image.akamaized.net/attach/images/20190227041553.680266.jpeg)
# #10 파일 다운로드가 완료되었습니다.
# #11 이미지 다운로드 (https://image.ytn.co.kr/osen/2019/05/20190523_1558610209_96022300_1.jpg)
# #11 파일 다운로드가 완료되었습니다.
# #12 이미지 다운로드 (https://spnimage.edaily.co.kr/images/photo/files/NP/S/2015/08/PS15082600129.jpg)
# #12 파일 다운로드가 완료되었습니다.
# #13 이미지 다운로드 (https://img.sbs.co.kr/newsnet/etv/upload/2012/08/02/30000120695.jpg)
# #13 파일 다운로드가 완료되었습니다.
# #14 이미지 다운로드 (https://i.pinimg.com/originals/b9/33/b1/b933b16a5f68988447c475aee3562e06.jpg)
# #14 파일 다운로드가 완료되었습니다.
# #15 이미지 다운로드 (https://img.hankyung.com/photo/201811/01.18262140.1.jpg)
# #15 파일 다운로드가 완료되었습니다.
# #16 이미지 다운로드 (https://img.sbs.co.kr/newsnet/etv/upload/2017/10/03/30000582113_1280.jpg)
# #16 파일 다운로드가 완료되었습니다.
# #17 이미지 다운로드 (http://img.etoday.co.kr/pto_db/2018/07/20180706113446_1228107_600_818.jpg)
# #17 파일 다운로드가 완료되었습니다.
# #18 이미지 다운로드 (https://image.ytn.co.kr/osen/2019/12/ebc3773d-554e-4e2d-b40a-4e6ecb4c517a.jpg)
# [Error] Invalid image, not saving https://image.ytn.co.kr/osen/2019/12/ebc3773d-554e-4e2d-b40a-4e6ecb4c517a.jpg
# [Info] Issue getting: https://image.ytn.co.kr/osen/2019/12/ebc3773d-554e-4e2d-b40a-4e6ecb4c517a.jpg
# [Error] No active exception to reraise
# #18 이미지 다운로드 (http://image.ytn.co.kr/osen/2017/11/20160613_1465781770_47067700_1.jpg)
# #18 파일 다운로드가 완료되었습니다.
# #19 이미지 다운로드 (https://static.hubzum.zumst.com/hubzum/2016/11/18/09/a73f76991f14471685617f1781542c9b.jpg)
# #19 파일 다운로드가 완료되었습니다.
# #20 이미지 다운로드 (https://t1.daumcdn.net/movie/3b8713a22660343c04cca305c40741f4a2b9535c)
# #20 파일 다운로드가 완료되었습니다.
# #21 이미지 다운로드 (http://cfile2.uf.tistory.com/image/1630074D4E898E6D24A0E0)
# #21 파일 다운로드가 완료되었습니다.
# #22 이미지 다운로드 (https://file.mk.co.kr/meet/neds/2017/11/image_readtop_2017_730865_15097748923087877.png)
# #22 파일 다운로드가 완료되었습니다.
# #23 이미지 다운로드 (http://cdnweb01.wikitree.co.kr/webdata/editor/201608/24/img_20160824134902_236dd1bb.jpg)
# #23 파일 다운로드가 완료되었습니다.
# #24 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/992FFE4E5C00A4A126)
# #24 파일 다운로드가 완료되었습니다.
# #25 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/2373AD4A525CF5F118)
# #25 파일 다운로드가 완료되었습니다.
# #26 이미지 다운로드 (https://t1.daumcdn.net/news/201911/12/fmkorea/20191112112710295lnjf.jpg)
# #26 파일 다운로드가 완료되었습니다.
# #27 이미지 다운로드 (http://image.fmkorea.com/files/attach/new/20180316/486616/909995987/981357030/3ec5f45a2f3dbf571d80cd02a7dad0b1.jpg)
# #27 파일 다운로드가 완료되었습니다.
# #28 이미지 다운로드 (http://cdnweb01.wikitree.co.kr/webdata/editor/201608/24/img_20160824134034_c465b3ae.jpg)
# #28 파일 다운로드가 완료되었습니다.
# #29 이미지 다운로드 (https://lh3.googleusercontent.com/06YadVYq-9XyFpni6tzcFYM9zcqThBUqtVyczTw4yXCPZyBF-m9R9Gy0sgKULGxNAh5VaOwIHmTzhsrle_EUHD2SLYypZWKxDA=w1600-rj)
# #29 파일 다운로드가 완료되었습니다.
# #30 이미지 다운로드 (https://image.ytn.co.kr/osen/2017/10/20171023_1508740827_17062100_1.jpg)
# #30 파일 다운로드가 완료되었습니다.
# #31 이미지 다운로드 (http://www.dogdrip.net/dvs/b/i/17/10/22/78/229/761/142/a053fcc606570e45e4452b712aaa39e1.jpg)
# #31 파일 다운로드가 완료되었습니다.
# #32 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/99C782365D3AA5C907)
# #32 파일 다운로드가 완료되었습니다.
# #33 이미지 다운로드 (http://image.sportsseoul.com/2018/03/06/news/2018030601000196300013191.jpg)
# #33 파일 다운로드가 완료되었습니다.
# [Info] Done. Downloaded 33 images.
# [Info] Indexing page: 2
# [Info] Indexed 35 Images on Page 2.
# ===============================================
# #34 이미지 다운로드 (http://newsroom.etomato.com/userfiles/DSC05069.jpg)
# #34 파일 다운로드가 완료되었습니다.
# #35 이미지 다운로드 (https://image.ytn.co.kr/osen/2019/11/6e8ef36b-36c7-4d1c-896f-19499d54ca7d.jpg)
# [Error] Invalid image, not saving https://image.ytn.co.kr/osen/2019/11/6e8ef36b-36c7-4d1c-896f-19499d54ca7d.jpg
# [Info] Issue getting: https://image.ytn.co.kr/osen/2019/11/6e8ef36b-36c7-4d1c-896f-19499d54ca7d.jpg
# [Error] No active exception to reraise
# #35 이미지 다운로드 (http://newsroom.etomato.com/userfiles/DSC05084.jpg)
# #35 파일 다운로드가 완료되었습니다.
# #36 이미지 다운로드 (http://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2019/05/14/l4yYxJN2K5lV636934516594025060.jpg)
# #36 파일 다운로드가 완료되었습니다.
# #37 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/22638B4C582ECAD124)
# #37 파일 다운로드가 완료되었습니다.
# #38 이미지 다운로드 (https://img.hankyung.com/photo/201904/03.18208318.1.jpg)
# #38 파일 다운로드가 완료되었습니다.
# #39 이미지 다운로드 (https://img.hankyung.com/photo/201905/2019050912182051313-540x810.jpg)
# #39 파일 다운로드가 완료되었습니다.
# #40 이미지 다운로드 (http://newsroom.etomato.com/userfiles/DSC05108.jpg)
# #40 파일 다운로드가 완료되었습니다.
# ===============================================
# [Info] Done. Downloaded 40 images.
# [Train Dataset] image_28.jpg
# [Train Dataset] image_38.jpg
# [Train Dataset] image_8.jpg
# [Train Dataset] image_29.jpg
# [Train Dataset] image_14.jpg
# [Train Dataset] image_26.jpg
# [Train Dataset] image_4.jpg
# [Train Dataset] image_40.jpg
# [Train Dataset] image_1.jpg
# [Train Dataset] image_5.jpg
# [Train Dataset] image_30.jpg
# [Train Dataset] image_21.jpg
# [Train Dataset] image_10.jpeg
# [Train Dataset] image_18.jpg
# [Train Dataset] image_3.jpg
# [Train Dataset] image_36.jpg
# [Train Dataset] image_22.png
# [Train Dataset] image_9.jpg
# [Train Dataset] image_17.jpg
# [Train Dataset] image_11.jpg
# [Train Dataset] image_12.jpg
# [Train Dataset] image_16.jpg
# [Train Dataset] image_33.jpg
# [Train Dataset] image_23.jpg
# [Train Dataset] image_13.jpg
# [Train Dataset] image_37.jpg
# [Train Dataset] image_34.jpg
# [Train Dataset] image_32.jpg
# [Train Dataset] image_2.jpg
# [Train Dataset] image_27.jpg
# [Test Dataset] image_31.jpg
# [Test Dataset] image_35.jpg
# [Test Dataset] image_15.jpg
# [Test Dataset] image_7.jpg
# [Test Dataset] image_20.jpg
# [Test Dataset] image_19.jpg
# [Test Dataset] image_39.jpg
# [Test Dataset] image_25.jpg
# [Test Dataset] image_6.jpg
# [Test Dataset] image_24.jpg

# %%
query = '김종국'
downloader.download(query, limit=40,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 30)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ===============================================
# #1 이미지 다운로드 (https://file.mk.co.kr/meet/neds/2021/07/image_readtop_2021_701568_16268402604724279.jpeg)
# #1 파일 다운로드가 완료되었습니다.
# #2 이미지 다운로드 (https://archivenew.vop.co.kr/images/mobilethumbnail/2020-12/20115347_10.jpg)
# #2 파일 다운로드가 완료되었습니다.
# #3 이미지 다운로드 (http://menu.mtn.co.kr/upload/article/2014/09/01/2014090115295148277_1.jpg)
# #3 파일 다운로드가 완료되었습니다.
# #4 이미지 다운로드 (http://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2021/08/25/QkZbkEFNU70A637654971108109048.jpg)
# #4 파일 다운로드가 완료되었습니다.
# #5 이미지 다운로드 (http://pds.joins.com/news/component/htmlphoto_mmdata/2008/10/29/htm_200810290905290107000001070100-002.jpg)
# #5 파일 다운로드가 완료되었습니다.
# #6 이미지 다운로드 (http://dimg.donga.com/wps/SPORTS/IMAGE/2008/10/19/5065864.1.jpg)
# #6 파일 다운로드가 완료되었습니다.
# #7 이미지 다운로드 (https://img.sbs.co.kr/newsnet/etv/upload/2019/08/26/30000633265_1280.jpg)
# #7 파일 다운로드가 완료되었습니다.
# #8 이미지 다운로드 (http://image.kmib.co.kr/online_image/2015/0107/201501071329_61180009013537_1.jpg)
# #8 파일 다운로드가 완료되었습니다.
# #9 이미지 다운로드 (http://img.tvreportcdn.de/images/20140205/20140205_1391606996_02841100_1.jpg)
# #9 파일 다운로드가 완료되었습니다.
# #10 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/993DFF445D50CD3315)
# #10 파일 다운로드가 완료되었습니다.
# #11 이미지 다운로드 (http://postfiles11.naver.net/20121014_10/sdhzaza7979_1350186980597yk7Ca_JPEG/kyeongin_com_20121014_125605.jpg?type=w3)
# #11 파일 다운로드가 완료되었습니다.
# #12 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/99568D4B5D46BF4D37)
# #12 파일 다운로드가 완료되었습니다.
# #13 이미지 다운로드 (http://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2018/05/04/L7rtui2paMdQ636610331327882902.jpg)
# #13 파일 다운로드가 완료되었습니다.
# #14 이미지 다운로드 (http://img.stoo.com/upimages/gisaimg/2014/12/2014123019281900065_1.jpg)
# #14 파일 다운로드가 완료되었습니다.
# #15 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/252F63385952505010)
# #15 파일 다운로드가 완료되었습니다.
# #16 이미지 다운로드 (http://cfile23.uf.tistory.com/image/113BF2335092EBFC2FC074)
# #16 파일 다운로드가 완료되었습니다.
# #17 이미지 다운로드 (http://imgnews.naver.com/image/038/2008/10/24/coming200810232230400.jpg)
# #17 파일 다운로드가 완료되었습니다.
# #18 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/99404E4E5F54D7C90F)
# #18 파일 다운로드가 완료되었습니다.
# #19 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/1658034F5002182C17)
# #19 파일 다운로드가 완료되었습니다.
# #20 이미지 다운로드 (http://img.etoday.co.kr/pto_db/2017/10/20171010111502_1134785_600_818.jpg)
# #20 파일 다운로드가 완료되었습니다.
# #21 이미지 다운로드 (https://pbs.twimg.com/profile_images/974334435377102848/_DiZ6rVX_400x400.jpg)
# #21 파일 다운로드가 완료되었습니다.
# #22 이미지 다운로드 (http://ph.spotvnews.co.kr/news/photo/202107/432663_548054_1250.jpg)
# #22 파일 다운로드가 완료되었습니다.
# #23 이미지 다운로드 (https://img.insight.co.kr/static/2020/02/26/1200/838z1qxu7x5er78iyzcr.jpg)
# #23 파일 다운로드가 완료되었습니다.
# #24 이미지 다운로드 (http://imgnews.naver.com/image/076/2009/02/25/92z77133_1.jpg)
# #24 파일 다운로드가 완료되었습니다.
# #25 이미지 다운로드 (https://i.ytimg.com/vi/HT8cGpwMzc0/maxresdefault.jpg)
# #25 파일 다운로드가 완료되었습니다.
# #26 이미지 다운로드 (http://cfile6.uf.tistory.com/image/9922A533598AA0910B671D)
# #26 파일 다운로드가 완료되었습니다.
# #27 이미지 다운로드 (http://fs.jtbc.joins.com/prog/enter/construction/Img/20170324_205739_0447.jpg)
# #27 파일 다운로드가 완료되었습니다.
# #28 이미지 다운로드 (https://i.ytimg.com/vi/vhUpd5CToD8/maxresdefault.jpg)
# #28 파일 다운로드가 완료되었습니다.
# #29 이미지 다운로드 (https://image.ytn.co.kr/osen/2019/01/20190116_1547620748_24170800_1.jpg)
# #29 파일 다운로드가 완료되었습니다.
# #30 이미지 다운로드 (https://file2.nocutnews.co.kr/newsroom/image/2010/09/01133532796_60800030.jpg)
# #30 파일 다운로드가 완료되었습니다.
# #31 이미지 다운로드 (http://knitwang.cafe24.com/web/product/14fw/kimjongkuk.jpg)
# #31 파일 다운로드가 완료되었습니다.
# #32 이미지 다운로드 (https://i.ytimg.com/vi/vSUBcOjQsa4/maxresdefault.jpg)
# #32 파일 다운로드가 완료되었습니다.
# #33 이미지 다운로드 (http://postfiles13.naver.net/20121014_92/sdhzaza7979_1350187212870L02NU_JPEG/888_00000.jpg?type=w3)
# [Error] Invalid image, not saving http://postfiles13.naver.net/20121014_92/sdhzaza7979_1350187212870L02NU_JPEG/888_00000.jpg?type=w3
# [Info] Issue getting: http://postfiles13.naver.net/20121014_92/sdhzaza7979_1350187212870L02NU_JPEG/888_00000.jpg?type=w3
# [Error] No active exception to reraise
# #33 이미지 다운로드 (https://i.ytimg.com/vi/xUw3WLfYzvg/maxresdefault.jpg)
# #33 파일 다운로드가 완료되었습니다.
# #34 이미지 다운로드 (https://i.ytimg.com/vi/KEdx8PN0hck/maxresdefault.jpg)
# #34 파일 다운로드가 완료되었습니다.
# [Info] Done. Downloaded 34 images.
# [Info] Indexing page: 2
# [Info] Indexed 35 Images on Page 2.
# ===============================================
# #35 이미지 다운로드 (https://file.mk.co.kr/meet/neds/2021/07/image_readtop_2021_701568_16268402604724279.jpeg)
# #35 파일 다운로드가 완료되었습니다.
# #36 이미지 다운로드 (https://archivenew.vop.co.kr/images/mobilethumbnail/2020-12/20115347_10.jpg)
# #36 파일 다운로드가 완료되었습니다.
# #37 이미지 다운로드 (http://menu.mtn.co.kr/upload/article/2014/09/01/2014090115295148277_1.jpg)
# #37 파일 다운로드가 완료되었습니다.
# #38 이미지 다운로드 (http://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2021/08/25/QkZbkEFNU70A637654971108109048.jpg)
# #38 파일 다운로드가 완료되었습니다.
# #39 이미지 다운로드 (http://pds.joins.com/news/component/htmlphoto_mmdata/2008/10/29/htm_200810290905290107000001070100-002.jpg)
# #39 파일 다운로드가 완료되었습니다.
# #40 이미지 다운로드 (http://dimg.donga.com/wps/SPORTS/IMAGE/2008/10/19/5065864.1.jpg)
# #40 파일 다운로드가 완료되었습니다.
# ===============================================
# [Info] Done. Downloaded 40 images.
# [Train Dataset] image_28.jpg
# [Train Dataset] image_38.jpg
# [Train Dataset] image_8.jpg
# [Train Dataset] image_29.jpg
# [Train Dataset] image_14.jpg
# [Train Dataset] image_26.jpg
# [Train Dataset] image_4.jpg
# [Train Dataset] image_40.jpg
# [Train Dataset] image_5.jpg
# [Train Dataset] image_10.jpg
# [Train Dataset] image_30.jpg
# [Train Dataset] image_21.jpg
# [Train Dataset] image_35.jpeg
# [Train Dataset] image_18.jpg
# [Train Dataset] image_3.jpg
# [Train Dataset] image_36.jpg
# [Train Dataset] image_9.jpg
# [Train Dataset] image_17.jpg
# [Train Dataset] image_11.jpg
# [Train Dataset] image_12.jpg
# [Train Dataset] image_16.jpg
# [Train Dataset] image_33.jpg
# [Train Dataset] image_23.jpg
# [Train Dataset] image_13.jpg
# [Train Dataset] image_37.jpg
# [Train Dataset] image_34.jpg
# [Train Dataset] image_32.jpg
# [Train Dataset] image_2.jpg
# [Train Dataset] image_27.jpg
# [Train Dataset] image_31.jpg
# [Test Dataset] image_15.jpg
# [Test Dataset] image_7.jpg
# [Test Dataset] image_20.jpg
# [Test Dataset] image_19.jpg
# [Test Dataset] image_39.jpg
# [Test Dataset] image_25.jpg
# [Test Dataset] image_1.jpeg
# [Test Dataset] image_6.jpg
# [Test Dataset] image_22.jpg
# [Test Dataset] image_24.jpg

# %%
query = '이병헌'
downloader.download(query, limit=40,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 30)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ===============================================
# #1 이미지 다운로드 (https://newsimg.hankookilbo.com/cms/articlerelease/2016/01/25/201601251517155220_1.jpg)
# #1 파일 다운로드가 완료되었습니다.
# #2 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/992074395E31B68F2C)
# #2 파일 다운로드가 완료되었습니다.
# #3 이미지 다운로드 (https://img.mbn.co.kr/filewww/news/other/2016/09/12/129111202022.png)
# #3 파일 다운로드가 완료되었습니다.
# #4 이미지 다운로드 (http://img.marieclairekorea.com/2019/09/mck_5d8883f2e595b.jpg)
# #4 파일 다운로드가 완료되었습니다.
# #5 이미지 다운로드 (http://asianwiki.com/images/e/ee/Lee_Byung-Hun-p04.jpg)
# #5 파일 다운로드가 완료되었습니다.
# #6 이미지 다운로드 (http://img2.sbs.co.kr/img/sbs_cms/CH/2016/04/20/CH56247343_w666_h968.jpg)
# #6 파일 다운로드가 완료되었습니다.
# #7 이미지 다운로드 (http://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2016/08/11/c2MCchMTuHs2636065227239080552.jpg)
# #7 파일 다운로드가 완료되었습니다.
# #8 이미지 다운로드 (http://img.yonhapnews.co.kr/photo/yna/YH/2012/08/13/PYH2012081307070001300_P2.jpg)
# #8 파일 다운로드가 완료되었습니다.
# #9 이미지 다운로드 (https://newsimg.sedaily.com/2018/01/04/1RUAPFDVPO_2.jpg)
# #9 파일 다운로드가 완료되었습니다.
# #10 이미지 다운로드 (http://img.etoday.co.kr/pto_db/2017/01/20170116113255_1005565_600_900.jpg)
# #10 파일 다운로드가 완료되었습니다.
# #11 이미지 다운로드 (http://image.cine21.com/resize/cine21/event/2015/0811/17_49_16__55c9b70c97748[H800-].jpg)
# #11 파일 다운로드가 완료되었습니다.
# #12 이미지 다운로드 (https://pds.joins.com/news/component/htmlphoto_mmdata/202011/26/a467d763-4eb8-4c21-9eae-52e4a2d71168.jpg)
# #12 파일 다운로드가 완료되었습니다.
# #13 이미지 다운로드 (https://img0.yna.co.kr/photo/yna/YH/2018/03/22/PYH2018032220700001300_P2.jpg)
# #13 파일 다운로드가 완료되었습니다.
# #14 이미지 다운로드 (https://menu.mt.co.kr/moneyweek/thumb/2017/09/20/06/2017092011308028611_1.jpg)
# #14 파일 다운로드가 완료되었습니다.
# #15 이미지 다운로드 (http://img.sbs.co.kr/newsnet/etv/upload/2013/03/12/30000245508.jpg)
# #15 파일 다운로드가 완료되었습니다.
# #16 이미지 다운로드 (https://img.hankyung.com/photo/201911/03.21013313.1.jpg)
# #16 파일 다운로드가 완료되었습니다.
# #17 이미지 다운로드 (https://img3.yna.co.kr/photo/yna/YH/2019/12/12/PYH2019121210030001300_P4.jpg)
# #17 파일 다운로드가 완료되었습니다.
# #18 이미지 다운로드 (https://dimg.donga.com/wps/NEWS/IMAGE/2015/11/19/74869692.4.jpg)
# #18 파일 다운로드가 완료되었습니다.
# #19 이미지 다운로드 (https://img.tvreportcdn.de/cms-content/uploads/2019/12/20/d5799972-31a1-4bd9-9d74-c53eea369fe9.jpg)
# [Error] Invalid image, not saving https://img.tvreportcdn.de/cms-content/uploads/2019/12/20/d5799972-31a1-4bd9-9d74-c53eea369fe9.jpg
# [Info] Issue getting: https://img.tvreportcdn.de/cms-content/uploads/2019/12/20/d5799972-31a1-4bd9-9d74-c53eea369fe9.jpg
# [Error] No active exception to reraise
# #19 이미지 다운로드 (http://res.heraldm.com/content/image/2015/11/14/20151114000020_0.jpg)
# #19 파일 다운로드가 완료되었습니다.
# #20 이미지 다운로드 (https://thumb.mt.co.kr/06/2021/07/2021071921210836724_1.jpg/dims/optimize/)
# #20 파일 다운로드가 완료되었습니다.
# #21 이미지 다운로드 (https://img1.yna.co.kr/photo/yna/YH/2013/03/11/PYH2013031104220001300_P4.jpg)
# #21 파일 다운로드가 완료되었습니다.
# #22 이미지 다운로드 (https://img7.yna.co.kr/etc/inner/KR/2020/01/16/AKR20200116182300005_01_i_P4.jpg)
# #22 파일 다운로드가 완료되었습니다.
# #23 이미지 다운로드 (http://img.tvreportcdn.de/images/20130705/20130705_1373028446_48482000_1.jpg?1373264769)
# #23 파일 다운로드가 완료되었습니다.
# #24 이미지 다운로드 (http://img.etoday.co.kr/pto_db/2016/11/20161110082444_970278_600_900.jpg)
# #24 파일 다운로드가 완료되었습니다.
# #25 이미지 다운로드 (http://thumb.mtstarnews.com/06/2018/09/2018092817242112342_1.jpg)
# #25 파일 다운로드가 완료되었습니다.
# #26 이미지 다운로드 (https://img.hankyung.com/photo/201011/201011136369k_2010111389211.jpg)
# #26 파일 다운로드가 완료되었습니다.
# #27 이미지 다운로드 (http://img.gqkorea.co.kr/gq/2011/03/style_564ed3475bf5a.jpg)
# #27 파일 다운로드가 완료되었습니다.
# #28 이미지 다운로드 (https://newsimg.hankookilbo.com/cms/articlerelease/2014/10/16/201410161481984960_1.jpg)
# #28 파일 다운로드가 완료되었습니다.
# #29 이미지 다운로드 (http://image.kmib.co.kr/online_image/2014/0902/201409020504_11130922778267_1.jpg)
# #29 파일 다운로드가 완료되었습니다.
# #30 이미지 다운로드 (http://pds.joins.com/news/component/htmlphoto_mmdata/201208/13/htm_20120813131032158.jpg)
# #30 파일 다운로드가 완료되었습니다.
# #31 이미지 다운로드 (http://img.lb.inews24.com/facebookexternalhit/face/626x352/image_joy/201511/1446518330842_1_113943.jpg)
# #31 파일 다운로드가 완료되었습니다.
# #32 이미지 다운로드 (https://i.pinimg.com/originals/5f/01/24/5f0124754e9514213c754302bf5a129e.jpg)
# #32 파일 다운로드가 완료되었습니다.
# #33 이미지 다운로드 (https://i.ytimg.com/vi/IBPjIoSFLCw/maxresdefault.jpg)
# #33 파일 다운로드가 완료되었습니다.
# #34 이미지 다운로드 (http://cfile234.uf.daum.net/image/1865D5044BE606C4747B0F)
# #34 파일 다운로드가 완료되었습니다.
# [Info] Done. Downloaded 34 images.
# [Info] Indexing page: 2
# [Info] Indexed 35 Images on Page 2.
# ===============================================
# #35 이미지 다운로드 (https://newsimg.hankookilbo.com/cms/articlerelease/2016/01/25/201601251517155220_1.jpg)
# #35 파일 다운로드가 완료되었습니다.
# #36 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/992074395E31B68F2C)
# #36 파일 다운로드가 완료되었습니다.
# #37 이미지 다운로드 (https://img.mbn.co.kr/filewww/news/other/2016/09/12/129111202022.png)
# #37 파일 다운로드가 완료되었습니다.
# #38 이미지 다운로드 (http://img.marieclairekorea.com/2019/09/mck_5d8883f2e595b.jpg)
# #38 파일 다운로드가 완료되었습니다.
# #39 이미지 다운로드 (http://asianwiki.com/images/e/ee/Lee_Byung-Hun-p04.jpg)
# #39 파일 다운로드가 완료되었습니다.
# #40 이미지 다운로드 (http://cfile10.uf.tistory.com/image/1462D84C505E88F2235A2B)
# #40 파일 다운로드가 완료되었습니다.
# ===============================================
# [Info] Done. Downloaded 40 images.
# [Train Dataset] image_28.jpg
# [Train Dataset] image_38.jpg
# [Train Dataset] image_8.jpg
# [Train Dataset] image_29.jpg
# [Train Dataset] image_14.jpg
# [Train Dataset] image_26.jpg
# [Train Dataset] image_4.jpg
# [Train Dataset] image_40.jpg
# [Train Dataset] image_1.jpg
# [Train Dataset] image_5.jpg
# [Train Dataset] image_10.jpg
# [Train Dataset] image_30.jpg
# [Train Dataset] image_21.jpg
# [Train Dataset] image_3.png
# [Train Dataset] image_18.jpg
# [Train Dataset] image_36.jpg
# [Train Dataset] image_9.jpg
# [Train Dataset] image_17.jpg
# [Train Dataset] image_11.jpg
# [Train Dataset] image_12.jpg
# [Train Dataset] image_16.jpg
# [Train Dataset] image_33.jpg
# [Train Dataset] image_23.jpg
# [Train Dataset] image_13.jpg
# [Train Dataset] image_34.jpg
# [Train Dataset] image_32.jpg
# [Train Dataset] image_2.jpg
# [Train Dataset] image_27.jpg
# [Train Dataset] image_31.jpg
# [Train Dataset] image_35.jpg
# [Test Dataset] image_15.jpg
# [Test Dataset] image_7.jpg
# [Test Dataset] image_20.jpg
# [Test Dataset] image_19.jpg
# [Test Dataset] image_37.png
# [Test Dataset] image_39.jpg
# [Test Dataset] image_25.jpg
# [Test Dataset] image_6.jpg
# [Test Dataset] image_22.jpg
# [Test Dataset] image_24.jpg

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision import datasets, models, transforms

import numpy as np
import time


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # device 객체

# %%
# 데이터셋을 불러올 때 사용할 변형(transformation) 객체 정의
transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(), # 데이터 증진(augmentation)
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

transforms_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

data_dir = './custom_dataset'
train_datasets = datasets.ImageFolder(os.path.join(data_dir, 'train'), transforms_train)
test_datasets = datasets.ImageFolder(os.path.join(data_dir, 'test'), transforms_test)

train_dataloader = torch.utils.data.DataLoader(train_datasets, batch_size=4, shuffle=True, num_workers=4)
test_dataloader = torch.utils.data.DataLoader(test_datasets, batch_size=4, shuffle=True, num_workers=4)

print('학습 데이터셋 크기:', len(train_datasets))
print('테스트 데이터셋 크기:', len(test_datasets))

class_names = train_datasets.classes
print('클래스:', class_names)
# Out:
# 학습 데이터셋 크기: 90
# 테스트 데이터셋 크기: 30
# 클래스: ['김종국', '마동석', '이병헌']
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
def imshow(input, title):
    # torch.Tensor를 numpy 객체로 변환
    input = input.numpy().transpose((1, 2, 0))
    # 이미지 정규화 해제하기
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    # 이미지 출력
    plt.imshow(input)
    plt.title(title)
    plt.show()


# 학습 데이터를 배치 단위로 불러오기
iterator = iter(train_dataloader)

# 현재 배치를 이용해 격자 형태의 이미지를 만들어 시각화
inputs, classes = next(iterator)
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])

# %%
model = models.resnet34(pretrained=True)
num_features = model.fc.in_features
# 전이 학습(transfer learning): 모델의 출력 뉴런 수를 3개로 교체하여 마지막 레이어 다시 학습
model.fc = nn.Linear(num_features, 3)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]

# %%
num_epochs = 50
model.train()
start_time = time.time()

# 전체 반복(epoch) 수 만큼 반복하며
for epoch in range(num_epochs):
    running_loss = 0.
    running_corrects = 0

    # 배치 단위로 학습 데이터 불러오기
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        # 모델에 입력(forward)하고 결과 계산
        optimizer.zero_grad()
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

      
        # 역전파를 통해 기울기(gradient) 계산 및 학습 진행
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_datasets)
    epoch_acc = running_corrects / len(train_datasets) * 100.

    # 학습 과정 중에 결과 출력
    print('#{} Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch, epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# #0 Loss: 1.1638 Acc: 36.6667% Time: 9.2019s
# #1 Loss: 0.8110 Acc: 62.2222% Time: 12.3538s
# #2 Loss: 0.2685 Acc: 91.1111% Time: 15.5338s
# #3 Loss: 0.2054 Acc: 92.2222% Time: 18.8075s
# #4 Loss: 0.3004 Acc: 90.0000% Time: 22.0560s
# #5 Loss: 0.2457 Acc: 92.2222% Time: 25.2867s
# #6 Loss: 0.3580 Acc: 85.5556% Time: 28.4926s
# #7 Loss: 0.2441 Acc: 91.1111% Time: 31.7320s
# #8 Loss: 0.1945 Acc: 95.5556% Time: 34.9008s
# #9 Loss: 0.2283 Acc: 93.3333% Time: 38.1435s
# #10 Loss: 0.3558 Acc: 88.8889% Time: 41.3115s
# #11 Loss: 0.2684 Acc: 88.8889% Time: 44.5634s
# #12 Loss: 0.1133 Acc: 97.7778% Time: 47.8270s
# #13 Loss: 0.0900 Acc: 96.6667% Time: 51.1156s
# #14 Loss: 0.0425 Acc: 97.7778% Time: 54.4627s
# #15 Loss: 0.1293 Acc: 97.7778% Time: 57.6263s
# #16 Loss: 0.0933 Acc: 98.8889% Time: 60.9335s
# #17 Loss: 0.2792 Acc: 92.2222% Time: 64.2622s
# #18 Loss: 0.1570 Acc: 95.5556% Time: 67.4432s
# #19 Loss: 0.2807 Acc: 90.0000% Time: 70.7007s
# #20 Loss: 0.1916 Acc: 91.1111% Time: 73.8534s
# #21 Loss: 0.1477 Acc: 94.4445% Time: 77.1514s
# #22 Loss: 0.3216 Acc: 92.2222% Time: 80.3008s
# #23 Loss: 0.3047 Acc: 88.8889% Time: 83.4961s
# #24 Loss: 0.1930 Acc: 92.2222% Time: 86.7578s
# #25 Loss: 0.1683 Acc: 94.4445% Time: 90.0081s
# #26 Loss: 0.1564 Acc: 94.4445% Time: 93.1900s
# #27 Loss: 0.1572 Acc: 95.5556% Time: 96.3319s
# #28 Loss: 0.1241 Acc: 95.5556% Time: 99.5586s
# #29 Loss: 0.1273 Acc: 95.5556% Time: 102.7367s
# #30 Loss: 0.1091 Acc: 96.6667% Time: 105.9834s
# #31 Loss: 0.1565 Acc: 94.4445% Time: 109.1636s
# #32 Loss: 0.0267 Acc: 100.0000% Time: 112.3083s
# #33 Loss: 0.0260 Acc: 98.8889% Time: 115.6251s
# #34 Loss: 0.0840 Acc: 97.7778% Time: 118.8537s
# #35 Loss: 0.2839 Acc: 93.3333% Time: 122.0630s
# #36 Loss: 0.1263 Acc: 96.6667% Time: 125.2738s
# #37 Loss: 0.2675 Acc: 91.1111% Time: 128.5112s
# #38 Loss: 0.1680 Acc: 93.3333% Time: 131.6941s
# #39 Loss: 0.3811 Acc: 88.8889% Time: 134.7892s
# #40 Loss: 0.1054 Acc: 95.5556% Time: 138.1560s
# #41 Loss: 0.0663 Acc: 97.7778% Time: 141.3134s
# #42 Loss: 0.1624 Acc: 95.5556% Time: 144.5664s
# #43 Loss: 0.1781 Acc: 94.4445% Time: 147.7406s
# #44 Loss: 0.0635 Acc: 95.5556% Time: 150.8749s
# #45 Loss: 0.0670 Acc: 98.8889% Time: 154.0636s
# #46 Loss: 0.0378 Acc: 98.8889% Time: 157.2537s
# #47 Loss: 0.3308 Acc: 92.2222% Time: 160.4791s
# #48 Loss: 0.1068 Acc: 95.5556% Time: 163.6257s
# #49 Loss: 0.1788 Acc: 94.4445% Time: 166.8896s

# %%
model.eval()
start_time = time.time()

with torch.no_grad():
    running_loss = 0.
    running_corrects = 0

    for inputs, labels in test_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

        # 한 배치의 첫 번째 이미지에 대하여 결과 시각화
        print(f'[예측 결과: {class_names[preds[0]]}] (실제 정답: {class_names[labels.data[0]]})')
        imshow(inputs.cpu().data[0], title='예측 결과: ' + class_names[preds[0]])

    epoch_loss = running_loss / len(test_datasets)
    epoch_acc = running_corrects / len(test_datasets) * 100.
    print('[Test Phase] Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# [예측 결과: 이병헌] (실제 정답: 이병헌)
# [예측 결과: 김종국] (실제 정답: 김종국)
# [예측 결과: 이병헌] (실제 정답: 이병헌)
# [예측 결과: 마동석] (실제 정답: 마동석)
# [예측 결과: 이병헌] (실제 정답: 이병헌)
# [예측 결과: 마동석] (실제 정답: 마동석)
# [예측 결과: 이병헌] (실제 정답: 이병헌)
# [예측 결과: 이병헌] (실제 정답: 이병헌)
# [Test Phase] Loss: 0.1435 Acc: 93.3333% Time: 2.2529s

# %%
for i in range(4):
  print(inputs.size(i))
# Out:
# 2
# 3
# 224
# 224

# %%
print(labels.data[1])
# Out:
# tensor(2, device='cuda:0')

# %%
print(epoch_acc)
# Out:
# tensor(93.3333, device='cuda:0')

# %%
# 테스트용 이미지 다운로드하기
# !wget https://upload.wikimedia.org/wikipedia/commons/f/f1/Don_Lee_by_Gage_Skidmore.jpg -O test_image.jpg
# Out:
# --2023-01-10 10:51:42--  https://upload.wikimedia.org/wikipedia/commons/f/f1/Don_Lee_by_Gage_Skidmore.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 103.102.166.240, 2001:df2:e500:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|103.102.166.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4070584 (3.9M) [image/jpeg]
# Saving to: ‘test_image.jpg’
#
# test_image.jpg      100%[===================>]   3.88M  --.-KB/s    in 0.1s
#
# 2023-01-10 10:51:43 (29.3 MB/s) - ‘test_image.jpg’ saved [4070584/4070584]

# %%
from PIL import Image


image = Image.open('namsh3.jpg')
image = transforms_test(image).unsqueeze(0).to(device)

with torch.no_grad():
    outputs = model(image)
    _, preds = torch.max(outputs, 1)
    imshow(image.cpu().data[0], title='예측 결과: ' + class_names[preds[0]])

# %%
print(preds)
# Out:
# tensor([2], device='cuda:0')

# %%
pwd
# Out:
# '/content'

# %%
print(outputs)
# Out:
# tensor([[-3.4681, -2.2993,  7.2211]], device='cuda:0')

# %%
print(preds)
# Out:
# tensor([2], device='cuda:0')

# %%
import numpy as np
from pandas import Series

tensor = torch.tensor([[-3.4681, -2.2993,  7.2211]], device='cuda:0')
np_array = tensor.cpu().numpy()
pct_change =Series.pct_change(np_array)
print(pct_change)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-4b5bc49f1f2e> in <module>
#       4 tensor = torch.tensor([[-3.4681, -2.2993,  7.2211]], device='cuda:0')
#       5 np_array = tensor.cpu().numpy()
# ----> 6 pct_change =Series.pct_change(np_array)
#       7 print(pct_change)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in pct_change(self, periods, fill_method, limit, freq, **kwargs)
#   10153         APPL -0.252395 -0.011860   NaN
#   10154         """
# > 10155         axis = self._get_axis_number(kwargs.pop("axis", self._stat_axis_name))
#   10156         if fill_method is None:
#   10157             data = self
#
# AttributeError: 'numpy.ndarray' object has no attribute '_get_axis_number'

# %%
print(np_array)
# Out:
# [[-3.4681 -2.2993  7.2211]]
