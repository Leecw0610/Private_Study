# %% [markdown]
# # 11월 3일자 복습

# %% [markdown]
# ## Data.go.kr 의 승강기 데이터 참조해 주소1, 주소2, 건물명, 승강기번호, 승강기상태, 최종검사일, 적재하중, 제조업체전화번호 가져오기

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
req = requests.get('http://apis.data.go.kr/openapi/service/ElevatorInformationService/getElevatorList?serviceKey=3kygm0EzV%2FeG00gMCdgTQjYgzVPeoD2d32kFk9tt9zK8azyGuHSH3DDt8jWoU9vhjMqn7gbVhjnXizJ76qne8g%3D%3D&numOfRows=100&pageNo=1&sido=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C&sigungu=%EC%9D%80%ED%8F%89%EA%B5%AC')

# %%
soup = BeautifulSoup(req.text, 'xml')

# %%
soup
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><address1>서울특별시 은평구 연서로 71</address1><address2>(역촌동)</address2><applcBeDt>2022-05-24</applcBeDt><applcEnDt>2023-05-23</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>236</buldMgtNo2><buldNm>(재)살림이</buldNm><buldPrpos>제2종근린생활시설-기타</buldPrpos><divGroundFloorCnt>5</divGroundFloorCnt><divUndgrndFloorCnt>1</divUndgrndFloorCnt><elevatorNo>0081201</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>승객용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>440</elvtrMgtNo2><elvtrModel>SCN5NKZi(412,S)</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>1998-01-15</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>1998-01-15</installationDe><installationPlace>1-1</installationPlace><lastInspctDe>2022-05-24</lastInspctDe><lastInspctKind>수시</lastInspctKind><lastResultNm>합격</lastResultNm><liveLoad>550 KG</liveLoad><manufacturerName>엘지산전(주) 창원공장</manufacturerName><manufacturerTelno>055-269-4114</manufacturerTelno><mnfcturCpnyCd>919920032</mnfcturCpnyCd><mntCpnyCd>919990047</mntCpnyCd><mntCpnyNm>(주)제일승강기</mntCpnyNm><mntCpnyTelno>031-908-8681</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>승강기 담당자</partcpntNm><partcpntTelno>010-9884-1***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>8 인승</ratedCap><ratedSpeed>1 M/MIN</ratedSpeed><shuttleFloorCnt>6</shuttleFloorCnt><shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>B1-5</shuttleSection><sigunguCd>122</sigunguCd><standardKey>1</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>034</zipCd1><zipCd2>17</zipCd2></item><item><address1>서울특별시 은평구 통일로71길 16</address1><address2>(대조동)</address2><applcBeDt>2022-09-29</applcBeDt><applcEnDt>2023-09-28</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>889</buldMgtNo2><buldNm>(주)KT 은평지사</buldNm><buldPrpos>업무시설-기타</buldPrpos><divGroundFloorCnt>4</divGroundFloorCnt><divUndgrndFloorCnt>1</divUndgrndFloorCnt><elevatorNo>0042569</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>장애인용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>1760</elvtrMgtNo2><elvtrModel>Di1</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>2005-08-24</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>2005-08-24</installationDe><installationPlace>1-1</installationPlace><lastInspctDe>2022-10-11</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>합격</lastResultNm><liveLoad>1150 KG</liveLoad><manufacturerName>오티스엘리베이터(유)창원공장</manufacturerName><manufacturerTelno>055-289-8235</manufacturerTelno><mnfcturCpnyCd>919990124</mnfcturCpnyCd><mntCpnyCd>919920075</mntCpnyCd><mntCpnyNm>오티스엘리베이터(유)서울</mntCpnyNm><mntCpnyTelno>02-2007-5800</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>김봉수(설비실장)</partcpntNm><partcpntTelno>010-3043-1***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>17 인승</ratedCap><ratedSpeed>1.5 M/MIN</ratedSpeed><shuttleFloorCnt>4</shuttleFloorCnt><shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>1-4</shuttleSection><sigunguCd>122</sigunguCd><standardKey>1</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>033</zipCd1><zipCd2>91</zipCd2></item><item><address1>서울특별시 은평구 통일로71길 16</address1><address2>(대조동)</address2><applcBeDt>2022-09-29</applcBeDt><applcEnDt>2023-09-28</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>889</buldMgtNo2><buldNm>(주)KT 은평지사</buldNm><buldPrpos>업무시설-기타</buldPrpos><divGroundFloorCnt>4</divGroundFloorCnt><divUndgrndFloorCnt>1</divUndgrndFloorCnt><elevatorNo>0042570</elevatorNo><elvtrAsignNo>2</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elv ...

# %%
list1 = soup.select('address1')

# %%
list1
# Out:
# [<address1>서울특별시 은평구 연서로 71</address1>,
#  <address1>서울특별시 은평구 통일로71길 16</address1>,
#  <address1>서울특별시 은평구 통일로71길 16</address1>,
#  <address1>서울특별시 은평구 은평로13길 12-1</address1>,
#  <address1>서울특별시 은평구 은평로13길 12-1</address1>,
#  <address1>서울특별시 은평구 응암로 165</address1>,
#  <address1>서울특별시 은평구 통일로 874</address1>,
#  <address1>서울특별시 은평구 통일로66길 6-10</address1>,
#  <address1>서울특별시 은평구 은평로 210</address1>,
#  <address1>서울특별시 은평구 은평로 210</address1>,
#  <address1>서울특별시 은평구 통일로87길 14</address1>,
#  <address1>서울특별시 은평구 통일로 585-1</address1>,
#  <address1>서울특별시 은평구 통일로 585-1</address1>,
#  <address1>서울특별시 은평구 은평로2길 6-18</address1>,
#  <address1>서울특별시 은평구 통일로 689-7</address1>,
#  <address1>서울특별시 은평구 연서로 520</address1>,
#  <address1>서울특별시 은평구 연서로13길 29-6 (구산동)</address1>,
#  <address1>서울특별시 은평구 통일로71길 6</address1>,
#  <address1>서울특별시 은평구 통일로53길 9-6</address1>,
#  <address1>서울특별시 은평구 서오릉로 30</address1>,
#  <address1>서울특별시 은평구 서오릉로 30</address1>,
#  <address1>서울특별시 은평구 서오릉로 30</address1>,
#  <address1>서울특별시 은평구 은평로 91</address1>,
#  <address1>서울특별시 은평구 은평로 91</address1>,
#  <address1>서울특별시 은평구 은평로 91</address1>,
#  <address1>서울특별시 은평구 불광로 55</address1>,
#  <address1>서울특별시 은평구 응암로 308</address1>,
#  <address1>서울특별시 은평구 갈현로 141</address1>,
#  <address1>서울특별시 은평구 연서로20길 13</address1>,
#  <address1>서울특별시 은평구 진흥로 183</address1>,
#  <address1>서울특별시 은평구 진흥로9길 8-4</address1>,
#  <address1>서울특별시 은평구 역말로9가길 8-1</address1>,
#  <address1>서울특별시 은평구 응암로21가길 1-7</address1>,
#  <address1>서울특별시 은평구 불광동 281-76</address1>,
#  <address1>서울특별시 은평구 불광로 50-5</address1>,
#  <address1>서울특별시 은평구 통일로78길 11-7</address1>,
#  <address1>서울특별시 은평구 통일로 708-7</address1>,
#  <address1>서울특별시 은평구 서오릉로 12</address1>,
#  <address1>서울특별시 은평구 갈현로15길 20</address1>,
#  <address1>서울특별시 은평구 은평로21길 16-1</address1>,
#  <address1>서울특별시 은평구 은평로21길 16</address1>,
#  <address1>서울특별시 은평구 역말로 37-6</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 216</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로 200</address1>,
#  <address1>서울특별시 은평구 수색로22가길 5-1</address1>]

# %%
soup.items()
# Out:
# [<item><address1>서울특별시 은평구 연서로 71</address1><address2>(역촌동)</address2><applcBeDt>2022-05-24</applcBeDt><applcEnDt>2023-05-23</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>236</buldMgtNo2><buldNm>(재)살림이</buldNm><buldPrpos>제2종근린생활시설-기타</buldPrpos><divGroundFloorCnt>5</divGroundFloorCnt><divUndgrndFloorCnt>1</divUndgrndFloorCnt><elevatorNo>0081201</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>승객용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>440</elvtrMgtNo2><elvtrModel>SCN5NKZi(412,S)</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>1998-01-15</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>1998-01-15</installationDe><installationPlace>1-1</installationPlace><lastInspctDe>2022-05-24</lastInspctDe><lastInspctKind>수시</lastInspctKind><lastResultNm>합격</lastResultNm><liveLoad>550 KG</liveLoad><manufacturerName>엘지산전(주) 창원공장</manufacturerName><manufacturerTelno>055-269-4114</manufacturerTelno><mnfcturCpnyCd>919920032</mnfcturCpnyCd><mntCpnyCd>919990047</mntCpnyCd><mntCpnyNm>(주)제일승강기</mntCpnyNm><mntCpnyTelno>031-908-8681</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>승강기 담당자</partcpntNm><partcpntTelno>010-9884-1***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>8 인승</ratedCap><ratedSpeed>1 M/MIN</ratedSpeed><shuttleFloorCnt>6</shuttleFloorCnt><shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>B1-5</shuttleSection><sigunguCd>122</sigunguCd><standardKey>1</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>034</zipCd1><zipCd2>17</zipCd2></item>,
#  <address1>서울특별시 은평구 연서로 71</address1>,
#  <address2>(역촌동)</address2>,
#  <applcBeDt>2022-05-24</applcBeDt>,
#  <applcEnDt>2023-05-23</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>236</buldMgtNo2>,
#  <buldNm>(재)살림이</buldNm>,
#  <buldPrpos>제2종근린생활시설-기타</buldPrpos>,
#  <divGroundFloorCnt>5</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>1</divUndgrndFloorCnt>,
#  <elevatorNo>0081201</elevatorNo>,
#  <elvtrAsignNo>1</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
#  <elvtrKindNm>승객용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>440</elvtrMgtNo2>,
#  <elvtrModel>SCN5NKZi(412,S)</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>1998-01-15</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>1998-01-15</installationDe>,
#  <installationPlace>1-1</installationPlace>,
#  <lastInspctDe>2022-05-24</lastInspctDe>,
#  <lastInspctKind>수시</lastInspctKind>,
#  <lastResultNm>합격</lastResultNm>,
#  <liveLoad>550 KG</liveLoad>,
#  <manufacturerName>엘지산전(주) 창원공장</manufacturerName>,
#  <manufacturerTelno>055-269-4114</manufacturerTelno>,
#  <mnfcturCpnyCd>919920032</mnfcturCpnyCd>,
#  <mntCpnyCd>919990047</mntCpnyCd>,
#  <mntCpnyNm>(주)제일승강기</mntCpnyNm>,
#  <mntCpnyTelno>031-908-8681</mntCpnyTelno>,
#  <mrYn>Y</mrYn>,
#  <partcpntNm>승강기 담당자</partcpntNm>,
#  <partcpntTelno>010-9884-1***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>8 인승</ratedCap>,
#  <ratedSpeed>1 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>6</shuttleFloorCnt>,
#  <shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>B1-5</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>1</standardKey>,
#  <subcntrCpny>-</subcntrCpny>,
#  <zipCd1>034</zipCd1>,
#  <zipCd2>17</zipCd2>,
#  <item><address1>서울특별시 은평구 통일로71길 16</address1><address2>(대조동)</address2><applcBeDt>2022-09-29</applcBeDt><applcEnDt>2023-09-28</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>889</buldMgtNo2><buldNm>(주)KT 은평지사</buldNm><buldPrpos>업무시설-기타</buldPrpos><divGroundFloorCnt>4</divGroundFloorCnt><divUndgrndFloorCnt>1</divUndgrndFloorCnt><elevatorNo>0042569</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>장애인용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>1760</elvtrMgtNo2><elvtrModel>Di1</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>2005-08-24</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>2005-08-24</installationDe><installationPlace>1-1</installationPlace><lastInspctDe>2022-10-11</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>합격</lastResultNm><liveLoad>1150 KG</liveLoad><manufacturerName>오티스엘리베이터(유)창원공장</manufacturerName><manufacturerTelno>055-289-8235</manufacturerTelno><mnfcturCpnyCd>919990124</mnfcturCpnyCd><mntCpnyCd>919920075</mntCpnyCd><mntCpnyNm>오티스엘리베이터(유)서울</mntCpnyNm><mntCpnyTelno>02-2007-5800</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>김봉수(설비실장)</partcpntNm><partcpntTelno>010-3043-1***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>17 인승</ratedCap><ratedSpeed>1.5 M/MIN</ratedSpeed><shuttleFloorCnt>4</shuttleFloorCnt><shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>1-4</shuttleSection><sigunguCd>122</sigunguCd><standardKey>1</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>033</zipCd1><zipCd2>91</zipCd2></item>,
#  <address1>서울특별시 은평구 통일로71길 16</address1>,
#  <address2>(대조동)</address2>,
#  <applcBeDt>2022-09-29</applcBeDt>,
#  <applcEnDt>2023-09-28</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>889</buldMgtNo2>,
#  <buldNm>(주)KT 은평지사</buldNm>,
#  <buldPrpos>업무시설-기타</buldPrpos>,
#  <divGroundFloorCnt>4</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>1</divUndgrndFloorCnt>,
#  <elevatorNo>0042569</elevatorNo>,
#  <elvtrAsignNo>1</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
#  <elvtrKindNm>장애인용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>1760</elvtrMgtNo2>,
#  <elvtrModel>Di1</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>2005-08-24</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>2005-08-24</installationDe>,
#  <installationPlace>1-1</installationPlace>,
#  <lastInspctDe>2022-10-11</lastInspctDe>,
#  <lastInspctKind>정기</lastInspctKind>,
#  <lastResultNm>합격</lastResultNm>,
#  <liveLoad>1150 KG</liveLoad>,
#  <manufacturerName>오티스엘리베이터(유)창원공장</manufacturerName>,
#  <manufacturerTelno>055-289-8235</manufacturerTelno>,
#  <mnfcturCpnyCd>919990124</mnfcturCpnyCd>,
#  <mntCpnyCd>919920075</mntCpnyCd>,
#  <mntCpnyNm>오티스엘리베이터(유)서울</mntCpnyNm>,
#  <mntCpnyTelno>02-2007-5800</mntCpnyTelno>,
#  <mrYn>Y</mrYn>,
#  <partcpntNm>김봉수(설비실장)</partcpntNm>,
#  <partcpntTelno>010-3043-1***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>17 인승</ratedCap>,
#  <ratedSpeed>1.5 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>4</shuttleFloorCnt>,
#  <shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>1-4</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>1</standardKey>,
#  <subcntrCpny>-</subcntrCpny>,
#  <zipCd1>033</zipCd1>,
#  <zipCd2>91</zipCd2>,
#  <item><address1>서울특별시 은평구 통일로71길 16</address1><address2>(대조동)</address2><applcBeDt>2022-09-29</applcBeDt><applcEnDt>2023-09-28</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>889</buldMgtNo2><buldNm>(주)KT 은평지사</buldNm><buldPrpos>업무시설-기타</buldPrpos><divGroundFloorCnt>4</divGroundFloorCnt><divUndgrndFloorCnt>1</divUndgrndFloorCnt><elevatorNo>0042570</elevatorNo><elvtrAsignNo>2</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>장애인용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>1881</elvtrMgtNo2><elvtrModel>Di1</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>2006-10-24</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>2006-10-24</installationDe><installationPlace>1-2</installationPlace><lastInspctDe>2022-10-11</lastInspctDe><lastInspctKind>정밀</lastInspctKind><lastResultNm>조건부합격</lastResultNm><liveLoad>1150 KG</liveLoad><manufacturerName>오티스엘리베이터(유)창원공장</manufacturerName><manufacturerTelno>055-289-8235</manufacturerTelno><mnfcturCpnyCd>919990124</mnfcturCpnyCd><mntCpnyCd>919920075</mntCpnyCd><mntCpnyNm>오티스엘리베이터(유)서울</mntCpnyNm><mntCpnyTelno>02-2007-5800</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>김봉수(설비실장)</partcpntNm><partcpntTelno>010-3043-1***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>17 인승</ratedCap><ratedSpeed>1.5 M/MIN</ratedSpeed><shuttleFloorCnt>5</shuttleFloorCnt><shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>B1-4</shuttleSection><sigunguCd>122</sigunguCd><standardKey>1</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>033</zipCd1><zipCd2>91</zipCd2></item>,
#  <address1>서울특별시 은평구 통일로71길 16</address1>,
#  <address2>(대조동)</address2>,
#  <applcBeDt>2022-09-29</applcBeDt>,
#  <applcEnDt>2023-09-28</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>889</buldMgtNo2>,
#  <buldNm>(주)KT 은평지사</buldNm>,
#  <buldPrpos>업무시설-기타</buldPrpos>,
#  <divGroundFloorCnt>4</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>1</divUndgrndFloorCnt>,
#  <elevatorNo>0042570</elevatorNo>,
#  <elvtrAsignNo>2</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
#  <elvtrKindNm>장애인용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>1881</elvtrMgtNo2>,
#  <elvtrModel>Di1</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>2006-10-24</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>2006-10-24</installationDe>,
#  <installationPlace>1-2</installationPlace>,
#  <lastInspctDe>2022-10-11</lastInspctDe>,
#  <lastInspctKind>정밀</lastInspctKind>,
#  <lastResultNm>조건부합격</lastResultNm>,
#  <liveLoad>1150 KG</liveLoad>,
#  <manufacturerName>오티스엘리베이터(유)창원공장</manufacturerName>,
#  <manufacturerTelno>055-289-8235</manufacturerTelno>,
#  <mnfcturCpnyCd>919990124</mnfcturCpnyCd>,
#  <mntCpnyCd>919920075</mntCpnyCd>,
#  <mntCpnyNm>오티스엘리베이터(유)서울</mntCpnyNm>,
#  <mntCpnyTelno>02-2007-5800</mntCpnyTelno>,
#  <mrYn>Y</mrYn>,
#  <partcpntNm>김봉수(설비실장)</partcpntNm>,
#  <partcpntTelno>010-3043-1***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>17 인승</ratedCap>,
#  <ratedSpeed>1.5 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>5</shuttleFloorCnt>,
#  <shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>B1-4</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>1</standardKey>,
#  <subcntrCpny>-</subcntrCpny>,
#  <zipCd1>033</zipCd1>,
#  <zipCd2>91</zipCd2>,
#  <item><address1>서울특별시 은평구 은평로13길 12-1</address1><address2>해명빌딩 (녹번동)</address2><applcBeDt>2022-04-14</applcBeDt><applcEnDt>2022-10-13</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>43</buldMgtNo2><buldNm>(주)녹번해명(해명빌딩)</buldNm><buldPrpos>제2종근린생활시설-기타</buldPrpos><divGroundFloorCnt>5</divGroundFloorCnt><divUndgrndFloorCnt>1</divUndgrndFloorCnt><elevatorNo>0104893</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>승객용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>138</elvtrMgtNo2><elvtrModel>확인불가</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>1991-06-10</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>1991-06-10</installationDe><installationPlace>1-1</installationPlace><lastInspctDe>2022-11-03</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>조건부합격</lastResultNm><liveLoad>1150 KG</liveLoad><manufacturerName>현대엘리베이터(주)</manufacturerName><manufacturerTelno>043-722-1000</manufacturerTelno><mnfcturCpnyCd>919920035</mnfcturCpnyCd><mntCpnyCd>919990073</mntCpnyCd><mntCpnyNm>명성엘리베이터(주)</mntCpnyNm><mntCpnyTelno>02-2616-2404</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>관리소장 (민정훈)</partcpntNm><partcpntTelno>(02)388-1***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>17 인승</ratedCap><ratedSpeed>1 M/MIN</ratedSpeed><shuttleFloorCnt>6</shuttleFloorCnt><shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>B1-5</shuttleSection><sigunguCd>122</sigunguCd><standardKey>8</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>034</zipCd1><zipCd2>59</zipCd2></item>,
#  <address1>서울특별시 은평구 은평로13길 12-1</address1>,
#  <address2>해명빌딩 (녹번동)</address2>,
#  <applcBeDt>2022-04-14</applcBeDt>,
#  <applcEnDt>2022-10-13</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>43</buldMgtNo2>,
#  <buldNm>(주)녹번해명(해명빌딩)</buldNm>,
#  <buldPrpos>제2종근린생활시설-기타</buldPrpos>,
#  <divGroundFloorCnt>5</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>1</divUndgrndFloorCnt>,
#  <elevatorNo>0104893</elevatorNo>,
#  <elvtrAsignNo>1</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
#  <elvtrKindNm>승객용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>138</elvtrMgtNo2>,
#  <elvtrModel>확인불가</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>1991-06-10</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>1991-06-10</installationDe>,
#  <installationPlace>1-1</installationPlace>,
#  <lastInspctDe>2022-11-03</lastInspctDe>,
#  <lastInspctKind>정기</lastInspctKind>,
#  <lastResultNm>조건부합격</lastResultNm>,
#  <liveLoad>1150 KG</liveLoad>,
#  <manufacturerName>현대엘리베이터(주)</manufacturerName>,
#  <manufacturerTelno>043-722-1000</manufacturerTelno>,
#  <mnfcturCpnyCd>919920035</mnfcturCpnyCd>,
#  <mntCpnyCd>919990073</mntCpnyCd>,
#  <mntCpnyNm>명성엘리베이터(주)</mntCpnyNm>,
#  <mntCpnyTelno>02-2616-2404</mntCpnyTelno>,
#  <mrYn>Y</mrYn>,
#  <partcpntNm>관리소장 (민정훈)</partcpntNm>,
#  <partcpntTelno>(02)388-1***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>17 인승</ratedCap>,
#  <ratedSpeed>1 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>6</shuttleFloorCnt>,
#  <shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>B1-5</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>8</standardKey>,
#  <subcntrCpny>-</subcntrCpny>,
#  <zipCd1>034</zipCd1>,
#  <zipCd2>59</zipCd2>,
#  <item><address1>서울특별시 은평구 은평로13길 12-1</address1><address2>해명빌딩 (녹번동)</address2><applcBeDt>2022-03-27</applcBeDt><applcEnDt>2022-09-26</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>43</buldMgtNo2><buldNm>(주)녹번해명(해명빌딩)</buldNm><buldPrpos>제2종근린생활시설-기타</buldPrpos><divGroundFloorCnt>5</divGroundFloorCnt><divUndgrndFloorCnt>1</divUndgrndFloorCnt><elevatorNo>0004213</elevatorNo><elvtrAsignNo>2</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>유압식-교류</elvtrFormNm><elvtrKindNm>자동차용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>139</elvtrMgtNo2><elvtrModel>확인불가</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>1991-06-10</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>1991-06-10</installationDe><installationPlace>1-2</installationPlace><lastInspctDe>2022-11-03</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>조건부합격</lastResultNm><liveLoad>2000 KG</liveLoad><manufacturerName>영진엘리베이터(주)</manufacturerName><manufacturerTelno>032-815-7871</manufacturerTelno><mnfcturCpnyCd>919930210</mnfcturCpnyCd><mntCpnyCd>919990073</mntCpnyCd><mntCpnyNm>명성엘리베이터(주)</mntCpnyNm><mntCpnyTelno>02-2616-2404</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>관리소장 (민정훈)</partcpntNm><partcpntTelno>(02)388-1***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>0 인승</ratedCap><ratedSpeed>.33 M/MIN</ratedSpeed><shuttleFloorCnt>2</shuttleFloorCnt><shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>B1-1</shuttleSection><sigunguCd>122</sigunguCd><standardKey>8</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>034</zipCd1><zipCd2>59</zipCd2></item>,
#  <address1>서울특별시 은평구 은평로13길 12-1</address1>,
#  <address2>해명빌딩 (녹번동)</address2>,
#  <applcBeDt>2022-03-27</applcBeDt>,
#  <applcEnDt>2022-09-26</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>43</buldMgtNo2>,
#  <buldNm>(주)녹번해명(해명빌딩)</buldNm>,
#  <buldPrpos>제2종근린생활시설-기타</buldPrpos>,
#  <divGroundFloorCnt>5</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>1</divUndgrndFloorCnt>,
#  <elevatorNo>0004213</elevatorNo>,
#  <elvtrAsignNo>2</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>유압식-교류</elvtrFormNm>,
#  <elvtrKindNm>자동차용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>139</elvtrMgtNo2>,
#  <elvtrModel>확인불가</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>1991-06-10</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>1991-06-10</installationDe>,
#  <installationPlace>1-2</installationPlace>,
#  <lastInspctDe>2022-11-03</lastInspctDe>,
#  <lastInspctKind>정기</lastInspctKind>,
#  <lastResultNm>조건부합격</lastResultNm>,
#  <liveLoad>2000 KG</liveLoad>,
#  <manufacturerName>영진엘리베이터(주)</manufacturerName>,
#  <manufacturerTelno>032-815-7871</manufacturerTelno>,
#  <mnfcturCpnyCd>919930210</mnfcturCpnyCd>,
#  <mntCpnyCd>919990073</mntCpnyCd>,
#  <mntCpnyNm>명성엘리베이터(주)</mntCpnyNm>,
#  <mntCpnyTelno>02-2616-2404</mntCpnyTelno>,
#  <mrYn>Y</mrYn>,
#  <partcpntNm>관리소장 (민정훈)</partcpntNm>,
#  <partcpntTelno>(02)388-1***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>0 인승</ratedCap>,
#  <ratedSpeed>.33 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>2</shuttleFloorCnt>,
#  <shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>B1-1</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>8</standardKey>,
#  <subcntrCpny>-</subcntrCpny>,
#  <zipCd1>034</zipCd1>,
#  <zipCd2>59</zipCd2>,
#  <item><address1>서울특별시 은평구 응암로 165</address1><address2>(응암동)</address2><applcBeDt>2022-08-09</applcBeDt><applcEnDt>2023-08-08</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>2669</buldMgtNo2><buldNm>(주)사과마을</buldNm><buldPrpos>판매시설-기타</buldPrpos><divGroundFloorCnt>2</divGroundFloorCnt><divUndgrndFloorCnt>0</divUndgrndFloorCnt><elevatorNo>0120103</elevatorNo><elvtrAsignNo>2</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>장애인용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>5517</elvtrMgtNo2><elvtrModel>WBSS2</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>2016-12-23</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>2016-12-23</installationDe><installationPlace>1-2</installationPlace><lastInspctDe>2022-09-06</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>조건후합격</lastResultNm><liveLoad>1600 KG</liveLoad><manufacturerName>현대엘리베이터(주)</manufacturerName><manufacturerTelno>043-722-1000</manufacturerTelno><mnfcturCpnyCd>919920035</mnfcturCpnyCd><mntCpnyCd>919930409</mntCpnyCd><mntCpnyNm>현대엘리베이터(주)서울사무소</mntCpnyNm><mntCpnyTelno>1577-0603</mntCpnyTelno><mrYn>N</mrYn><partcpntNm>조승현(승강기담당)</partcpntNm><partcpntTelno>02-308-1***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>24 인승</ratedCap><ratedSpeed>1 M/MIN</ratedSpeed><shuttleFloorCnt>2</shuttleFloorCnt><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>1-2</shuttleSection><sigunguCd>122</sigunguCd><standardKey>3</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>034</zipCd1><zipCd2>85</zipCd2></item>,
#  <address1>서울특별시 은평구 응암로 165</address1>,
#  <address2>(응암동)</address2>,
#  <applcBeDt>2022-08-09</applcBeDt>,
#  <applcEnDt>2023-08-08</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>2669</buldMgtNo2>,
#  <buldNm>(주)사과마을</buldNm>,
#  <buldPrpos>판매시설-기타</buldPrpos>,
#  <divGroundFloorCnt>2</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>0</divUndgrndFloorCnt>,
#  <elevatorNo>0120103</elevatorNo>,
#  <elvtrAsignNo>2</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
#  <elvtrKindNm>장애인용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>5517</elvtrMgtNo2>,
#  <elvtrModel>WBSS2</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>2016-12-23</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>2016-12-23</installationDe>,
#  <installationPlace>1-2</installationPlace>,
#  <lastInspctDe>2022-09-06</lastInspctDe>,
#  <lastInspctKind>정기</lastInspctKind>,
#  <lastResultNm>조건후합격</lastResultNm>,
#  <liveLoad>1600 KG</liveLoad>,
#  <manufacturerName>현대엘리베이터(주)</manufacturerName>,
#  <manufacturerTelno>043-722-1000</manufacturerTelno>,
#  <mnfcturCpnyCd>919920035</mnfcturCpnyCd>,
#  <mntCpnyCd>919930409</mntCpnyCd>,
#  <mntCpnyNm>현대엘리베이터(주)서울사무소</mntCpnyNm>,
#  <mntCpnyTelno>1577-0603</mntCpnyTelno>,
#  <mrYn>N</mrYn>,
#  <partcpntNm>조승현(승강기담당)</partcpntNm>,
#  <partcpntTelno>02-308-1***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>24 인승</ratedCap>,
#  <ratedSpeed>1 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>2</shuttleFloorCnt>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>1-2</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>3</standardKey>,
#  <subcntrCpny>-</subcntrCpny>,
#  <zipCd1>034</zipCd1>,
#  <zipCd2>85</zipCd2>,
#  <item><address1>서울특별시 은평구 통일로 874</address1><address2>(불광동)</address2><applcBeDt>2021-08-25</applcBeDt><applcEnDt>2022-08-24</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>779</buldMgtNo2><buldNm>(주)연신개발(연신빌딩)</buldNm><buldPrpos>제1종근린생활시설-기타</buldPrpos><divGroundFloorCnt>8</divGroundFloorCnt><divUndgrndFloorCnt>0</divUndgrndFloorCnt><elevatorNo>0068472</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>승객용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>1513</elvtrMgtNo2><elvtrModel>Di1</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>2004-08-25</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>2004-08-25</installationDe><installationPlace>1-1</installationPlace><lastInspctDe>2021-10-18</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>합격</lastResultNm><liveLoad>750 KG</liveLoad><manufacturerName>오티스엘리베이터(유)창원공장</manufacturerName><manufacturerTelno>055-289-8235</manufacturerTelno><mnfcturCpnyCd>919990124</mnfcturCpnyCd><mntCpnyCd>919920075</mntCpnyCd><mntCpnyNm>오티스엘리베이터(유)서울</mntCpnyNm><mntCpnyTelno>02-2007-5800</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>이성혁</partcpntNm><partcpntTelno>02-355-3***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>11 인승</ratedCap><ratedSpeed>1 M/MIN</ratedSpeed><shuttleFloorCnt>8</shuttleFloorCnt><shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>1-8</shuttleSection><sigunguCd>122</sigunguCd><standardKey>1</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>033</zipCd1><zipCd2>44</zipCd2></item>,
#  <address1>서울특별시 은평구 통일로 874</address1>,
#  <address2>(불광동)</address2>,
#  <applcBeDt>2021-08-25</applcBeDt>,
#  <applcEnDt>2022-08-24</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>779</buldMgtNo2>,
#  <buldNm>(주)연신개발(연신빌딩)</buldNm>,
#  <buldPrpos>제1종근린생활시설-기타</buldPrpos>,
#  <divGroundFloorCnt>8</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>0</divUndgrndFloorCnt>,
#  <elevatorNo>0068472</elevatorNo>,
#  <elvtrAsignNo>1</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
#  <elvtrKindNm>승객용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>1513</elvtrMgtNo2>,
#  <elvtrModel>Di1</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>2004-08-25</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>2004-08-25</installationDe>,
#  <installationPlace>1-1</installationPlace>,
#  <lastInspctDe>2021-10-18</lastInspctDe>,
#  <lastInspctKind>정기</lastInspctKind>,
#  <lastResultNm>합격</lastResultNm>,
#  <liveLoad>750 KG</liveLoad>,
#  <manufacturerName>오티스엘리베이터(유)창원공장</manufacturerName>,
#  <manufacturerTelno>055-289-8235</manufacturerTelno>,
#  <mnfcturCpnyCd>919990124</mnfcturCpnyCd>,
#  <mntCpnyCd>919920075</mntCpnyCd>,
#  <mntCpnyNm>오티스엘리베이터(유)서울</mntCpnyNm>,
#  <mntCpnyTelno>02-2007-5800</mntCpnyTelno>,
#  <mrYn>Y</mrYn>,
#  <partcpntNm>이성혁</partcpntNm>,
#  <partcpntTelno>02-355-3***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>11 인승</ratedCap>,
#  <ratedSpeed>1 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>8</shuttleFloorCnt>,
#  <shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>1-8</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>1</standardKey>,
#  <subcntrCpny>-</subcntrCpny>,
#  <zipCd1>033</zipCd1>,
#  <zipCd2>44</zipCd2>,
#  <item><address1>서울특별시 은평구 통일로66길 6-10</address1><address2>(불광동)</address2><applcBeDt>2021-11-12</applcBeDt><applcEnDt>2022-11-11</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>1487</buldMgtNo2><buldNm>115하우스</buldNm><buldPrpos>공동주택-분양</buldPrpos><divGroundFloorCnt>9</divGroundFloorCnt><divUndgrndFloorCnt>0</divUndgrndFloorCnt><elevatorNo>0083623</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>승객용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>3730</elvtrMgtNo2><elvtrModel>GR1</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>2011-10-18</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>2011-10-18</installationDe><installationPlace>1-1</installationPlace><lastInspctDe>2022-02-11</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>합격</lastResultNm><liveLoad>550 KG</liveLoad><manufacturerName>오티스엘리베이터(유)서울</manufacturerName><manufacturerTelno>02-2007-5800</manufacturerTelno><mnfcturCpnyCd>919920075</mnfcturCpnyCd><mntCpnyCd>919920075</mntCpnyCd><mntCpnyNm>오티스엘리베이터(유)서울</mntCpnyNm><mntCpnyTelno>02-2007-5800</mntCpnyTelno><mrYn>N</mrYn><partcpntNm>승강기 담당자</partcpntNm><partcpntTelno>010-3844-6***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>8 인승</ratedCap><ratedSpeed>1 M/MIN</ratedSpeed><shuttleFloorCnt>9</shuttleFloorCnt><shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>1-9</shuttleSection><sigunguCd>122</sigunguCd><standardKey>3</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>033</zipCd1><zipCd2>68</zipCd2></item>,
#  <address1>서울특별시 은평구 통일로66길 6-10</address1>,
#  <address2>(불광동)</address2>,
#  <applcBeDt>2021-11-12</applcBeDt>,
#  <applcEnDt>2022-11-11</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>1487</buldMgtNo2>,
#  <buldNm>115하우스</buldNm>,
#  <buldPrpos>공동주택-분양</buldPrpos>,
#  <divGroundFloorCnt>9</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>0</divUndgrndFloorCnt>,
#  <elevatorNo>0083623</elevatorNo>,
#  <elvtrAsignNo>1</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
#  <elvtrKindNm>승객용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>3730</elvtrMgtNo2>,
#  <elvtrModel>GR1</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>2011-10-18</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>2011-10-18</installationDe>,
#  <installationPlace>1-1</installationPlace>,
#  <lastInspctDe>2022-02-11</lastInspctDe>,
#  <lastInspctKind>정기</lastInspctKind>,
#  <lastResultNm>합격</lastResultNm>,
#  <liveLoad>550 KG</liveLoad>,
#  <manufacturerName>오티스엘리베이터(유)서울</manufacturerName>,
#  <manufacturerTelno>02-2007-5800</manufacturerTelno>,
#  <mnfcturCpnyCd>919920075</mnfcturCpnyCd>,
#  <mntCpnyCd>919920075</mntCpnyCd>,
#  <mntCpnyNm>오티스엘리베이터(유)서울</mntCpnyNm>,
#  <mntCpnyTelno>02-2007-5800</mntCpnyTelno>,
#  <mrYn>N</mrYn>,
#  <partcpntNm>승강기 담당자</partcpntNm>,
#  <partcpntTelno>010-3844-6***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>8 인승</ratedCap>,
#  <ratedSpeed>1 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>9</shuttleFloorCnt>,
#  <shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>1-9</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>3</standardKey>,
#  <subcntrCpny>-</subcntrCpny>,
#  <zipCd1>033</zipCd1>,
#  <zipCd2>68</zipCd2>,
#  <item><address1>서울특별시 은평구 은평로 210</address1><address2>(응암동)</address2><applcBeDt>2022-05-24</applcBeDt><applcEnDt>2023-05-23</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>12</buldMgtNo2><buldNm>A.G.M빌딩</buldNm><buldPrpos>제2종근린생활시설-기타</buldPrpos><divGroundFloorCnt>5</divGroundFloorCnt><divUndgrndFloorCnt>0</divUndgrndFloorCnt><elevatorNo>0004227</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>승객용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>223</elvtrMgtNo2><elvtrModel>WBLX-GX-2(M)</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>1989-06-01</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>2021-05-24</installationDe><installationPlace>1-1</installationPlace><lastInspctDe>2022-08-16</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>합격</lastResultNm><liveLoad>550 KG</liveLoad><manufacturerName>현대엘리베이터(주)</manufacturerName><manufacturerTelno>043-722-1000</manufacturerTelno><mnfcturCpnyCd>919920035</mnfcturCpnyCd><mntCpnyCd>919990085</mntCpnyCd><mntCpnyNm>대한주차관리(주)</mntCpnyNm><mntCpnyTelno>02-852-4417</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>승강기담당 (양찬영)</partcpntNm><partcpntTelno>010-3283-9***</partcpntTelno><pauseAblDe>-</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>7 인승</ratedCap><ratedSpeed>1 M/MIN</ratedSpeed><shuttleFloorCnt>5</shuttleFloorCnt><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>1-5</shuttleSection><sigunguCd>122</sigunguCd><standardKey>3</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>034</zipCd1><zipCd2>72</zipCd2></item>,
#  <address1>서울특별시 은평구 은평로 210</address1>,
#  <address2>(응암동)</address2>,
#  <applcBeDt>2022-05-24</applcBeDt>,
#  <applcEnDt>2023-05-23</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>12</buldMgtNo2>,
#  <buldNm>A.G.M빌딩</buldNm>,
#  <buldPrpos>제2종근린생활시설-기타</buldPrpos>,
#  <divGroundFloorCnt>5</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>0</divUndgrndFloorCnt>,
#  <elevatorNo>0004227</elevatorNo>,
#  <elvtrAsignNo>1</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
#  <elvtrKindNm>승객용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>223</elvtrMgtNo2>,
#  <elvtrModel>WBLX-GX-2(M)</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>1989-06-01</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>2021-05-24</installationDe>,
#  <installationPlace>1-1</installationPlace>,
#  <lastInspctDe>2022-08-16</lastInspctDe>,
#  <lastInspctKind>정기</lastInspctKind>,
#  <lastResultNm>합격</lastResultNm>,
#  <liveLoad>550 KG</liveLoad>,
#  <manufacturerName>현대엘리베이터(주)</manufacturerName>,
#  <manufacturerTelno>043-722-1000</manufacturerTelno>,
#  <mnfcturCpnyCd>919920035</mnfcturCpnyCd>,
#  <mntCpnyCd>919990085</mntCpnyCd>,
#  <mntCpnyNm>대한주차관리(주)</mntCpnyNm>,
#  <mntCpnyTelno>02-852-4417</mntCpnyTelno>,
#  <mrYn>Y</mrYn>,
#  <partcpntNm>승강기담당 (양찬영)</partcpntNm>,
#  <partcpntTelno>010-3283-9***</partcpntTelno>,
#  <pauseAblDe>-</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>7 인승</ratedCap>,
#  <ratedSpeed>1 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>5</shuttleFloorCnt>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>1-5</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>3</standardKey>,
#  <subcntrCpny>-</subcntrCpny>,
#  <zipCd1>034</zipCd1>,
#  <zipCd2>72</zipCd2>,
#  <item><address1>서울특별시 은평구 은평로 210</address1><address2>(응암동)</address2><applcBeDt>2022-07-19</applcBeDt><applcEnDt>2023-01-18</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>12</buldMgtNo2><buldNm>A.G.M빌딩</buldNm><buldPrpos>제2종근린생활시설-기타</buldPrpos><divGroundFloorCnt>1</divGroundFloorCnt><divUndgrndFloorCnt>1</divUndgrndFloorCnt><elevatorNo>0103615</elevatorNo><elvtrAsignNo>2</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>유압식-교류</elvtrFormNm><elvtrKindNm>자동차용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>224</elvtrMgtNo2><elvtrModel>확인불가</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>1989-06-01</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>1989-06-01</installationDe><installationPlace>1-2</installationPlace><lastInspctDe>2022-08-16</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>조건부합격</lastResultNm><liveLoad>2000 KG</liveLoad><manufacturerName>기타(KTL)</manufacturerName><mnfcturCpnyCd>999999900</mnfcturCpnyCd><mntCpnyCd>919990085</mntCpnyCd><mntCpnyNm>대한주차관리(주)</mntCpnyNm><mntCpnyTelno>02-852-4417</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>승강기담당 (양찬영)</partcpntNm><partcpntTelno>010-3283-9***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedSpeed>.33 M/MIN</ratedSpeed><shuttleFloorCnt>2</shuttleFloorCnt><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>B1-1</shuttleSection><sigunguCd>122</sigunguCd><standardKey>20</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>034</zipCd1><zipCd2>72</zipCd2></item>,
#  <address1>서울특별시 은평구 은평로 210</address1>,
#  <address2>(응암동)</address2>,
#  <applcBeDt>2022-07-19</applcBeDt>,
#  <applcEnDt>2023-01-18</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>12</buldMgtNo2>,
#  <buldNm>A.G.M빌딩</buldNm>,
#  <buldPrpos>제2종근린생활시설-기타</buldPrpos>,
#  <divGroundFloorCnt>1</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>1</divUndgrndFloorCnt>,
#  <elevatorNo>0103615</elevatorNo>,
#  <elvtrAsignNo>2</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>유압식-교류</elvtrFormNm>,
#  <elvtrKindNm>자동차용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>224</elvtrMgtNo2>,
#  <elvtrModel>확인불가</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>1989-06-01</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>1989-06-01</installationDe>,
#  <installationPlace>1-2</installationPlace>,
#  <lastInspctDe>2022-08-16</lastInspctDe>,
#  <lastInspctKind>정기</lastInspctKind>,
#  <lastResultNm>조건부합격</lastResultNm>,
#  <liveLoad>2000 KG</liveLoad>,
#  <manufacturerName>기타(KTL)</manufacturerName>,
#  <mnfcturCpnyCd>999999900</mnfcturCpnyCd>,
#  <mntCpnyCd>919990085</mntCpnyCd>,
#  <mntCpnyNm>대한주차관리(주)</mntCpnyNm>,
#  <mntCpnyTelno>02-852-4417</mntCpnyTelno>,
#  <mrYn>Y</mrYn>,
#  <partcpntNm>승강기담당 (양찬영)</partcpntNm>,
#  <partcpntTelno>010-3283-9***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedSpeed>.33 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>2</shuttleFloorCnt>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>B1-1</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>20</standardKey>,
#  <subcntrCpny>-</subcntrCpny>,
#  <zipCd1>034</zipCd1>,
#  <zipCd2>72</zipCd2>,
#  <item><address1>서울특별시 은평구 통일로87길 14</address1><address2>(갈현동)</address2><applcBeDt>2022-02-26</applcBeDt><applcEnDt>2023-02-25</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>471</buldMgtNo2><buldNm>A1빌딩</buldNm><buldPrpos>제2종근린생활시설-기타</buldPrpos><divGroundFloorCnt>5</divGroundFloorCnt><divUndgrndFloorCnt>0</divUndgrndFloorCnt><elevatorNo>0041811</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>승객용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>1953</elvtrMgtNo2><elvtrModel>Di1</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>2002-10-19</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>2007-06-07</installationDe><installationPlace>1-1</installationPlace><lastInspctDe>2022-07-12</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>합격</lastResultNm><liveLoad>750 KG</liveLoad><manufacturerName>오티스엘리베이터(유)서울</manufacturerName><manufacturerTelno>02-2007-5800</manufacturerTelno><mnfcturCpnyCd>919920075</mnfcturCpnyCd><mntCpnyCd>919920075</mntCpnyCd><mntCpnyNm>오티스엘리베이터(유)서울</mntCpnyNm><mntCpnyTelno>02-2007-5800</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>장승기</partcpntNm><partcpntTelno>010-6517-3***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>11 인승</ratedCap><ratedSpeed>1 M/MIN</ratedSpeed><shuttleFloorCnt>5</shuttleFloorCnt><shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>1-5</shuttleSection><sigunguCd>122</sigunguCd><standardKey>1</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>033</zipCd1><zipCd2>28</zipCd2></item>,
#  <address1>서울특별시 은평구 통일로87길 14</address1>,
#  <address2>(갈현동)</address2>,
#  <applcBeDt>2022-02-26</applcBeDt>,
#  <applcEnDt>2023-02-25</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>471</buldMgtNo2>,
#  <buldNm>A1빌딩</buldNm>,
#  <buldPrpos>제2종근린생활시설-기타</buldPrpos>,
#  <divGroundFloorCnt>5</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>0</divUndgrndFloorCnt>,
#  <elevatorNo>0041811</elevatorNo>,
#  <elvtrAsignNo>1</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
#  <elvtrKindNm>승객용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>1953</elvtrMgtNo2>,
#  <elvtrModel>Di1</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>2002-10-19</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>2007-06-07</installationDe>,
#  <installationPlace>1-1</installationPlace>,
#  <lastInspctDe>2022-07-12</lastInspctDe>,
#  <lastInspctKind>정기</lastInspctKind>,
#  <lastResultNm>합격</lastResultNm>,
#  <liveLoad>750 KG</liveLoad>,
#  <manufacturerName>오티스엘리베이터(유)서울</manufacturerName>,
#  <manufacturerTelno>02-2007-5800</manufacturerTelno>,
#  <mnfcturCpnyCd>919920075</mnfcturCpnyCd>,
#  <mntCpnyCd>919920075</mntCpnyCd>,
#  <mntCpnyNm>오티스엘리베이터(유)서울</mntCpnyNm>,
#  <mntCpnyTelno>02-2007-5800</mntCpnyTelno>,
#  <mrYn>Y</mrYn>,
#  <partcpntNm>장승기</partcpntNm>,
#  <partcpntTelno>010-6517-3***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>11 인승</ratedCap>,
#  <ratedSpeed>1 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>5</shuttleFloorCnt>,
#  <shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>1-5</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>1</standardKey>,
#  <subcntrCpny>-</subcntrCpny>,
#  <zipCd1>033</zipCd1>,
#  <zipCd2>28</zipCd2>,
#  <item><address1>서울특별시 은평구 통일로 585-1</address1><address2>(응암동)</address2><applcBeDt>2022-06-30</applcBeDt><applcEnDt>2023-06-29</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>1919</buldMgtNo2><buldNm>AVENUE호텔</buldNm><buldPrpos>업무시설-기타</buldPrpos><divGroundFloorCnt>12</divGroundFloorCnt><divUndgrndFloorCnt>0</divUndgrndFloorCnt><elevatorNo>0105742</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>장애인용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>4315</elvtrMgtNo2><elvtrModel>WBST1</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>2014-06-30</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>2014-06-30</installationDe><installationPlace>1-1(좌)</installationPlace><lastInspctDe>2022-09-28</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>조건부합격</lastResultNm><liveLoad>900 KG</liveLoad><manufacturerName>현대엘리베이터(주)</manufacturerName><manufacturerTelno>043-722-1000</manufacturerTelno><mnfcturCpnyCd>919920035</mnfcturCpnyCd><mntCpnyCd>919930409</mntCpnyCd><mntCpnyNm>현대엘리베이터(주)서울사무소</mntCpnyNm><mntCpnyTelno>1577-0603</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>박종천</partcpntNm><partcpntTelno>02)350-6***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>13 인승</ratedCap><ratedSpeed>1.5 M/MIN</ratedSpeed><shuttleFloorCnt>12</shuttleFloorCnt><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>1-12</shuttleSection><sigunguCd>122</sigunguCd><standardKey>3</standardKey><subcntrCpny>정우엘리베이터(주)</subcntrCpny><zipCd1>034</zipCd1><zipCd2>73</zipCd2></item>,
#  <address1>서울특별시 은평구 통일로 585-1</address1>,
#  <address2>(응암동)</address2>,
#  <applcBeDt>2022-06-30</applcBeDt>,
#  <applcEnDt>2023-06-29</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>1919</buldMgtNo2>,
#  <buldNm>AVENUE호텔</buldNm>,
#  <buldPrpos>업무시설-기타</buldPrpos>,
#  <divGroundFloorCnt>12</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>0</divUndgrndFloorCnt>,
#  <elevatorNo>0105742</elevatorNo>,
#  <elvtrAsignNo>1</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
#  <elvtrKindNm>장애인용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>4315</elvtrMgtNo2>,
#  <elvtrModel>WBST1</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>2014-06-30</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>2014-06-30</installationDe>,
#  <installationPlace>1-1(좌)</installationPlace>,
#  <lastInspctDe>2022-09-28</lastInspctDe>,
#  <lastInspctKind>정기</lastInspctKind>,
#  <lastResultNm>조건부합격</lastResultNm>,
#  <liveLoad>900 KG</liveLoad>,
#  <manufacturerName>현대엘리베이터(주)</manufacturerName>,
#  <manufacturerTelno>043-722-1000</manufacturerTelno>,
#  <mnfcturCpnyCd>919920035</mnfcturCpnyCd>,
#  <mntCpnyCd>919930409</mntCpnyCd>,
#  <mntCpnyNm>현대엘리베이터(주)서울사무소</mntCpnyNm>,
#  <mntCpnyTelno>1577-0603</mntCpnyTelno>,
#  <mrYn>Y</mrYn>,
#  <partcpntNm>박종천</partcpntNm>,
#  <partcpntTelno>02)350-6***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>13 인승</ratedCap>,
#  <ratedSpeed>1.5 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>12</shuttleFloorCnt>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>1-12</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>3</standardKey>,
#  <subcntrCpny>정우엘리베이터(주)</subcntrCpny>,
#  <zipCd1>034</zipCd1>,
#  <zipCd2>73</zipCd2>,
#  <item><address1>서울특별시 은평구 통일로 585-1</address1><address2>(응암동)</address2><applcBeDt>2022-06-30</applcBeDt><applcEnDt>2023-06-29</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>1919</buldMgtNo2><buldNm>AVENUE호텔</buldNm><buldPrpos>업무시설-기타</buldPrpos><divGroundFloorCnt>12</divGroundFloorCnt><divUndgrndFloorCnt>0</divUndgrndFloorCnt><elevatorNo>0105743</elevatorNo><elvtrAsignNo>2</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>승객용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>4316</elvtrMgtNo2><elvtrModel>WBST1</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>2014-06-30</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>2014-06-30</installationDe><installationPlace>1-2(우)</installationPlace><lastInspctDe>2022-09-28</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>합격</lastResultNm><liveLoad>600 KG</liveLoad><manufacturerName>현대엘리베이터(주)</manufacturerName><manufacturerTelno>043-722-1000</manufacturerTelno><mnfcturCpnyCd>919920035</mnfcturCpnyCd><mntCpnyCd>919930409</mntCpnyCd><mntCpnyNm>현대엘리베이터(주)서울사무소</mntCpnyNm><mntCpnyTelno>1577-0603</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>박종천</partcpntNm><partcpntTelno>02)350-6***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>9 인승</ratedCap><ratedSpeed>1.5 M/MIN</ratedSpeed><shuttleFloorCnt>12</shuttleFloorCnt><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>1-12</shuttleSection><sigunguCd>122</sigunguCd><standardKey>3</standardKey><subcntrCpny>정우엘리베이터(주)</subcntrCpny><zipCd1>034</zipCd1><zipCd2>73</zipCd2></item>,
#  <address1>서울특별시 은평구 통일로 585-1</address1>,
#  <address2>(응암동)</address2>,
#  <applcBeDt>2022-06-30</applcBeDt>,
#  <applcEnDt>2023-06-29</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>1919</buldMgtNo2>,
#  <buldNm>AVENUE호텔</buldNm>,
#  <buldPrpos>업무시설-기타</buldPrpos>,
#  <divGroundFloorCnt>12</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>0</divUndgrndFloorCnt>,
#  <elevatorNo>0105743</elevatorNo>,
#  <elvtrAsignNo>2</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
#  <elvtrKindNm>승객용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>4316</elvtrMgtNo2>,
#  <elvtrModel>WBST1</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>2014-06-30</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>2014-06-30</installationDe>,
#  <installationPlace>1-2(우)</installationPlace>,
#  <lastInspctDe>2022-09-28</lastInspctDe>,
#  <lastInspctKind>정기</lastInspctKind>,
#  <lastResultNm>합격</lastResultNm>,
#  <liveLoad>600 KG</liveLoad>,
#  <manufacturerName>현대엘리베이터(주)</manufacturerName>,
#  <manufacturerTelno>043-722-1000</manufacturerTelno>,
#  <mnfcturCpnyCd>919920035</mnfcturCpnyCd>,
#  <mntCpnyCd>919930409</mntCpnyCd>,
#  <mntCpnyNm>현대엘리베이터(주)서울사무소</mntCpnyNm>,
#  <mntCpnyTelno>1577-0603</mntCpnyTelno>,
#  <mrYn>Y</mrYn>,
#  <partcpntNm>박종천</partcpntNm>,
#  <partcpntTelno>02)350-6***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>9 인승</ratedCap>,
#  <ratedSpeed>1.5 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>12</shuttleFloorCnt>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>1-12</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>3</standardKey>,
#  <subcntrCpny>정우엘리베이터(주)</subcntrCpny>,
#  <zipCd1>034</zipCd1>,
#  <zipCd2>73</zipCd2>,
#  <item><address1>서울특별시 은평구 은평로2길 6-18</address1><address2>(신사동)</address2><applcBeDt>2022-07-10</applcBeDt><applcEnDt>2023-07-09</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>1331</buldMgtNo2><buldNm>A플러스 빌</buldNm><buldPrpos>제2종근린생활시설-기타</buldPrpos><divGroundFloorCnt>7</divGroundFloorCnt><divUndgrndFloorCnt>0</divUndgrndFloorCnt><elevatorNo>0103174</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>승객용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>3367</elvtrMgtNo2><elvtrModel>STVF-7</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>2010-11-15</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>2010-11-15</installationDe><installationPlace>1-1</installationPlace><lastInspctDe>2022-10-11</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>합격</lastResultNm><liveLoad>600 KG</liveLoad><manufacturerName>현대엘리베이터(주)</manufacturerName><manufacturerTelno>043-722-1000</manufacturerTelno><mnfcturCpnyCd>919920035</mnfcturCpnyCd><mntCpnyCd>919930409</mntCpnyCd><mntCpnyNm>현대엘리베이터(주)서울사무소</mntCpnyNm><mntCpnyTelno>1577-0603</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>정윤수</partcpntNm><partcpntTelno>02-387-6***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>9 인승</ratedCap><ratedSpeed>1 M/MIN</ratedSpeed><shuttleFloorCnt>7</shuttleFloorCnt><shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>1-7</shuttleSection><sigunguCd>122</sigunguCd><standardKey>3</standardKey><subcntrCpny>정우엘리베이터(주)</subcntrCpny><zipCd1>034</zipCd1><zipCd2>50</zipCd2></item>,
#  <address1>서울특별시 은평구 은평로2길 6-18</address1>,
#  <address2>(신사동)</address2>,
#  <applcBeDt>2022-07-10</applcBeDt>,
#  <applcEnDt>2023-07-09</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>1331</buldMgtNo2>,
#  <buldNm>A플러스 빌</buldNm>,
#  <buldPrpos>제2종근린생활시설-기타</buldPrpos>,
#  <divGroundFloorCnt>7</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>0</divUndgrndFloorCnt>,
#  <elevatorNo>0103174</elevatorNo>,
#  <elvtrAsignNo>1</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
# ...
#  <address1>서울특별시 은평구 연서로 520</address1>,
#  <address2>(진관동)</address2>,
#  <applcBeDt>2021-11-27</applcBeDt>,
#  <applcEnDt>2022-11-26</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>3311</buldMgtNo2>,
#  <buldNm>BC빌딩</buldNm>,
#  <buldPrpos>제2종근린생활시설-기타</buldPrpos>,
#  <divGroundFloorCnt>6</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>0</divUndgrndFloorCnt>,
#  <elevatorNo>0138790</elevatorNo>,
#  <elvtrAsignNo>1</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
#  <elvtrKindNm>장애인용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>6750</elvtrMgtNo2>,
#  <elvtrModel>WBSS2</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>2019-11-27</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>2019-11-27</installationDe>,
#  <installationPlace>1-1</installationPlace>,
#  <lastInspctDe>2022-02-18</lastInspctDe>,
#  <lastInspctKind>정기</lastInspctKind>,
#  <lastResultNm>합격</lastResultNm>,
#  <liveLoad>1000 KG</liveLoad>,
#  <manufacturerName>현대엘리베이터(주)</manufacturerName>,
#  <manufacturerTelno>043-722-1000</manufacturerTelno>,
#  <mnfcturCpnyCd>919920035</mnfcturCpnyCd>,
#  <mntCpnyCd>920070053</mntCpnyCd>,
#  <mntCpnyNm>현대엘리베이터(주)서울</mntCpnyNm>,
#  <mntCpnyTelno>1577-0603</mntCpnyTelno>,
#  <mrYn>N</mrYn>,
#  <partcpntNm>김병창</partcpntNm>,
#  <partcpntTelno>010-8777-3***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>15 인승</ratedCap>,
#  <ratedSpeed>1 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>6</shuttleFloorCnt>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>1-6</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>3</standardKey>,
#  <subcntrCpny>-</subcntrCpny>,
#  <zipCd1>033</zipCd1>,
#  <zipCd2>08</zipCd2>,
#  <item><address1>서울특별시 은평구 연서로13길 29-6 (구산동)</address1><address2> </address2><applcBeDt>2022-08-18</applcBeDt><applcEnDt>2023-08-17</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>3540</buldMgtNo2><buldNm>BOMIN ASTRO</buldNm><buldPrpos>공동주택-분양</buldPrpos><divGroundFloorCnt>6</divGroundFloorCnt><divUndgrndFloorCnt>0</divUndgrndFloorCnt><elevatorNo>0150214</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>장애인용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>7142</elvtrMgtNo2><elvtrModel>K-NP-MRL-P1(M)</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>2021-06-17</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>2021-06-17</installationDe><installationPlace>1-1</installationPlace><lastInspctDe>2022-08-18</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>합격</lastResultNm><liveLoad>900 KG</liveLoad><manufacturerName>한국미쓰비시엘리베이터(주)(서울)</manufacturerName><manufacturerTelno>02-6670-2152</manufacturerTelno><mnfcturCpnyCd>920020007</mnfcturCpnyCd><mntCpnyCd>920180086</mntCpnyCd><mntCpnyNm>한국미쓰비시엘리베이터(주)강북1</mntCpnyNm><mntCpnyTelno>02-921-3114</mntCpnyTelno><mrYn>N</mrYn><partcpntNm>김형기</partcpntNm><partcpntTelno>***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>12 인승</ratedCap><ratedSpeed>1 M/MIN</ratedSpeed><shuttleFloorCnt>6</shuttleFloorCnt><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>1-6</shuttleSection><sigunguCd>122</sigunguCd><standardKey>3</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>034</zipCd1><zipCd2>14</zipCd2></item>,
#  <address1>서울특별시 은평구 연서로13길 29-6 (구산동)</address1>,
#  <address2> </address2>,
#  <applcBeDt>2022-08-18</applcBeDt>,
#  <applcEnDt>2023-08-17</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>3540</buldMgtNo2>,
#  <buldNm>BOMIN ASTRO</buldNm>,
#  <buldPrpos>공동주택-분양</buldPrpos>,
#  <divGroundFloorCnt>6</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>0</divUndgrndFloorCnt>,
#  <elevatorNo>0150214</elevatorNo>,
#  <elvtrAsignNo>1</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
#  <elvtrKindNm>장애인용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>7142</elvtrMgtNo2>,
#  <elvtrModel>K-NP-MRL-P1(M)</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>2021-06-17</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>2021-06-17</installationDe>,
#  <installationPlace>1-1</installationPlace>,
#  <lastInspctDe>2022-08-18</lastInspctDe>,
#  <lastInspctKind>정기</lastInspctKind>,
#  <lastResultNm>합격</lastResultNm>,
#  <liveLoad>900 KG</liveLoad>,
#  <manufacturerName>한국미쓰비시엘리베이터(주)(서울)</manufacturerName>,
#  <manufacturerTelno>02-6670-2152</manufacturerTelno>,
#  <mnfcturCpnyCd>920020007</mnfcturCpnyCd>,
#  <mntCpnyCd>920180086</mntCpnyCd>,
#  <mntCpnyNm>한국미쓰비시엘리베이터(주)강북1</mntCpnyNm>,
#  <mntCpnyTelno>02-921-3114</mntCpnyTelno>,
#  <mrYn>N</mrYn>,
#  <partcpntNm>김형기</partcpntNm>,
#  <partcpntTelno>***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>12 인승</ratedCap>,
#  <ratedSpeed>1 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>6</shuttleFloorCnt>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>1-6</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>3</standardKey>,
#  <subcntrCpny>-</subcntrCpny>,
#  <zipCd1>034</zipCd1>,
#  <zipCd2>14</zipCd2>,
#  <item><address1>서울특별시 은평구 통일로71길 6</address1><address2>(대조동)</address2><applcBeDt>2022-07-29</applcBeDt><applcEnDt>2023-07-28</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>2183</buldMgtNo2><buldNm>Babyjjam</buldNm><buldPrpos>제2종근린생활시설-기타</buldPrpos><divGroundFloorCnt>5</divGroundFloorCnt><divUndgrndFloorCnt>1</divUndgrndFloorCnt><elevatorNo>0074954</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>장애인용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>4708</elvtrMgtNo2><elvtrModel>TK-50CS</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>2015-07-29</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>2015-07-29</installationDe><installationPlace>1-1</installationPlace><lastInspctDe>2022-09-19</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>조건부합격</lastResultNm><liveLoad>1000 KG</liveLoad><manufacturerName>티케이엘리베이터코리아(주)</manufacturerName><manufacturerTelno>02-2610-7869</manufacturerTelno><mnfcturCpnyCd>919920034</mnfcturCpnyCd><mntCpnyCd>919981550</mntCpnyCd><mntCpnyNm>(주)신한엘리베이터</mntCpnyNm><mntCpnyTelno>02-2026-6700</mntCpnyTelno><mrYn>N</mrYn><partcpntNm>김정민</partcpntNm><partcpntTelno>***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>15 인승</ratedCap><ratedSpeed>1 M/MIN</ratedSpeed><shuttleFloorCnt>6</shuttleFloorCnt><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>B1-5</shuttleSection><sigunguCd>122</sigunguCd><standardKey>3</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>033</zipCd1><zipCd2>91</zipCd2></item>,
#  <address1>서울특별시 은평구 통일로71길 6</address1>,
#  <address2>(대조동)</address2>,
#  <applcBeDt>2022-07-29</applcBeDt>,
#  <applcEnDt>2023-07-28</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>2183</buldMgtNo2>,
#  <buldNm>Babyjjam</buldNm>,
#  <buldPrpos>제2종근린생활시설-기타</buldPrpos>,
#  <divGroundFloorCnt>5</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>1</divUndgrndFloorCnt>,
#  <elevatorNo>0074954</elevatorNo>,
#  <elvtrAsignNo>1</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
#  <elvtrKindNm>장애인용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>4708</elvtrMgtNo2>,
#  <elvtrModel>TK-50CS</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>2015-07-29</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>2015-07-29</installationDe>,
#  <installationPlace>1-1</installationPlace>,
#  <lastInspctDe>2022-09-19</lastInspctDe>,
#  <lastInspctKind>정기</lastInspctKind>,
#  <lastResultNm>조건부합격</lastResultNm>,
#  <liveLoad>1000 KG</liveLoad>,
#  <manufacturerName>티케이엘리베이터코리아(주)</manufacturerName>,
#  <manufacturerTelno>02-2610-7869</manufacturerTelno>,
#  <mnfcturCpnyCd>919920034</mnfcturCpnyCd>,
#  <mntCpnyCd>919981550</mntCpnyCd>,
#  <mntCpnyNm>(주)신한엘리베이터</mntCpnyNm>,
#  <mntCpnyTelno>02-2026-6700</mntCpnyTelno>,
#  <mrYn>N</mrYn>,
#  <partcpntNm>김정민</partcpntNm>,
#  <partcpntTelno>***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>15 인승</ratedCap>,
#  <ratedSpeed>1 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>6</shuttleFloorCnt>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>B1-5</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>3</standardKey>,
#  <subcntrCpny>-</subcntrCpny>,
#  <zipCd1>033</zipCd1>,
#  <zipCd2>91</zipCd2>,
#  <item><address1>서울특별시 은평구 통일로53길 9-6</address1><address2>C.H.L연립주택 </address2><applcBeDt>2022-04-13</applcBeDt><applcEnDt>2022-10-12</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>40</buldMgtNo2><buldNm>C.H.L연립주택</buldNm><buldPrpos>공동주택-분양</buldPrpos><divGroundFloorCnt>4</divGroundFloorCnt><divUndgrndFloorCnt>1</divUndgrndFloorCnt><elevatorNo>0039283</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-교류</elvtrFormNm><elvtrKindNm>승객용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>86</elvtrMgtNo2><elvtrModel>확인불가</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>1995-03-10</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>1995-03-10</installationDe><installationPlace>1-1</installationPlace><lastInspctDe>2022-05-27</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>합격</lastResultNm><liveLoad>450 KG</liveLoad><manufacturerName>영진기계</manufacturerName><manufacturerTelno>02-867-5337</manufacturerTelno><mnfcturCpnyCd>919930209</mnfcturCpnyCd><mntCpnyCd>919930353</mntCpnyCd><mntCpnyNm>(주)화신엘리베이터공사</mntCpnyNm><mntCpnyTelno>02-776-4939</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>장인주</partcpntNm><partcpntTelno>***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>6 인승</ratedCap><ratedSpeed>1 M/MIN</ratedSpeed><shuttleFloorCnt>5</shuttleFloorCnt><shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>B1-4</shuttleSection><sigunguCd>122</sigunguCd><standardKey>8</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>033</zipCd1><zipCd2>82</zipCd2></item>,
#  <address1>서울특별시 은평구 통일로53길 9-6</address1>,
#  <address2>C.H.L연립주택 </address2>,
#  <applcBeDt>2022-04-13</applcBeDt>,
#  <applcEnDt>2022-10-12</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>40</buldMgtNo2>,
#  <buldNm>C.H.L연립주택</buldNm>,
#  <buldPrpos>공동주택-분양</buldPrpos>,
#  <divGroundFloorCnt>4</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>1</divUndgrndFloorCnt>,
#  <elevatorNo>0039283</elevatorNo>,
#  <elvtrAsignNo>1</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-교류</elvtrFormNm>,
#  <elvtrKindNm>승객용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>86</elvtrMgtNo2>,
#  <elvtrModel>확인불가</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>1995-03-10</frstInstallationDe>,
#  <inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt>,
#  <installationDe>1995-03-10</installationDe>,
#  <installationPlace>1-1</installationPlace>,
#  <lastInspctDe>2022-05-27</lastInspctDe>,
#  <lastInspctKind>정기</lastInspctKind>,
#  <lastResultNm>합격</lastResultNm>,
#  <liveLoad>450 KG</liveLoad>,
#  <manufacturerName>영진기계</manufacturerName>,
#  <manufacturerTelno>02-867-5337</manufacturerTelno>,
#  <mnfcturCpnyCd>919930209</mnfcturCpnyCd>,
#  <mntCpnyCd>919930353</mntCpnyCd>,
#  <mntCpnyNm>(주)화신엘리베이터공사</mntCpnyNm>,
#  <mntCpnyTelno>02-776-4939</mntCpnyTelno>,
#  <mrYn>Y</mrYn>,
#  <partcpntNm>장인주</partcpntNm>,
#  <partcpntTelno>***</partcpntTelno>,
#  <pauseAblDe>--</pauseAblDe>,
#  <pauseAbleResn>-</pauseAbleResn>,
#  <ratedCap>6 인승</ratedCap>,
#  <ratedSpeed>1 M/MIN</ratedSpeed>,
#  <shuttleFloorCnt>5</shuttleFloorCnt>,
#  <shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm>,
#  <shuttleMngrTelno>-</shuttleMngrTelno>,
#  <shuttleSection>B1-4</shuttleSection>,
#  <sigunguCd>122</sigunguCd>,
#  <standardKey>8</standardKey>,
#  <subcntrCpny>-</subcntrCpny>,
#  <zipCd1>033</zipCd1>,
#  <zipCd2>82</zipCd2>,
#  <item><address1>서울특별시 은평구 서오릉로 30</address1><address2>(녹번동)</address2><applcBeDt>2022-05-12</applcBeDt><applcEnDt>2023-05-11</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>2723</buldMgtNo2><buldNm>C.S 아르체</buldNm><buldPrpos>공동주택-분양</buldPrpos><divGroundFloorCnt>11</divGroundFloorCnt><divUndgrndFloorCnt>1</divUndgrndFloorCnt><elevatorNo>0125129</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>장애인용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>5724</elvtrMgtNo2><elvtrModel>GM3(7)</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>2017-05-12</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>2017-05-12</installationDe><installationPlace>1-1</installationPlace><lastInspctDe>2022-06-27</lastInspctDe><lastInspctKind>정기</lastInspctKind><lastResultNm>합격</lastResultNm><liveLoad>1000 KG</liveLoad><manufacturerName>(주)금영제너럴</manufacturerName><manufacturerTelno>02-2056-1117</manufacturerTelno><mnfcturCpnyCd>920070033</mnfcturCpnyCd><mntCpnyCd>920070033</mntCpnyCd><mntCpnyNm>(주)금영제너럴</mntCpnyNm><mntCpnyTelno>02-2056-1117</mntCpnyTelno><mrYn>N</mrYn><partcpntNm>주택관리 담당자</partcpntNm><partcpntTelno>***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>15 인승</ratedCap><ratedSpeed>1.5 M/MIN</ratedSpeed><shuttleFloorCnt>12</shuttleFloorCnt><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>B1-11</shuttleSection><sigunguCd>122</sigunguCd><standardKey>3</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>033</zipCd1><zipCd2>80</zipCd2></item>,
#  <address1>서울특별시 은평구 서오릉로 30</address1>,
#  <address2>(녹번동)</address2>,
#  <applcBeDt>2022-05-12</applcBeDt>,
#  <applcEnDt>2023-05-11</applcEnDt>,
#  <areaNo>01</areaNo>,
#  <buldMgtNo1>122</buldMgtNo1>,
#  <buldMgtNo2>2723</buldMgtNo2>,
#  <buldNm>C.S 아르체</buldNm>,
#  <buldPrpos>공동주택-분양</buldPrpos>,
#  <divGroundFloorCnt>11</divGroundFloorCnt>,
#  <divUndgrndFloorCnt>1</divUndgrndFloorCnt>,
#  <elevatorNo>0125129</elevatorNo>,
#  <elvtrAsignNo>1</elvtrAsignNo>,
#  <elvtrDivNm>엘리베이터</elvtrDivNm>,
#  <elvtrFormNm>권상식-VVVF</elvtrFormNm>,
#  <elvtrKindNm>장애인용</elvtrKindNm>,
#  <elvtrMgtNo1>122</elvtrMgtNo1>,
#  <elvtrMgtNo2>5724</elvtrMgtNo2>,
#  <elvtrModel>GM3(7)</elvtrModel>,
#  <elvtrResmptDe>--</elvtrResmptDe>,
#  <elvtrStts>운행중</elvtrStts>,
#  <frstInstallationDe>2017-05-12</frstInstallationDe>,
#  ...]

# %%
soup.items()[0]
# Out:
# <item><address1>서울특별시 은평구 연서로 71</address1><address2>(역촌동)</address2><applcBeDt>2022-05-24</applcBeDt><applcEnDt>2023-05-23</applcEnDt><areaNo>01</areaNo><buldMgtNo1>122</buldMgtNo1><buldMgtNo2>236</buldMgtNo2><buldNm>(재)살림이</buldNm><buldPrpos>제2종근린생활시설-기타</buldPrpos><divGroundFloorCnt>5</divGroundFloorCnt><divUndgrndFloorCnt>1</divUndgrndFloorCnt><elevatorNo>0081201</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>승객용</elvtrKindNm><elvtrMgtNo1>122</elvtrMgtNo1><elvtrMgtNo2>440</elvtrMgtNo2><elvtrModel>SCN5NKZi(412,S)</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>1998-01-15</frstInstallationDe><inspctInstt>한국승강기안전공단 서울서부지사</inspctInstt><installationDe>1998-01-15</installationDe><installationPlace>1-1</installationPlace><lastInspctDe>2022-05-24</lastInspctDe><lastInspctKind>수시</lastInspctKind><lastResultNm>합격</lastResultNm><liveLoad>550 KG</liveLoad><manufacturerName>엘지산전(주) 창원공장</manufacturerName><manufacturerTelno>055-269-4114</manufacturerTelno><mnfcturCpnyCd>919920032</mnfcturCpnyCd><mntCpnyCd>919990047</mntCpnyCd><mntCpnyNm>(주)제일승강기</mntCpnyNm><mntCpnyTelno>031-908-8681</mntCpnyTelno><mrYn>Y</mrYn><partcpntNm>승강기 담당자</partcpntNm><partcpntTelno>010-9884-1***</partcpntTelno><pauseAblDe>--</pauseAblDe><pauseAbleResn>-</pauseAbleResn><ratedCap>8 인승</ratedCap><ratedSpeed>1 M/MIN</ratedSpeed><shuttleFloorCnt>6</shuttleFloorCnt><shuttleMngrNm>선임(운행관리자정보없음)</shuttleMngrNm><shuttleMngrTelno>-</shuttleMngrTelno><shuttleSection>B1-5</shuttleSection><sigunguCd>122</sigunguCd><standardKey>1</standardKey><subcntrCpny>-</subcntrCpny><zipCd1>034</zipCd1><zipCd2>17</zipCd2></item>

# %%
col_names = []
for item in soup.items()[0]:
    # print(item.name)
    # print('--')
    col_names.append(item.name)

# %%
col_names
# Out:
# ['address1',
#  'address2',
#  'applcBeDt',
#  'applcEnDt',
#  'areaNo',
#  'buldMgtNo1',
#  'buldMgtNo2',
#  'buldNm',
#  'buldPrpos',
#  'divGroundFloorCnt',
#  'divUndgrndFloorCnt',
#  'elevatorNo',
#  'elvtrAsignNo',
#  'elvtrDivNm',
#  'elvtrFormNm',
#  'elvtrKindNm',
#  'elvtrMgtNo1',
#  'elvtrMgtNo2',
#  'elvtrModel',
#  'elvtrResmptDe',
#  'elvtrStts',
#  'frstInstallationDe',
#  'inspctInstt',
#  'installationDe',
#  'installationPlace',
#  'lastInspctDe',
#  'lastInspctKind',
#  'lastResultNm',
#  'liveLoad',
#  'manufacturerName',
#  'manufacturerTelno',
#  'mnfcturCpnyCd',
#  'mntCpnyCd',
#  'mntCpnyNm',
#  'mntCpnyTelno',
#  'mrYn',
#  'partcpntNm',
#  'partcpntTelno',
#  'pauseAblDe',
#  'pauseAbleResn',
#  'ratedCap',
#  'ratedSpeed',
#  'shuttleFloorCnt',
#  'shuttleMngrNm',
#  'shuttleMngrTelno',
#  'shuttleSection',
#  'sigunguCd',
#  'standardKey',
#  'subcntrCpny',
#  'zipCd1',
#  'zipCd2']

# %%
soup.items()[1]
# Out:
# <address1>서울특별시 은평구 연서로 71</address1>

# %%
data = []
for item in soup.items :
    temp = []
    for t in item :
        temp.append(t.text)
        # print(t.text)
        # print('------')  
    data.append(temp)

# %%
t.text
# Out:
# '87'

# %%
data
# Out:
# [['서울특별시 은평구 연서로 71',
#   '(역촌동)',
#   '2022-05-24',
#   '2023-05-23',
#   '01',
#   '122',
#   '236',
#   '(재)살림이',
#   '제2종근린생활시설-기타',
#   '5',
#   '1',
#   '0081201',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '440',
#   'SCN5NKZi(412,S)',
#   '--',
#   '운행중',
#   '1998-01-15',
#   '한국승강기안전공단 서울서부지사',
#   '1998-01-15',
#   '1-1',
#   '2022-05-24',
#   '수시',
#   '합격',
#   '550 KG',
#   '엘지산전(주) 창원공장',
#   '055-269-4114',
#   '919920032',
#   '919990047',
#   '(주)제일승강기',
#   '031-908-8681',
#   'Y',
#   '승강기 담당자',
#   '010-9884-1***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '6',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B1-5',
#   '122',
#   '1',
#   '-',
#   '034',
#   '17'],
#  ['서울특별시 은평구 통일로71길 16',
#   '(대조동)',
#   '2022-09-29',
#   '2023-09-28',
#   '01',
#   '122',
#   '889',
#   '(주)KT 은평지사',
#   '업무시설-기타',
#   '4',
#   '1',
#   '0042569',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '1760',
#   'Di1',
#   '--',
#   '운행중',
#   '2005-08-24',
#   '한국승강기안전공단 서울서부지사',
#   '2005-08-24',
#   '1-1',
#   '2022-10-11',
#   '정기',
#   '합격',
#   '1150 KG',
#   '오티스엘리베이터(유)창원공장',
#   '055-289-8235',
#   '919990124',
#   '919920075',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   'Y',
#   '김봉수(설비실장)',
#   '010-3043-1***',
#   '--',
#   '-',
#   '17 인승',
#   '1.5 M/MIN',
#   '4',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-4',
#   '122',
#   '1',
#   '-',
#   '033',
#   '91'],
#  ['서울특별시 은평구 통일로71길 16',
#   '(대조동)',
#   '2022-09-29',
#   '2023-09-28',
#   '01',
#   '122',
#   '889',
#   '(주)KT 은평지사',
#   '업무시설-기타',
#   '4',
#   '1',
#   '0042570',
#   '2',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '1881',
#   'Di1',
#   '--',
#   '운행중',
#   '2006-10-24',
#   '한국승강기안전공단 서울서부지사',
#   '2006-10-24',
#   '1-2',
#   '2022-10-11',
#   '정밀',
#   '조건부합격',
#   '1150 KG',
#   '오티스엘리베이터(유)창원공장',
#   '055-289-8235',
#   '919990124',
#   '919920075',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   'Y',
#   '김봉수(설비실장)',
#   '010-3043-1***',
#   '--',
#   '-',
#   '17 인승',
#   '1.5 M/MIN',
#   '5',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B1-4',
#   '122',
#   '1',
#   '-',
#   '033',
#   '91'],
#  ['서울특별시 은평구 은평로13길 12-1',
#   '해명빌딩 (녹번동)',
#   '2022-04-14',
#   '2022-10-13',
#   '01',
#   '122',
#   '43',
#   '(주)녹번해명(해명빌딩)',
#   '제2종근린생활시설-기타',
#   '5',
#   '1',
#   '0104893',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '138',
#   '확인불가',
#   '--',
#   '운행중',
#   '1991-06-10',
#   '한국승강기안전공단 서울서부지사',
#   '1991-06-10',
#   '1-1',
#   '2022-11-03',
#   '정기',
#   '조건부합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919990073',
#   '명성엘리베이터(주)',
#   '02-2616-2404',
#   'Y',
#   '관리소장 (민정훈)',
#   '(02)388-1***',
#   '--',
#   '-',
#   '17 인승',
#   '1 M/MIN',
#   '6',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B1-5',
#   '122',
#   '8',
#   '-',
#   '034',
#   '59'],
#  ['서울특별시 은평구 은평로13길 12-1',
#   '해명빌딩 (녹번동)',
#   '2022-03-27',
#   '2022-09-26',
#   '01',
#   '122',
#   '43',
#   '(주)녹번해명(해명빌딩)',
#   '제2종근린생활시설-기타',
#   '5',
#   '1',
#   '0004213',
#   '2',
#   '엘리베이터',
#   '유압식-교류',
#   '자동차용',
#   '122',
#   '139',
#   '확인불가',
#   '--',
#   '운행중',
#   '1991-06-10',
#   '한국승강기안전공단 서울서부지사',
#   '1991-06-10',
#   '1-2',
#   '2022-11-03',
#   '정기',
#   '조건부합격',
#   '2000 KG',
#   '영진엘리베이터(주)',
#   '032-815-7871',
#   '919930210',
#   '919990073',
#   '명성엘리베이터(주)',
#   '02-2616-2404',
#   'Y',
#   '관리소장 (민정훈)',
#   '(02)388-1***',
#   '--',
#   '-',
#   '0 인승',
#   '.33 M/MIN',
#   '2',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B1-1',
#   '122',
#   '8',
#   '-',
#   '034',
#   '59'],
#  ['서울특별시 은평구 응암로 165',
#   '(응암동)',
#   '2022-08-09',
#   '2023-08-08',
#   '01',
#   '122',
#   '2669',
#   '(주)사과마을',
#   '판매시설-기타',
#   '2',
#   '0',
#   '0120103',
#   '2',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '5517',
#   'WBSS2',
#   '--',
#   '운행중',
#   '2016-12-23',
#   '한국승강기안전공단 서울서부지사',
#   '2016-12-23',
#   '1-2',
#   '2022-09-06',
#   '정기',
#   '조건후합격',
#   '1600 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919930409',
#   '현대엘리베이터(주)서울사무소',
#   '1577-0603',
#   'N',
#   '조승현(승강기담당)',
#   '02-308-1***',
#   '--',
#   '-',
#   '24 인승',
#   '1 M/MIN',
#   '2',
#   '-',
#   '1-2',
#   '122',
#   '3',
#   '-',
#   '034',
#   '85'],
#  ['서울특별시 은평구 통일로 874',
#   '(불광동)',
#   '2021-08-25',
#   '2022-08-24',
#   '01',
#   '122',
#   '779',
#   '(주)연신개발(연신빌딩)',
#   '제1종근린생활시설-기타',
#   '8',
#   '0',
#   '0068472',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '1513',
#   'Di1',
#   '--',
#   '운행중',
#   '2004-08-25',
#   '한국승강기안전공단 서울서부지사',
#   '2004-08-25',
#   '1-1',
#   '2021-10-18',
#   '정기',
#   '합격',
#   '750 KG',
#   '오티스엘리베이터(유)창원공장',
#   '055-289-8235',
#   '919990124',
#   '919920075',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   'Y',
#   '이성혁',
#   '02-355-3***',
#   '--',
#   '-',
#   '11 인승',
#   '1 M/MIN',
#   '8',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-8',
#   '122',
#   '1',
#   '-',
#   '033',
#   '44'],
#  ['서울특별시 은평구 통일로66길 6-10',
#   '(불광동)',
#   '2021-11-12',
#   '2022-11-11',
#   '01',
#   '122',
#   '1487',
#   '115하우스',
#   '공동주택-분양',
#   '9',
#   '0',
#   '0083623',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '3730',
#   'GR1',
#   '--',
#   '운행중',
#   '2011-10-18',
#   '한국승강기안전공단 서울서부지사',
#   '2011-10-18',
#   '1-1',
#   '2022-02-11',
#   '정기',
#   '합격',
#   '550 KG',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   '919920075',
#   '919920075',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   'N',
#   '승강기 담당자',
#   '010-3844-6***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '9',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-9',
#   '122',
#   '3',
#   '-',
#   '033',
#   '68'],
#  ['서울특별시 은평구 은평로 210',
#   '(응암동)',
#   '2022-05-24',
#   '2023-05-23',
#   '01',
#   '122',
#   '12',
#   'A.G.M빌딩',
#   '제2종근린생활시설-기타',
#   '5',
#   '0',
#   '0004227',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '223',
#   'WBLX-GX-2(M)',
#   '--',
#   '운행중',
#   '1989-06-01',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-24',
#   '1-1',
#   '2022-08-16',
#   '정기',
#   '합격',
#   '550 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919990085',
#   '대한주차관리(주)',
#   '02-852-4417',
#   'Y',
#   '승강기담당 (양찬영)',
#   '010-3283-9***',
#   '-',
#   '-',
#   '7 인승',
#   '1 M/MIN',
#   '5',
#   '-',
#   '1-5',
#   '122',
#   '3',
#   '-',
#   '034',
#   '72'],
#  ['서울특별시 은평구 은평로 210',
#   '(응암동)',
#   '2022-07-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '12',
#   'A.G.M빌딩',
#   '제2종근린생활시설-기타',
#   '1',
#   '1',
#   '0103615',
#   '2',
#   '엘리베이터',
#   '유압식-교류',
#   '자동차용',
#   '122',
#   '224',
#   '확인불가',
#   '--',
#   '운행중',
#   '1989-06-01',
#   '한국승강기안전공단 서울서부지사',
#   '1989-06-01',
#   '1-2',
#   '2022-08-16',
#   '정기',
#   '조건부합격',
#   '2000 KG',
#   '기타(KTL)',
#   '999999900',
#   '919990085',
#   '대한주차관리(주)',
#   '02-852-4417',
#   'Y',
#   '승강기담당 (양찬영)',
#   '010-3283-9***',
#   '--',
#   '-',
#   '.33 M/MIN',
#   '2',
#   '-',
#   'B1-1',
#   '122',
#   '20',
#   '-',
#   '034',
#   '72'],
#  ['서울특별시 은평구 통일로87길 14',
#   '(갈현동)',
#   '2022-02-26',
#   '2023-02-25',
#   '01',
#   '122',
#   '471',
#   'A1빌딩',
#   '제2종근린생활시설-기타',
#   '5',
#   '0',
#   '0041811',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '1953',
#   'Di1',
#   '--',
#   '운행중',
#   '2002-10-19',
#   '한국승강기안전공단 서울서부지사',
#   '2007-06-07',
#   '1-1',
#   '2022-07-12',
#   '정기',
#   '합격',
#   '750 KG',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   '919920075',
#   '919920075',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   'Y',
#   '장승기',
#   '010-6517-3***',
#   '--',
#   '-',
#   '11 인승',
#   '1 M/MIN',
#   '5',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-5',
#   '122',
#   '1',
#   '-',
#   '033',
#   '28'],
#  ['서울특별시 은평구 통일로 585-1',
#   '(응암동)',
#   '2022-06-30',
#   '2023-06-29',
#   '01',
#   '122',
#   '1919',
#   'AVENUE호텔',
#   '업무시설-기타',
#   '12',
#   '0',
#   '0105742',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '4315',
#   'WBST1',
#   '--',
#   '운행중',
#   '2014-06-30',
#   '한국승강기안전공단 서울서부지사',
#   '2014-06-30',
#   '1-1(좌)',
#   '2022-09-28',
#   '정기',
#   '조건부합격',
#   '900 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919930409',
#   '현대엘리베이터(주)서울사무소',
#   '1577-0603',
#   'Y',
#   '박종천',
#   '02)350-6***',
#   '--',
#   '-',
#   '13 인승',
#   '1.5 M/MIN',
#   '12',
#   '-',
#   '1-12',
#   '122',
#   '3',
#   '정우엘리베이터(주)',
#   '034',
#   '73'],
#  ['서울특별시 은평구 통일로 585-1',
#   '(응암동)',
#   '2022-06-30',
#   '2023-06-29',
#   '01',
#   '122',
#   '1919',
#   'AVENUE호텔',
#   '업무시설-기타',
#   '12',
#   '0',
#   '0105743',
#   '2',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '4316',
#   'WBST1',
#   '--',
#   '운행중',
#   '2014-06-30',
#   '한국승강기안전공단 서울서부지사',
#   '2014-06-30',
#   '1-2(우)',
#   '2022-09-28',
#   '정기',
#   '합격',
#   '600 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919930409',
#   '현대엘리베이터(주)서울사무소',
#   '1577-0603',
#   'Y',
#   '박종천',
#   '02)350-6***',
#   '--',
#   '-',
#   '9 인승',
#   '1.5 M/MIN',
#   '12',
#   '-',
#   '1-12',
#   '122',
#   '3',
#   '정우엘리베이터(주)',
#   '034',
#   '73'],
#  ['서울특별시 은평구 은평로2길 6-18',
#   '(신사동)',
#   '2022-07-10',
#   '2023-07-09',
#   '01',
#   '122',
#   '1331',
#   'A플러스 빌',
#   '제2종근린생활시설-기타',
#   '7',
#   '0',
#   '0103174',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '3367',
#   'STVF-7',
#   '--',
#   '운행중',
#   '2010-11-15',
#   '한국승강기안전공단 서울서부지사',
#   '2010-11-15',
#   '1-1',
#   '2022-10-11',
#   '정기',
#   '합격',
#   '600 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919930409',
#   '현대엘리베이터(주)서울사무소',
#   '1577-0603',
#   'Y',
#   '정윤수',
#   '02-387-6***',
#   '--',
#   '-',
#   '9 인승',
#   '1 M/MIN',
#   '7',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-7',
#   '122',
#   '3',
#   '정우엘리베이터(주)',
#   '034',
#   '50'],
#  ['서울특별시 은평구 통일로 689-7',
#   '(녹번동)',
#   '2022-03-06',
#   '2023-03-05',
#   '01',
#   '122',
#   '2741',
#   'B.L 빌리지',
#   '공동주택-민영임대(민간건설사)',
#   '5',
#   '0',
#   '0120304',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '5609',
#   'WBSS2',
#   '--',
#   '운행중',
#   '2017-03-06',
#   '한국승강기안전공단 서울서부지사',
#   '2017-03-06',
#   '1-1',
#   '2022-07-21',
#   '정기',
#   '합격',
#   '600 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920160023',
#   '한국엘리베이터보수관리(주)',
#   '032-546-4222',
#   'N',
#   '김용덕',
#   '010-4272-7***',
#   '--',
#   '-',
#   '9 인승',
#   '1 M/MIN',
#   '5',
#   '-',
#   '1-5',
#   '122',
#   '3',
#   '-',
#   '033',
#   '75'],
#  ['서울특별시 은평구 연서로 520',
#   '(진관동)',
#   '2021-11-27',
#   '2022-11-26',
#   '01',
#   '122',
#   '3311',
#   'BC빌딩',
#   '제2종근린생활시설-기타',
#   '6',
#   '0',
#   '0138790',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '6750',
#   'WBSS2',
#   '--',
#   '운행중',
#   '2019-11-27',
#   '한국승강기안전공단 서울서부지사',
#   '2019-11-27',
#   '1-1',
#   '2022-02-18',
#   '정기',
#   '합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'N',
#   '김병창',
#   '010-8777-3***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '6',
#   '-',
#   '1-6',
#   '122',
#   '3',
#   '-',
#   '033',
#   '08'],
#  ['서울특별시 은평구 연서로13길 29-6 (구산동)',
#   ' ',
#   '2022-08-18',
#   '2023-08-17',
#   '01',
#   '122',
#   '3540',
#   'BOMIN ASTRO',
#   '공동주택-분양',
#   '6',
#   '0',
#   '0150214',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '7142',
#   'K-NP-MRL-P1(M)',
#   '--',
#   '운행중',
#   '2021-06-17',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-17',
#   '1-1',
#   '2022-08-18',
#   '정기',
#   '합격',
#   '900 KG',
#   '한국미쓰비시엘리베이터(주)(서울)',
#   '02-6670-2152',
#   '920020007',
#   '920180086',
#   '한국미쓰비시엘리베이터(주)강북1',
#   '02-921-3114',
#   'N',
#   '김형기',
#   '***',
#   '--',
#   '-',
#   '12 인승',
#   '1 M/MIN',
#   '6',
#   '-',
#   '1-6',
#   '122',
#   '3',
#   '-',
#   '034',
#   '14'],
#  ['서울특별시 은평구 통일로71길 6',
#   '(대조동)',
#   '2022-07-29',
#   '2023-07-28',
#   '01',
#   '122',
#   '2183',
#   'Babyjjam',
#   '제2종근린생활시설-기타',
#   '5',
#   '1',
#   '0074954',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '4708',
#   'TK-50CS',
#   '--',
#   '운행중',
#   '2015-07-29',
#   '한국승강기안전공단 서울서부지사',
#   '2015-07-29',
#   '1-1',
#   '2022-09-19',
#   '정기',
#   '조건부합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919981550',
#   '(주)신한엘리베이터',
#   '02-2026-6700',
#   'N',
#   '김정민',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '6',
#   '-',
#   'B1-5',
#   '122',
#   '3',
#   '-',
#   '033',
#   '91'],
#  ['서울특별시 은평구 통일로53길 9-6',
#   'C.H.L연립주택 ',
#   '2022-04-13',
#   '2022-10-12',
#   '01',
#   '122',
#   '40',
#   'C.H.L연립주택',
#   '공동주택-분양',
#   '4',
#   '1',
#   '0039283',
#   '1',
#   '엘리베이터',
#   '권상식-교류',
#   '승객용',
#   '122',
#   '86',
#   '확인불가',
#   '--',
#   '운행중',
#   '1995-03-10',
#   '한국승강기안전공단 서울서부지사',
#   '1995-03-10',
#   '1-1',
#   '2022-05-27',
#   '정기',
#   '합격',
#   '450 KG',
#   '영진기계',
#   '02-867-5337',
#   '919930209',
#   '919930353',
#   '(주)화신엘리베이터공사',
#   '02-776-4939',
#   'Y',
#   '장인주',
#   '***',
#   '--',
#   '-',
#   '6 인승',
#   '1 M/MIN',
#   '5',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B1-4',
#   '122',
#   '8',
#   '-',
#   '033',
#   '82'],
#  ['서울특별시 은평구 서오릉로 30',
#   '(녹번동)',
#   '2022-05-12',
#   '2023-05-11',
#   '01',
#   '122',
#   '2723',
#   'C.S 아르체',
#   '공동주택-분양',
#   '11',
#   '1',
#   '0125129',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '5724',
#   'GM3(7)',
#   '--',
#   '운행중',
#   '2017-05-12',
#   '한국승강기안전공단 서울서부지사',
#   '2017-05-12',
#   '1-1',
#   '2022-06-27',
#   '정기',
#   '합격',
#   '1000 KG',
#   '(주)금영제너럴',
#   '02-2056-1117',
#   '920070033',
#   '920070033',
#   '(주)금영제너럴',
#   '02-2056-1117',
#   'N',
#   '주택관리 담당자',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.5 M/MIN',
#   '12',
#   '-',
#   'B1-11',
#   '122',
#   '3',
#   '-',
#   '033',
#   '80'],
#  ['서울특별시 은평구 서오릉로 30',
#   '(녹번동)',
#   '2022-05-10',
#   '2023-05-09',
#   '01',
#   '122',
#   '2723',
#   'C.S 아르체',
#   '공동주택-분양',
#   '6',
#   '1',
#   '0120302',
#   '2',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '5587',
#   'GM3(10)',
#   '--',
#   '운행중',
#   '2017-05-04',
#   '한국승강기안전공단 서울서부지사',
#   '2017-05-04',
#   '1-2',
#   '2022-06-27',
#   '정기',
#   '합격',
#   '900 KG',
#   '(주)금영제너럴',
#   '02-2056-1117',
#   '920070033',
#   '920070033',
#   '(주)금영제너럴',
#   '02-2056-1117',
#   'N',
#   '주택관리 담당자',
#   '***',
#   '--',
#   '-',
#   '13 인승',
#   '1 M/MIN',
#   '7',
#   '-',
#   'B1-6',
#   '122',
#   '3',
#   '-',
#   '033',
#   '80'],
#  ['서울특별시 은평구 서오릉로 30',
#   '(녹번동)',
#   '2022-05-10',
#   '2023-05-09',
#   '01',
#   '122',
#   '2723',
#   'C.S 아르체',
#   '공동주택-분양',
#   '6',
#   '1',
#   '0120303',
#   '3',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '5588',
#   'GM3(10)',
#   '--',
#   '운행중',
#   '2017-05-04',
#   '한국승강기안전공단 서울서부지사',
#   '2017-05-04',
#   '1-3',
#   '2022-06-27',
#   '정기',
#   '합격',
#   '900 KG',
#   '(주)금영제너럴',
#   '02-2056-1117',
#   '920070033',
#   '920070033',
#   '(주)금영제너럴',
#   '02-2056-1117',
#   'N',
#   '주택관리 담당자',
#   '***',
#   '--',
#   '-',
#   '13 인승',
#   '1 M/MIN',
#   '7',
#   '-',
#   'B1-6',
#   '122',
#   '3',
#   '-',
#   '033',
#   '80'],
#  ['서울특별시 은평구 은평로 91',
#   '(응암동)',
#   '2022-06-21',
#   '2023-06-20',
#   '01',
#   '122',
#   '764',
#   'CJ드림시티오피스텔',
#   '업무시설-기타',
#   '15',
#   '3',
#   '0041739',
#   '3',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '1502',
#   'CV-150L',
#   '--',
#   '운행중',
#   '2004-06-28',
#   '한국승강기안전공단 서울서부지사',
#   '2004-06-28',
#   'B-1',
#   '2022-08-16',
#   '정기',
#   '합격',
#   '1150 KG',
#   '도시바엘리베이터코리아(주)_폐업',
#   '02-771-7490',
#   '920030001',
#   '919981684',
#   '성도엘리베이터(주)',
#   '02-324-3567',
#   'Y',
#   '승강기담당자',
#   '02-357-8***',
#   '--',
#   '-',
#   '17 인승',
#   '1.5 M/MIN',
#   '18',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B3-15',
#   '122',
#   '12',
#   '-',
#   '034',
#   '61'],
#  ['서울특별시 은평구 은평로 91',
#   '(응암동)',
#   '2022-06-21',
#   '2023-06-20',
#   '01',
#   '122',
#   '764',
#   'CJ드림시티오피스텔',
#   '업무시설-기타',
#   '15',
#   '3',
#   '0041737',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '1503',
#   'CV-150L',
#   '--',
#   '운행중',
#   '2004-06-28',
#   '한국승강기안전공단 서울서부지사',
#   '2004-06-28',
#   'A-1',
#   '2022-08-16',
#   '정기',
#   '조건부합격',
#   '1150 KG',
#   '도시바엘리베이터코리아(주)_폐업',
#   '02-771-7490',
#   '920030001',
#   '919981684',
#   '성도엘리베이터(주)',
#   '02-324-3567',
#   'Y',
#   '승강기담당자',
#   '02-357-8***',
#   '--',
#   '-',
#   '17 인승',
#   '1.5 M/MIN',
#   '15',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-15',
#   '122',
#   '12',
#   '-',
#   '034',
#   '61'],
#  ['서울특별시 은평구 은평로 91',
#   '(응암동)',
#   '2022-06-21',
#   '2023-06-20',
#   '01',
#   '122',
#   '764',
#   'CJ드림시티오피스텔',
#   '업무시설-기타',
#   '14',
#   '2',
#   '0041738',
#   '2',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '1535',
#   'CV-150L',
#   '--',
#   '운행중',
#   '2004-08-10',
#   '한국승강기안전공단 서울서부지사',
#   '2004-08-10',
#   'A-2',
#   '2022-08-16',
#   '정기',
#   '합격',
#   '600 KG',
#   '도시바엘리베이터코리아(주)_폐업',
#   '02-771-7490',
#   '920030001',
#   '919981684',
#   '성도엘리베이터(주)',
#   '02-324-3567',
#   'Y',
#   '승강기담당자',
#   '02-357-8***',
#   '--',
#   '-',
#   '9 인승',
#   '1.5 M/MIN',
#   '16',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B2-14',
#   '122',
#   '12',
#   '-',
#   '034',
#   '61'],
#  ['서울특별시 은평구 불광로 55',
#   '(불광동)',
#   '2022-05-24',
#   '2023-05-23',
#   '01',
#   '122',
#   '3060',
#   'CML큐브',
#   '단독주택-다가구주택',
#   '6',
#   '0',
#   '0129256',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '6108',
#   'WBSS2',
#   '--',
#   '운행중',
#   '2018-05-24',
#   '한국승강기안전공단 서울서부지사',
#   '2018-05-24',
#   '1-1',
#   '2022-07-28',
#   '정기',
#   '합격',
#   '550 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920180023',
#   '현대엘리베이터(주)강서지사',
#   '02-6920-7805',
#   'N',
#   '문현아(승강기담당자)',
#   '010-8728-0***',
#   '--',
#   '-',
#   '8 인승',
#   '1.5 M/MIN',
#   '6',
#   '-',
#   '1-6',
#   '122',
#   '03',
#   '-',
#   '033',
#   '58'],
#  ['서울특별시 은평구 응암로 308',
#   '(응암동)',
#   '2021-06-24',
#   '2022-06-23',
#   '01',
#   '122',
#   '1744',
#   'CM빌딩',
#   '제2종근린생활시설-기타',
#   '5',
#   '0',
#   '0080675',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '4101',
#   'SSVF7',
#   '--',
#   '운행중',
#   '2013-06-24',
#   '한국승강기안전공단 서울서부지사',
#   '2013-06-24',
#   '1-1',
#   '2021-07-29',
#   '정기',
#   '조건부합격',
#   '900 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919930409',
#   '현대엘리베이터(주)서울사무소',
#   '1577-0603',
#   'N',
#   '신화숙',
#   '02-354-9***',
#   '--',
#   '-',
#   '13 인승',
#   '1 M/MIN',
#   '5',
#   '-',
#   '1-5',
#   '122',
#   '3',
#   '정우엘리베이터(주)',
#   '034',
#   '64'],
#  ['서울특별시 은평구 갈현로 141',
#   '(구산동)',
#   '2022-05-19',
#   '2023-05-18',
#   '01',
#   '122',
#   '858',
#   'CN빌',
#   '공동주택-분양',
#   '6',
#   '0',
#   '0006130',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '1640',
#   'Si1',
#   '--',
#   '운행중',
#   '2005-03-30',
#   '(재)승강기안전기술연구원 서울지원',
#   '2005-03-30',
#   '1-1',
#   '2022-06-20',
#   '정기',
#   '합격',
#   '550 KG',
#   '오티스엘리베이터(유)창원공장',
#   '055-289-8235',
#   '919990124',
#   '920040051',
#   '(주)쉰들러엘리베이터 서울',
#   '02-3470-2509',
#   'Y',
#   '장경순(승강기담당)',
#   '010-9054-2***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '6',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-6',
#   '122',
#   '5',
#   '-',
#   '034',
#   '29'],
#  ['서울특별시 은평구 연서로20길 13',
#   '(대조동, 씨티뷰)',
#   '2021-12-07',
#   '2022-12-06',
#   '01',
#   '122',
#   '1982',
#   'CN씨티뷰',
#   '공동주택-분양',
#   '6',
#   '0',
#   '0073834',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '4427',
#   'TK-50CS',
#   '--',
#   '운행중',
#   '2014-09-29',
#   '한국승강기안전공단 서울서부지사',
#   '2014-09-29',
#   '1-1',
#   '2022-05-09',
#   '정기',
#   '조건후합격',
#   '550 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'N',
#   '승강기담당자(박세규)',
#   '010-8722-9***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '6',
#   '-',
#   '1-6',
#   '122',
#   '3',
#   '성도엘리베이터(주)',
#   '033',
#   '87'],
#  ['서울특별시 은평구 진흥로 183',
#   '(대조동)',
#   '2021-12-06',
#   '2022-12-05',
#   '01',
#   '122',
#   '322',
#   'CS모텔',
#   '숙박시설-숙박시설',
#   '7',
#   '1',
#   '0084992',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '597',
#   'Di1',
#   '--',
#   '운행중',
#   '2000-12-15',
#   '한국승강기안전공단 서울서부지사',
#   '2000-12-15',
#   '1-1',
#   '2022-04-04',
#   '정기',
#   '조건후합격',
#   '550 KG',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   '919920075',
#   '920050036',
#   '(주)승조엔지니어링',
#   '02-2698-6007',
#   'Y',
#   '승강기담당자',
#   '(02)353-0***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '7',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-7',
#   '122',
#   '1',
#   '-',
#   '033',
#   '97'],
#  ['서울특별시 은평구 진흥로9길 8-4',
#   ' (역촌동)',
#   '2022-04-22',
#   '2023-04-21',
#   '01',
#   '122',
#   '2452',
#   'CS아르체',
#   '공동주택-분양',
#   '8',
#   '0',
#   '0089125',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '5031',
#   'TK-50CS',
#   '--',
#   '운행중',
#   '2016-04-22',
#   '한국승강기안전공단 서울서부지사',
#   '2016-04-22',
#   '1-1',
#   '2022-09-22',
#   '정기',
#   '조건부합격',
#   '630 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919950932',
#   '티센크루프엘리베이터코리아(주)',
#   '02-2610-7777',
#   'N',
#   '김영훈',
#   '***',
#   '--',
#   '-',
#   '9 인승',
#   '1 M/MIN',
#   '8',
#   '-',
#   '1-8',
#   '122',
#   '3',
#   '성도엘리베이터(주)',
#   '034',
#   '04'],
#  ['서울특별시 은평구 역말로9가길 8-1',
#   '(대조동)',
#   '2022-06-14',
#   '2023-06-13',
#   '01',
#   '122',
#   '2495',
#   'CS아르체',
#   '공동주택-분양',
#   '6',
#   '0',
#   '0116380',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '5082',
#   'TK-50CS',
#   '--',
#   '운행중',
#   '2016-06-14',
#   '한국승강기안전공단 서울서부지사',
#   '2016-06-14',
#   '1-1',
#   '2022-09-07',
#   '정기',
#   '합격',
#   '550 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919950932',
#   '티센크루프엘리베이터코리아(주)',
#   '02-2610-7777',
#   'N',
#   '반장님',
#   '***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '6',
#   '-',
#   '1-6',
#   '122',
#   '3',
#   '성도엘리베이터(주)',
#   '033',
#   '89'],
#  ['서울특별시 은평구 응암로21가길 1-7',
#   '(응암동)',
#   '2022-03-25',
#   '2023-03-24',
#   '01',
#   '122',
#   '2417',
#   'CS아르체',
#   '공동주택-분양',
#   '8',
#   '0',
#   '0088931',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '4987',
#   'TK-50CS',
#   '--',
#   '운행중',
#   '2016-03-25',
#   '한국승강기안전공단 서울서부지사',
#   '2016-03-25',
#   '1-1',
#   '2022-08-09',
#   '정기',
#   '합격',
#   '630 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'N',
#   '입주자대표',
#   '010-8080-5***',
#   '--',
#   '-',
#   '9 인승',
#   '1 M/MIN',
#   '8',
#   '-',
#   '1-8',
#   '122',
#   '03',
#   '성도엘리베이터(주)',
#   '034',
#   '56'],
#  ['서울특별시 은평구 불광동 281-76',
#   ' ',
#   '2022-03-18',
#   '2023-03-17',
#   '01',
#   '122',
#   '3639',
#   'D&J아파트',
#   '공동주택-분양',
#   '12',
#   '0',
#   '0152633',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '7284',
#   'WBSS-GY-2(M)',
#   '--',
#   '운행중',
#   '2022-03-18',
#   '한국승강기안전공단 서울서부지사',
#   '2022-03-18',
#   '1-1',
#   '2022-03-18',
#   '설치',
#   '보완후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'N',
#   '조영대(건축소장)',
#   '***',
#   '--',
#   '-',
#   '13 인승',
#   '1.5 M/MIN',
#   '12',
#   '-',
#   '1-12',
#   '122',
#   '3',
#   '-',
#   '033',
#   '68'],
#  ['서울특별시 은평구 불광로 50-5',
#   '(불광동)',
#   '2022-05-02',
#   '2023-05-01',
#   '01',
#   '122',
#   '3241',
#   'D&J하우징',
#   '업무시설-기타',
#   '10',
#   '0',
#   '0136892',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '6542',
#   'WBSS2',
#   '--',
#   '운행중',
#   '2019-05-02',
#   '한국승강기안전공단 서울서부지사',
#   '2019-05-02',
#   '1-1',
#   '2022-09-27',
#   '정기',
#   '합격',
#   '900 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919920035',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   'N',
#   '승강기담당자',
#   '***',
#   '--',
#   '-',
#   '13 인승',
#   '1.5 M/MIN',
#   '10',
#   '-',
#   '1-10',
#   '122',
#   '3',
#   '-',
#   '033',
#   '68'],
#  ['서울특별시 은평구 통일로78길 11-7',
#   '(불광동)',
#   '2022-07-31',
#   '2023-07-30',
#   '01',
#   '122',
#   '2848',
#   'D&J하우징',
#   '업무시설-기타',
#   '11',
#   '0',
#   '0125354',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '5807',
#   'WBSS2',
#   '--',
#   '운행중',
#   '2017-07-31',
#   '한국승강기안전공단 서울서부지사',
#   '2017-07-31',
#   '1-1',
#   '2022-10-19',
#   '정기',
#   '조건부합격',
#   '900 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920180023',
#   '현대엘리베이터(주)강서지사',
#   '02-6920-7805',
#   'N',
#   '김락영(승강기담당자)',
#   '02-383-2***',
#   '--',
#   '-',
#   '13 인승',
#   '1.5 M/MIN',
#   '11',
#   '-',
#   '1-11',
#   '122',
#   '3',
#   '-',
#   '033',
#   '50'],
#  ['서울특별시 은평구 통일로 708-7',
#   '(불광동)',
#   '2021-12-20',
#   '2022-12-19',
#   '01',
#   '122',
#   '386',
#   'D.U 모텔',
#   '숙박시설-숙박시설',
#   '8',
#   '1',
#   '0084748',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '883',
#   'Di1',
#   '--',
#   '운행중',
#   '2001-11-26',
#   '(재)승강기안전기술연구원 서울지원',
#   '2001-11-26',
#   '1-1',
#   '2022-01-11',
#   '정기',
#   '합격',
#   '450 KG',
#   '오티스엘리베이터(유)창원공장',
#   '055-289-8235',
#   '919990124',
#   '920010024',
#   '승우엘레텍(주)',
#   '02-2642-2893',
#   'Y',
#   '승강기담당자',
#   '(02)351-3***',
#   '--',
#   '-',
#   '6 인승',
#   '1 M/MIN',
#   '8',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B1-7',
#   '122',
#   '1',
#   '-',
#   '033',
#   '68'],
#  ['서울특별시 은평구 서오릉로 12',
#   '(녹번동)',
#   '2022-08-14',
#   '2023-08-13',
#   '01',
#   '122',
#   '3425',
#   'DH PALACE TOWER',
#   '공동주택-기타',
#   '13',
#   '2',
#   '0146060',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '6901',
#   'WBSS-GY-2(M)',
#   '--',
#   '운행중',
#   '2020-08-14',
#   '한국승강기안전공단 서울서부지사',
#   '2020-08-14',
#   '1-1',
#   '2022-10-13',
#   '정기',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920220019',
#   '대영엘리베이터(주)',
#   '0220633496',
#   'N',
#   '승강기담당자',
#   '02-6928-7***',
#   '-',
#   '-',
#   '13 인승',
#   '1.75 M/MIN',
#   '15',
#   '-',
#   'B2-13',
#   '122',
#   '3',
#   '-',
#   '033',
#   '84'],
#  ['서울특별시 은평구 갈현로15길 20',
#   '(구산동, DH팰리스)',
#   '2021-10-10',
#   '2022-10-09',
#   '01',
#   '122',
#   '2203',
#   'DH팰리스',
#   '공동주택-분양',
#   '6',
#   '0',
#   '0113823',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '4740',
#   'GPR',
#   '--',
#   '운행중',
#   '2015-08-19',
#   '(재)승강기안전기술연구원 서울지원',
#   '2015-08-19',
#   '1-1',
#   '2022-11-01',
#   '정기',
#   '조건부합격',
#   '750 KG',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   '919920075',
#   '919920075',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   'N',
#   '승강기담당',
#   '***',
#   '--',
#   '-',
#   '11 인승',
#   '1 M/MIN',
#   '6',
#   '-',
#   '1-6',
#   '122',
#   '03',
#   '-',
#   '034',
#   '29'],
#  ['서울특별시 은평구 은평로21길 16-1',
#   '(녹번동)',
#   '2021-06-08',
#   '2022-06-07',
#   '01',
#   '122',
#   '2502',
#   'DH팰리스 A동',
#   '공동주택-분양',
#   '7',
#   '0',
#   '0116397',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '5094',
#   'TK-50CS',
#   '--',
#   '운행중',
#   '2016-06-08',
#   '한국승강기안전공단 서울서부지사',
#   '2016-06-08',
#   'A동',
#   '2021-07-16',
#   '정기',
#   '합격',
#   '550 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919950932',
#   '티센크루프엘리베이터코리아(주)',
#   '02-2610-7777',
#   'N',
#   'A동 대표',
#   '010-2352-3***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '7',
#   '-',
#   '1-7',
#   '122',
#   '3',
#   '성도엘리베이터(주)',
#   '033',
#   '82'],
#  ['서울특별시 은평구 은평로21길 16',
#   ' ',
#   '2022-09-17',
#   '2023-09-16',
#   '01',
#   '122',
#   '3363',
#   'DH팰리스 B동',
#   '공동주택-분양',
#   '7',
#   '0',
#   '0116398',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '5095',
#   'TK-50CS',
#   '--',
#   '운행중',
#   '2016-06-08',
#   '(재)승강기안전기술연구원 서울지원',
#   '2016-06-08',
#   'B동',
#   '2022-10-20',
#   '정기',
#   '조건후합격',
#   '550 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '920050038',
#   '대명엘리베이터(주)',
#   '02-2043-9950',
#   'N',
#   '승강기담당',
#   '***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '7',
#   '-',
#   '1-7',
#   '122',
#   '3',
#   '-',
#   '033',
#   '82'],
#  ['서울특별시 은평구 역말로 37-6',
#   '(역촌동)',
#   '2022-06-27',
#   '2023-06-26',
#   '01',
#   '122',
#   '589',
#   'DK아파트',
#   '공동주택-분양',
#   '7',
#   '1',
#   '0038838',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '1205',
#   'DY-30A',
#   '--',
#   '운행중',
#   '2003-06-27',
#   '한국승강기안전공단 서울서부지사',
#   '2003-06-27',
#   '1-1',
#   '2022-08-10',
#   '정밀',
#   '합격',
#   '1000 KG',
#   '동양중공업(주)',
#   '031-498-7777',
#   '919930173',
#   '919981684',
#   '성도엘리베이터(주)',
#   '02-324-3567',
#   'Y',
#   '승강기담당자',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '8',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B1-7',
#   '122',
#   '12',
#   '-',
#   '034',
#   '16'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-23',
#   '2022-08-22',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '26',
#   '4',
#   '0150066',
#   '2',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7070',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '101-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B4-26',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-23',
#   '2022-08-22',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '26',
#   '4',
#   '0150067',
#   '3',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7071',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '101-3',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B4-26',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-23',
#   '2022-08-22',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '24',
#   '3',
#   '0150065',
#   '4',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7072',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '102-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '27',
#   '-',
#   'B3-24',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '27',
#   '3',
#   '0150016',
#   '7',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7073',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '103-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '30',
#   '-',
#   'B3-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '27',
#   '3',
#   '0150017',
#   '8',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7074',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '103-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '30',
#   '-',
#   'B3-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '19',
#   '4',
#   '0150018',
#   '9',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7075',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '104-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '23',
#   '-',
#   'B3-19',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '19',
#   '4',
#   '0150019',
#   '10',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7076',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '104-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '23',
#   '-',
#   'B3-19',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-25',
#   '2022-08-24',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '18',
#   '3',
#   '0150041',
#   '13',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7077',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '105-3',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '21',
#   '-',
#   'B3-18',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-25',
#   '2022-08-24',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '16',
#   '4',
#   '0150042',
#   '16',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7080',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '106-3',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '19',
#   '-',
#   'B4-16',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '30',
#   '4',
#   '0150136',
#   '5',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7103',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-05-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-13',
#   '102-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '33',
#   '-',
#   'B4-30',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '30',
#   '4',
#   '0150137',
#   '6',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7104',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-05-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-13',
#   '102-3',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '33',
#   '-',
#   'B4-30',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '27',
#   '3',
#   '0150138',
#   '11',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7105',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-05-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-13',
#   '105-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B3-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '27',
#   '3',
#   '0150139',
#   '12',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7106',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-05-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-13',
#   '105-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B3-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-25',
#   '2022-08-24',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '19',
#   '4',
#   '0150068',
#   '14',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7050',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '106-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '22',
#   '-',
#   'B4-19',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-25',
#   '2022-08-24',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '19',
#   '4',
#   '0150069',
#   '15',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7051',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '106-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '22',
#   '-',
#   'B4-19',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-23',
#   '2022-08-22',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '24',
#   '4',
#   '0150046',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7042',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '101-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '27',
#   '-',
#   'B4-24',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-09-30',
#   '2022-08-24',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '1',
#   '2',
#   '0150343',
#   '17',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '7173',
#   'EVO1(M)',
#   '--',
#   '운행중',
#   '2021-09-30',
#   '한국승강기안전공단 서울서부지사',
#   '2021-09-30',
#   '102커뮤니티',
#   '2021-09-30',
#   '설치',
#   '보완후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'N',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '3',
#   '-',
#   'B2-1',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰2단지주상복합',
#   '2021-08-26',
#   '2022-08-25',
#   '01',
#   '122',
#   '3633',
#   'DMC SK뷰2단지주상복합',
#   '공동주택-분양',
#   '21',
#   '5',
#   '0150181',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7120',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-06-03',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-03',
#   '201-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '승강기담당자',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '25',
#   '-',
#   'B5-21',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰2단지주상복합',
#   '2021-08-26',
#   '2022-08-25',
#   '01',
#   '122',
#   '3633',
#   'DMC SK뷰2단지주상복합',
#   '공동주택-분양',
#   '21',
#   '5',
#   '0150182',
#   '2',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7121',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-06-03',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-03',
#   '201-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '승강기담당자',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '25',
#   '-',
#   'B5-21',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰2단지주상복합',
#   '2021-08-26',
#   '2022-08-25',
#   '01',
#   '122',
#   '3633',
#   'DMC SK뷰2단지주상복합',
#   '공동주택-분양',
#   '22',
#   '5',
#   '0150183',
#   '3',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7122',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-06-03',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-03',
#   '202-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '승강기담당자',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '26',
#   '-',
#   'B5-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰2단지주상복합',
#   '2021-08-26',
#   '2022-08-25',
#   '01',
#   '122',
#   '3633',
#   'DMC SK뷰2단지주상복합',
#   '공동주택-분양',
#   '22',
#   '5',
#   '0150184',
#   '4',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7123',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-06-03',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-03',
#   '202-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '승강기담당자',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '26',
#   '-',
#   'B5-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰2단지주상복합',
#   '2021-09-30',
#   '2022-09-29',
#   '01',
#   '122',
#   '3633',
#   'DMC SK뷰2단지주상복합',
#   '공동주택-분양',
#   '3',
#   '1',
#   '0150344',
#   '5',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '7174',
#   'EVO1(M)',
#   '--',
#   '운행중',
#   '2021-09-30',
#   '한국승강기안전공단 서울서부지사',
#   '2021-09-30',
#   '201커뮤니티',
#   '2021-09-30',
#   '설치',
#   '합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'N',
#   '승강기담당자',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '5',
#   '-',
#   'B1-3',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-03-08',
#   '2023-03-07',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '1',
#   '1',
#   '0152585',
#   '08',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '7254',
#   'WBSS(E)(M)',
#   '--',
#   '운행중',
#   '2022-03-08',
#   '한국승강기안전공단 서울서부지사',
#   '2022-03-08',
#   '1단지-외부2',
#   '2022-03-08',
#   '설치',
#   '보완후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920180023',
#   '현대엘리베이터(주)강서지사',
#   '02-6920-7805',
#   'N',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '2',
#   '-',
#   'B1-1',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-03-08',
#   '2023-03-07',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '1',
#   '1',
#   '0152587',
#   '022',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '7255',
#   'WBSS(E)(M)',
#   '--',
#   '운행중',
#   '2022-03-08',
#   '한국승강기안전공단 서울서부지사',
#   '2022-03-08',
#   '2단지-외부2',
#   '2022-03-08',
#   '설치',
#   '보완후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920180023',
#   '현대엘리베이터(주)강서지사',
#   '02-6920-7805',
#   'N',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '1 M/MIN',
#   '2',
#   '-',
#   'B1-1',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-03-08',
#   '2023-03-07',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '1',
#   '1',
#   '0152584',
#   '07',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애/전망용',
#   '122',
#   '7251',
#   'WBSS(E)(M)',
#   '--',
#   '운행중',
#   '2022-03-08',
#   '한국승강기안전공단 서울서부지사',
#   '2022-03-08',
#   '1단지-외부1',
#   '2022-03-08',
#   '설치',
#   '보완후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920180023',
#   '현대엘리베이터(주)강서지사',
#   '02-6920-7805',
#   'N',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '2',
#   '-',
#   'B1-1',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-03-08',
#   '2023-03-07',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '1',
#   '1',
#   '0152586',
#   '021',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '7252',
#   'WBSS(E)(M)',
#   '--',
#   '운행중',
#   '2022-03-08',
#   '한국승강기안전공단 서울서부지사',
#   '2022-03-08',
#   '2단지-외부1',
#   '2022-03-08',
#   '설치',
#   '보완후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920180023',
#   '현대엘리베이터(주)강서지사',
#   '02-6920-7805',
#   'N',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '1 M/MIN',
#   '2',
#   '-',
#   '1-2',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-03-08',
#   '2023-03-07',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '1',
#   '2',
#   '0152612',
#   '035',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애/전망용',
#   '122',
#   '7253',
#   'WBSS(E)(M)',
#   '--',
#   '운행중',
#   '2022-03-08',
#   '한국승강기안전공단 서울서부지사',
#   '2022-03-08',
#   '썬큰',
#   '2022-03-08',
#   '설치',
#   '보완후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920180023',
#   '현대엘리베이터(주)강서지사',
#   '02-6920-7805',
#   'N',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '3',
#   '-',
#   'B2-1',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '20',
#   '3',
#   '0150171',
#   '01',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7124',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-05-27',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-27',
#   '101-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '23',
#   '-',
#   'B3-20',
#   '122',
#   '03',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '20',
#   '3',
#   '0150172',
#   '02',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7125',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-05-27',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-27',
#   '101-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '23',
#   '-',
#   'B3-20',
#   '122',
#   '03',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '18',
#   '3',
#   '0150173',
#   '05',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7126',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-05-27',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-27',
#   '103-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '21',
#   '-',
#   'B3-18',
#   '122',
#   '03',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '18',
#   '3',
#   '0150174',
#   '06',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7127',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-05-27',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-27',
#   '103-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '21',
#   '-',
#   'B3-18',
#   '122',
#   '03',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '22',
#   '3',
#   '0150193',
#   '03',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7133',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-09',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-09',
#   '102-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '25',
#   '-',
#   'B3-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '22',
#   '3',
#   '0150194',
#   '04',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7134',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-09',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-09',
#   '102-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '25',
#   '-',
#   'B3-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '12',
#   '3',
#   '0150188',
#   '015',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7135',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-09',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-09',
#   '204-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '14',
#   '-',
#   'B3-12',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '12',
#   '3',
#   '0150189',
#   '016',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7136',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-09',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-09',
#   '204-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '14',
#   '-',
#   'B3-12',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '7',
#   '3',
#   '0150190',
#   '017',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7137',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-09',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-09',
#   '205-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '9',
#   '-',
#   'B3-7',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-20',
#   '2023-01-19',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '7',
#   '3',
#   '0150191',
#   '019',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7138',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-09',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-09',
#   '206-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '9',
#   '-',
#   'B3-7',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '9',
#   '3',
#   '0150235',
#   '018',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7139',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-29',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-29',
#   '205-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '11',
#   '-',
#   'B3-9',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-20',
#   '2023-01-19',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '12',
#   '3',
#   '0150236',
#   '020',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7140',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-29',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-29',
#   '206-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '14',
#   '-',
#   'B3-12',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '22',
#   '3',
#   '0150233',
#   '013',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7148',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-29',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-29',
#   '203-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '25',
#   '-',
#   'B3-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '22',
#   '3',
#   '0150234',
#   '014',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7149',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-29',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-29',
#   '203-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '25',
#   '-',
#   'B3-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '20',
#   '3',
#   '0150414',
#   '09',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7179',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-10-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-10-13',
#   '201-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '23',
#   '-',
#   'B3-20',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '20',
#   '3',
#   '0150415',
#   '010',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7180',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-10-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-10-13',
#   '201-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '23',
#   '-',
#   'B3-20',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '22',
#   '3',
#   '0150416',
#   '011',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7181',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-10-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-10-13',
#   '202-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '25',
#   '-',
#   'B3-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '22',
#   '3',
#   '0150417',
#   '012',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7182',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-10-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-10-13',
#   '202-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '25',
#   '-',
#   'B3-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-20',
#   '2023-01-19',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '30',
#   '2',
#   '0150418',
#   '23',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7183',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-10-14',
#   '한국승강기안전공단 서울서부지사',
#   '2021-10-14',
#   '301-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '32',
#   '-',
#   'B2-30',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-20',
#   '2023-01-19',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '30',
#   '2',
#   '0150419',
#   '24',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7184',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-10-14',
#   '한국승강기안전공단 서울서부지사',
#   '2021-10-14',
#   '301-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '32',
#   '-',
#   'B2-30',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-21',
#   '2023-01-20',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '29',
#   '2',
#   '0150420',
#   '25',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7185',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-10-14',
#   '한국승강기안전공단 서울서부지사',
#   '2021-10-14',
#   '301-3',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '31',
#   '-',
#   'B2-29',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-21',
#   '2023-01-20',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '30',
#   '2',
#   '0150491',
#   '26',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7186',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-11-04',
#   '한국승강기안전공단 서울서부지사',
#   '2021-11-04',
#   '302-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '32',
#   '-',
#   'B2-30',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-21',
#   '2023-01-20',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '30',
#   '2',
#   '0150492',
#   '27',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7187',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-11-04',
#   '한국승강기안전공단 서울서부지사',
#   '2021-11-04',
#   '302-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '32',
#   '-',
#   'B2-30',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-21',
#   '2023-01-20',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '30',
#   '2',
#   '0150493',
#   '28',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7188',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-11-04',
#   '한국승강기안전공단 서울서부지사',
#   '2021-11-04',
#   '302-3',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '32',
#   '-',
#   'B2-30',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-24',
#   '2023-01-23',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '27',
#   '2',
#   '0150486',
#   '29',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7189',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-11-04',
#   '한국승강기안전공단 서울서부지사',
#   '2021-11-04',
#   '303-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B2-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-26',
#   '2023-01-25',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '27',
#   '2',
#   '0150487',
#   '30',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7190',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-11-04',
#   '한국승강기안전공단 서울서부지사',
#   '2021-11-04',
#   '303-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B2-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-26',
#   '2023-01-25',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '27',
#   '2',
#   '0150488',
#   '31',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7191',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-11-04',
#   '한국승강기안전공단 서울서부지사',
#   '2021-11-04',
#   '303-3',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B2-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-26',
#   '2023-01-25',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '26',
#   '2',
#   '0150331',
#   '32',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7192',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-08-18',
#   '한국승강기안전공단 서울서부지사',
#   '2021-08-18',
#   '304-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '28',
#   '-',
#   'B2-26',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-24',
#   '2023-01-23',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '27',
#   '2',
#   '0150332',
#   '33',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7193',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-08-24',
#   '한국승강기안전공단 서울서부지사',
#   '2021-08-24',
#   '304-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B2-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   ' ',
#   '2022-01-24',
#   '2023-01-23',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '27',
#   '2',
#   '0150333',
#   '34',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7194',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-08-24',
#   '한국승강기안전공단 서울서부지사',
#   '2021-08-24',
#   '304-3',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B2-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로22가길 5-1',
#   '(수색동, DMC 갤러리아 B)',
#   '2022-08-26',
#   '2023-08-25',
#   '01',
#   '122',
#   '3433',
#   'DMC갤러리아B동',
#   '공동주택-분양',
#   '5',
#   '0',
#   '0146088',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '6918',
#   'WBSS-GY-2(M)',
#   '--',
#   '운행중',
#   '2020-08-26',
#   '한국승강기안전공단 서울서부지사',
#   '2020-08-26',
#   '1-1',
#   '2022-11-02',
#   '정기',
#   '합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920010079',
#   '정우엘리베이터(주)',
#   '02-306-9483',
#   'N',
#   '(주)위듀 부동산종합관리',
#   '02-356-8***',
#   '--',
#   '-',
#   '13 인승',
#   '1 M/MIN',
#   '5',
#   '-',
#   '1-5',
#   '122',
#   '03',
#   '-',
#   '034',
#   '87']]

# %%
data = []
for item in soup.items :
    temp = []
    for t in item :
        temp.append(t.text.strip())
        # print(t.text)
        # print('------')  
    data.append(temp)

# %%
data
# Out:
# [['서울특별시 은평구 연서로 71',
#   '(역촌동)',
#   '2022-05-24',
#   '2023-05-23',
#   '01',
#   '122',
#   '236',
#   '(재)살림이',
#   '제2종근린생활시설-기타',
#   '5',
#   '1',
#   '0081201',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '440',
#   'SCN5NKZi(412,S)',
#   '--',
#   '운행중',
#   '1998-01-15',
#   '한국승강기안전공단 서울서부지사',
#   '1998-01-15',
#   '1-1',
#   '2022-05-24',
#   '수시',
#   '합격',
#   '550 KG',
#   '엘지산전(주) 창원공장',
#   '055-269-4114',
#   '919920032',
#   '919990047',
#   '(주)제일승강기',
#   '031-908-8681',
#   'Y',
#   '승강기 담당자',
#   '010-9884-1***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '6',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B1-5',
#   '122',
#   '1',
#   '-',
#   '034',
#   '17'],
#  ['서울특별시 은평구 통일로71길 16',
#   '(대조동)',
#   '2022-09-29',
#   '2023-09-28',
#   '01',
#   '122',
#   '889',
#   '(주)KT 은평지사',
#   '업무시설-기타',
#   '4',
#   '1',
#   '0042569',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '1760',
#   'Di1',
#   '--',
#   '운행중',
#   '2005-08-24',
#   '한국승강기안전공단 서울서부지사',
#   '2005-08-24',
#   '1-1',
#   '2022-10-11',
#   '정기',
#   '합격',
#   '1150 KG',
#   '오티스엘리베이터(유)창원공장',
#   '055-289-8235',
#   '919990124',
#   '919920075',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   'Y',
#   '김봉수(설비실장)',
#   '010-3043-1***',
#   '--',
#   '-',
#   '17 인승',
#   '1.5 M/MIN',
#   '4',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-4',
#   '122',
#   '1',
#   '-',
#   '033',
#   '91'],
#  ['서울특별시 은평구 통일로71길 16',
#   '(대조동)',
#   '2022-09-29',
#   '2023-09-28',
#   '01',
#   '122',
#   '889',
#   '(주)KT 은평지사',
#   '업무시설-기타',
#   '4',
#   '1',
#   '0042570',
#   '2',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '1881',
#   'Di1',
#   '--',
#   '운행중',
#   '2006-10-24',
#   '한국승강기안전공단 서울서부지사',
#   '2006-10-24',
#   '1-2',
#   '2022-10-11',
#   '정밀',
#   '조건부합격',
#   '1150 KG',
#   '오티스엘리베이터(유)창원공장',
#   '055-289-8235',
#   '919990124',
#   '919920075',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   'Y',
#   '김봉수(설비실장)',
#   '010-3043-1***',
#   '--',
#   '-',
#   '17 인승',
#   '1.5 M/MIN',
#   '5',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B1-4',
#   '122',
#   '1',
#   '-',
#   '033',
#   '91'],
#  ['서울특별시 은평구 은평로13길 12-1',
#   '해명빌딩 (녹번동)',
#   '2022-04-14',
#   '2022-10-13',
#   '01',
#   '122',
#   '43',
#   '(주)녹번해명(해명빌딩)',
#   '제2종근린생활시설-기타',
#   '5',
#   '1',
#   '0104893',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '138',
#   '확인불가',
#   '--',
#   '운행중',
#   '1991-06-10',
#   '한국승강기안전공단 서울서부지사',
#   '1991-06-10',
#   '1-1',
#   '2022-11-03',
#   '정기',
#   '조건부합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919990073',
#   '명성엘리베이터(주)',
#   '02-2616-2404',
#   'Y',
#   '관리소장 (민정훈)',
#   '(02)388-1***',
#   '--',
#   '-',
#   '17 인승',
#   '1 M/MIN',
#   '6',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B1-5',
#   '122',
#   '8',
#   '-',
#   '034',
#   '59'],
#  ['서울특별시 은평구 은평로13길 12-1',
#   '해명빌딩 (녹번동)',
#   '2022-03-27',
#   '2022-09-26',
#   '01',
#   '122',
#   '43',
#   '(주)녹번해명(해명빌딩)',
#   '제2종근린생활시설-기타',
#   '5',
#   '1',
#   '0004213',
#   '2',
#   '엘리베이터',
#   '유압식-교류',
#   '자동차용',
#   '122',
#   '139',
#   '확인불가',
#   '--',
#   '운행중',
#   '1991-06-10',
#   '한국승강기안전공단 서울서부지사',
#   '1991-06-10',
#   '1-2',
#   '2022-11-03',
#   '정기',
#   '조건부합격',
#   '2000 KG',
#   '영진엘리베이터(주)',
#   '032-815-7871',
#   '919930210',
#   '919990073',
#   '명성엘리베이터(주)',
#   '02-2616-2404',
#   'Y',
#   '관리소장 (민정훈)',
#   '(02)388-1***',
#   '--',
#   '-',
#   '0 인승',
#   '.33 M/MIN',
#   '2',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B1-1',
#   '122',
#   '8',
#   '-',
#   '034',
#   '59'],
#  ['서울특별시 은평구 응암로 165',
#   '(응암동)',
#   '2022-08-09',
#   '2023-08-08',
#   '01',
#   '122',
#   '2669',
#   '(주)사과마을',
#   '판매시설-기타',
#   '2',
#   '0',
#   '0120103',
#   '2',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '5517',
#   'WBSS2',
#   '--',
#   '운행중',
#   '2016-12-23',
#   '한국승강기안전공단 서울서부지사',
#   '2016-12-23',
#   '1-2',
#   '2022-09-06',
#   '정기',
#   '조건후합격',
#   '1600 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919930409',
#   '현대엘리베이터(주)서울사무소',
#   '1577-0603',
#   'N',
#   '조승현(승강기담당)',
#   '02-308-1***',
#   '--',
#   '-',
#   '24 인승',
#   '1 M/MIN',
#   '2',
#   '-',
#   '1-2',
#   '122',
#   '3',
#   '-',
#   '034',
#   '85'],
#  ['서울특별시 은평구 통일로 874',
#   '(불광동)',
#   '2021-08-25',
#   '2022-08-24',
#   '01',
#   '122',
#   '779',
#   '(주)연신개발(연신빌딩)',
#   '제1종근린생활시설-기타',
#   '8',
#   '0',
#   '0068472',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '1513',
#   'Di1',
#   '--',
#   '운행중',
#   '2004-08-25',
#   '한국승강기안전공단 서울서부지사',
#   '2004-08-25',
#   '1-1',
#   '2021-10-18',
#   '정기',
#   '합격',
#   '750 KG',
#   '오티스엘리베이터(유)창원공장',
#   '055-289-8235',
#   '919990124',
#   '919920075',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   'Y',
#   '이성혁',
#   '02-355-3***',
#   '--',
#   '-',
#   '11 인승',
#   '1 M/MIN',
#   '8',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-8',
#   '122',
#   '1',
#   '-',
#   '033',
#   '44'],
#  ['서울특별시 은평구 통일로66길 6-10',
#   '(불광동)',
#   '2021-11-12',
#   '2022-11-11',
#   '01',
#   '122',
#   '1487',
#   '115하우스',
#   '공동주택-분양',
#   '9',
#   '0',
#   '0083623',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '3730',
#   'GR1',
#   '--',
#   '운행중',
#   '2011-10-18',
#   '한국승강기안전공단 서울서부지사',
#   '2011-10-18',
#   '1-1',
#   '2022-02-11',
#   '정기',
#   '합격',
#   '550 KG',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   '919920075',
#   '919920075',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   'N',
#   '승강기 담당자',
#   '010-3844-6***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '9',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-9',
#   '122',
#   '3',
#   '-',
#   '033',
#   '68'],
#  ['서울특별시 은평구 은평로 210',
#   '(응암동)',
#   '2022-05-24',
#   '2023-05-23',
#   '01',
#   '122',
#   '12',
#   'A.G.M빌딩',
#   '제2종근린생활시설-기타',
#   '5',
#   '0',
#   '0004227',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '223',
#   'WBLX-GX-2(M)',
#   '--',
#   '운행중',
#   '1989-06-01',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-24',
#   '1-1',
#   '2022-08-16',
#   '정기',
#   '합격',
#   '550 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919990085',
#   '대한주차관리(주)',
#   '02-852-4417',
#   'Y',
#   '승강기담당 (양찬영)',
#   '010-3283-9***',
#   '-',
#   '-',
#   '7 인승',
#   '1 M/MIN',
#   '5',
#   '-',
#   '1-5',
#   '122',
#   '3',
#   '-',
#   '034',
#   '72'],
#  ['서울특별시 은평구 은평로 210',
#   '(응암동)',
#   '2022-07-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '12',
#   'A.G.M빌딩',
#   '제2종근린생활시설-기타',
#   '1',
#   '1',
#   '0103615',
#   '2',
#   '엘리베이터',
#   '유압식-교류',
#   '자동차용',
#   '122',
#   '224',
#   '확인불가',
#   '--',
#   '운행중',
#   '1989-06-01',
#   '한국승강기안전공단 서울서부지사',
#   '1989-06-01',
#   '1-2',
#   '2022-08-16',
#   '정기',
#   '조건부합격',
#   '2000 KG',
#   '기타(KTL)',
#   '999999900',
#   '919990085',
#   '대한주차관리(주)',
#   '02-852-4417',
#   'Y',
#   '승강기담당 (양찬영)',
#   '010-3283-9***',
#   '--',
#   '-',
#   '.33 M/MIN',
#   '2',
#   '-',
#   'B1-1',
#   '122',
#   '20',
#   '-',
#   '034',
#   '72'],
#  ['서울특별시 은평구 통일로87길 14',
#   '(갈현동)',
#   '2022-02-26',
#   '2023-02-25',
#   '01',
#   '122',
#   '471',
#   'A1빌딩',
#   '제2종근린생활시설-기타',
#   '5',
#   '0',
#   '0041811',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '1953',
#   'Di1',
#   '--',
#   '운행중',
#   '2002-10-19',
#   '한국승강기안전공단 서울서부지사',
#   '2007-06-07',
#   '1-1',
#   '2022-07-12',
#   '정기',
#   '합격',
#   '750 KG',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   '919920075',
#   '919920075',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   'Y',
#   '장승기',
#   '010-6517-3***',
#   '--',
#   '-',
#   '11 인승',
#   '1 M/MIN',
#   '5',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-5',
#   '122',
#   '1',
#   '-',
#   '033',
#   '28'],
#  ['서울특별시 은평구 통일로 585-1',
#   '(응암동)',
#   '2022-06-30',
#   '2023-06-29',
#   '01',
#   '122',
#   '1919',
#   'AVENUE호텔',
#   '업무시설-기타',
#   '12',
#   '0',
#   '0105742',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '4315',
#   'WBST1',
#   '--',
#   '운행중',
#   '2014-06-30',
#   '한국승강기안전공단 서울서부지사',
#   '2014-06-30',
#   '1-1(좌)',
#   '2022-09-28',
#   '정기',
#   '조건부합격',
#   '900 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919930409',
#   '현대엘리베이터(주)서울사무소',
#   '1577-0603',
#   'Y',
#   '박종천',
#   '02)350-6***',
#   '--',
#   '-',
#   '13 인승',
#   '1.5 M/MIN',
#   '12',
#   '-',
#   '1-12',
#   '122',
#   '3',
#   '정우엘리베이터(주)',
#   '034',
#   '73'],
#  ['서울특별시 은평구 통일로 585-1',
#   '(응암동)',
#   '2022-06-30',
#   '2023-06-29',
#   '01',
#   '122',
#   '1919',
#   'AVENUE호텔',
#   '업무시설-기타',
#   '12',
#   '0',
#   '0105743',
#   '2',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '4316',
#   'WBST1',
#   '--',
#   '운행중',
#   '2014-06-30',
#   '한국승강기안전공단 서울서부지사',
#   '2014-06-30',
#   '1-2(우)',
#   '2022-09-28',
#   '정기',
#   '합격',
#   '600 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919930409',
#   '현대엘리베이터(주)서울사무소',
#   '1577-0603',
#   'Y',
#   '박종천',
#   '02)350-6***',
#   '--',
#   '-',
#   '9 인승',
#   '1.5 M/MIN',
#   '12',
#   '-',
#   '1-12',
#   '122',
#   '3',
#   '정우엘리베이터(주)',
#   '034',
#   '73'],
#  ['서울특별시 은평구 은평로2길 6-18',
#   '(신사동)',
#   '2022-07-10',
#   '2023-07-09',
#   '01',
#   '122',
#   '1331',
#   'A플러스 빌',
#   '제2종근린생활시설-기타',
#   '7',
#   '0',
#   '0103174',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '3367',
#   'STVF-7',
#   '--',
#   '운행중',
#   '2010-11-15',
#   '한국승강기안전공단 서울서부지사',
#   '2010-11-15',
#   '1-1',
#   '2022-10-11',
#   '정기',
#   '합격',
#   '600 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919930409',
#   '현대엘리베이터(주)서울사무소',
#   '1577-0603',
#   'Y',
#   '정윤수',
#   '02-387-6***',
#   '--',
#   '-',
#   '9 인승',
#   '1 M/MIN',
#   '7',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-7',
#   '122',
#   '3',
#   '정우엘리베이터(주)',
#   '034',
#   '50'],
#  ['서울특별시 은평구 통일로 689-7',
#   '(녹번동)',
#   '2022-03-06',
#   '2023-03-05',
#   '01',
#   '122',
#   '2741',
#   'B.L 빌리지',
#   '공동주택-민영임대(민간건설사)',
#   '5',
#   '0',
#   '0120304',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '5609',
#   'WBSS2',
#   '--',
#   '운행중',
#   '2017-03-06',
#   '한국승강기안전공단 서울서부지사',
#   '2017-03-06',
#   '1-1',
#   '2022-07-21',
#   '정기',
#   '합격',
#   '600 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920160023',
#   '한국엘리베이터보수관리(주)',
#   '032-546-4222',
#   'N',
#   '김용덕',
#   '010-4272-7***',
#   '--',
#   '-',
#   '9 인승',
#   '1 M/MIN',
#   '5',
#   '-',
#   '1-5',
#   '122',
#   '3',
#   '-',
#   '033',
#   '75'],
#  ['서울특별시 은평구 연서로 520',
#   '(진관동)',
#   '2021-11-27',
#   '2022-11-26',
#   '01',
#   '122',
#   '3311',
#   'BC빌딩',
#   '제2종근린생활시설-기타',
#   '6',
#   '0',
#   '0138790',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '6750',
#   'WBSS2',
#   '--',
#   '운행중',
#   '2019-11-27',
#   '한국승강기안전공단 서울서부지사',
#   '2019-11-27',
#   '1-1',
#   '2022-02-18',
#   '정기',
#   '합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'N',
#   '김병창',
#   '010-8777-3***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '6',
#   '-',
#   '1-6',
#   '122',
#   '3',
#   '-',
#   '033',
#   '08'],
#  ['서울특별시 은평구 연서로13길 29-6 (구산동)',
#   '',
#   '2022-08-18',
#   '2023-08-17',
#   '01',
#   '122',
#   '3540',
#   'BOMIN ASTRO',
#   '공동주택-분양',
#   '6',
#   '0',
#   '0150214',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '7142',
#   'K-NP-MRL-P1(M)',
#   '--',
#   '운행중',
#   '2021-06-17',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-17',
#   '1-1',
#   '2022-08-18',
#   '정기',
#   '합격',
#   '900 KG',
#   '한국미쓰비시엘리베이터(주)(서울)',
#   '02-6670-2152',
#   '920020007',
#   '920180086',
#   '한국미쓰비시엘리베이터(주)강북1',
#   '02-921-3114',
#   'N',
#   '김형기',
#   '***',
#   '--',
#   '-',
#   '12 인승',
#   '1 M/MIN',
#   '6',
#   '-',
#   '1-6',
#   '122',
#   '3',
#   '-',
#   '034',
#   '14'],
#  ['서울특별시 은평구 통일로71길 6',
#   '(대조동)',
#   '2022-07-29',
#   '2023-07-28',
#   '01',
#   '122',
#   '2183',
#   'Babyjjam',
#   '제2종근린생활시설-기타',
#   '5',
#   '1',
#   '0074954',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '4708',
#   'TK-50CS',
#   '--',
#   '운행중',
#   '2015-07-29',
#   '한국승강기안전공단 서울서부지사',
#   '2015-07-29',
#   '1-1',
#   '2022-09-19',
#   '정기',
#   '조건부합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919981550',
#   '(주)신한엘리베이터',
#   '02-2026-6700',
#   'N',
#   '김정민',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '6',
#   '-',
#   'B1-5',
#   '122',
#   '3',
#   '-',
#   '033',
#   '91'],
#  ['서울특별시 은평구 통일로53길 9-6',
#   'C.H.L연립주택',
#   '2022-04-13',
#   '2022-10-12',
#   '01',
#   '122',
#   '40',
#   'C.H.L연립주택',
#   '공동주택-분양',
#   '4',
#   '1',
#   '0039283',
#   '1',
#   '엘리베이터',
#   '권상식-교류',
#   '승객용',
#   '122',
#   '86',
#   '확인불가',
#   '--',
#   '운행중',
#   '1995-03-10',
#   '한국승강기안전공단 서울서부지사',
#   '1995-03-10',
#   '1-1',
#   '2022-05-27',
#   '정기',
#   '합격',
#   '450 KG',
#   '영진기계',
#   '02-867-5337',
#   '919930209',
#   '919930353',
#   '(주)화신엘리베이터공사',
#   '02-776-4939',
#   'Y',
#   '장인주',
#   '***',
#   '--',
#   '-',
#   '6 인승',
#   '1 M/MIN',
#   '5',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B1-4',
#   '122',
#   '8',
#   '-',
#   '033',
#   '82'],
#  ['서울특별시 은평구 서오릉로 30',
#   '(녹번동)',
#   '2022-05-12',
#   '2023-05-11',
#   '01',
#   '122',
#   '2723',
#   'C.S 아르체',
#   '공동주택-분양',
#   '11',
#   '1',
#   '0125129',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '5724',
#   'GM3(7)',
#   '--',
#   '운행중',
#   '2017-05-12',
#   '한국승강기안전공단 서울서부지사',
#   '2017-05-12',
#   '1-1',
#   '2022-06-27',
#   '정기',
#   '합격',
#   '1000 KG',
#   '(주)금영제너럴',
#   '02-2056-1117',
#   '920070033',
#   '920070033',
#   '(주)금영제너럴',
#   '02-2056-1117',
#   'N',
#   '주택관리 담당자',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.5 M/MIN',
#   '12',
#   '-',
#   'B1-11',
#   '122',
#   '3',
#   '-',
#   '033',
#   '80'],
#  ['서울특별시 은평구 서오릉로 30',
#   '(녹번동)',
#   '2022-05-10',
#   '2023-05-09',
#   '01',
#   '122',
#   '2723',
#   'C.S 아르체',
#   '공동주택-분양',
#   '6',
#   '1',
#   '0120302',
#   '2',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '5587',
#   'GM3(10)',
#   '--',
#   '운행중',
#   '2017-05-04',
#   '한국승강기안전공단 서울서부지사',
#   '2017-05-04',
#   '1-2',
#   '2022-06-27',
#   '정기',
#   '합격',
#   '900 KG',
#   '(주)금영제너럴',
#   '02-2056-1117',
#   '920070033',
#   '920070033',
#   '(주)금영제너럴',
#   '02-2056-1117',
#   'N',
#   '주택관리 담당자',
#   '***',
#   '--',
#   '-',
#   '13 인승',
#   '1 M/MIN',
#   '7',
#   '-',
#   'B1-6',
#   '122',
#   '3',
#   '-',
#   '033',
#   '80'],
#  ['서울특별시 은평구 서오릉로 30',
#   '(녹번동)',
#   '2022-05-10',
#   '2023-05-09',
#   '01',
#   '122',
#   '2723',
#   'C.S 아르체',
#   '공동주택-분양',
#   '6',
#   '1',
#   '0120303',
#   '3',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '5588',
#   'GM3(10)',
#   '--',
#   '운행중',
#   '2017-05-04',
#   '한국승강기안전공단 서울서부지사',
#   '2017-05-04',
#   '1-3',
#   '2022-06-27',
#   '정기',
#   '합격',
#   '900 KG',
#   '(주)금영제너럴',
#   '02-2056-1117',
#   '920070033',
#   '920070033',
#   '(주)금영제너럴',
#   '02-2056-1117',
#   'N',
#   '주택관리 담당자',
#   '***',
#   '--',
#   '-',
#   '13 인승',
#   '1 M/MIN',
#   '7',
#   '-',
#   'B1-6',
#   '122',
#   '3',
#   '-',
#   '033',
#   '80'],
#  ['서울특별시 은평구 은평로 91',
#   '(응암동)',
#   '2022-06-21',
#   '2023-06-20',
#   '01',
#   '122',
#   '764',
#   'CJ드림시티오피스텔',
#   '업무시설-기타',
#   '15',
#   '3',
#   '0041739',
#   '3',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '1502',
#   'CV-150L',
#   '--',
#   '운행중',
#   '2004-06-28',
#   '한국승강기안전공단 서울서부지사',
#   '2004-06-28',
#   'B-1',
#   '2022-08-16',
#   '정기',
#   '합격',
#   '1150 KG',
#   '도시바엘리베이터코리아(주)_폐업',
#   '02-771-7490',
#   '920030001',
#   '919981684',
#   '성도엘리베이터(주)',
#   '02-324-3567',
#   'Y',
#   '승강기담당자',
#   '02-357-8***',
#   '--',
#   '-',
#   '17 인승',
#   '1.5 M/MIN',
#   '18',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B3-15',
#   '122',
#   '12',
#   '-',
#   '034',
#   '61'],
#  ['서울특별시 은평구 은평로 91',
#   '(응암동)',
#   '2022-06-21',
#   '2023-06-20',
#   '01',
#   '122',
#   '764',
#   'CJ드림시티오피스텔',
#   '업무시설-기타',
#   '15',
#   '3',
#   '0041737',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '1503',
#   'CV-150L',
#   '--',
#   '운행중',
#   '2004-06-28',
#   '한국승강기안전공단 서울서부지사',
#   '2004-06-28',
#   'A-1',
#   '2022-08-16',
#   '정기',
#   '조건부합격',
#   '1150 KG',
#   '도시바엘리베이터코리아(주)_폐업',
#   '02-771-7490',
#   '920030001',
#   '919981684',
#   '성도엘리베이터(주)',
#   '02-324-3567',
#   'Y',
#   '승강기담당자',
#   '02-357-8***',
#   '--',
#   '-',
#   '17 인승',
#   '1.5 M/MIN',
#   '15',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-15',
#   '122',
#   '12',
#   '-',
#   '034',
#   '61'],
#  ['서울특별시 은평구 은평로 91',
#   '(응암동)',
#   '2022-06-21',
#   '2023-06-20',
#   '01',
#   '122',
#   '764',
#   'CJ드림시티오피스텔',
#   '업무시설-기타',
#   '14',
#   '2',
#   '0041738',
#   '2',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '1535',
#   'CV-150L',
#   '--',
#   '운행중',
#   '2004-08-10',
#   '한국승강기안전공단 서울서부지사',
#   '2004-08-10',
#   'A-2',
#   '2022-08-16',
#   '정기',
#   '합격',
#   '600 KG',
#   '도시바엘리베이터코리아(주)_폐업',
#   '02-771-7490',
#   '920030001',
#   '919981684',
#   '성도엘리베이터(주)',
#   '02-324-3567',
#   'Y',
#   '승강기담당자',
#   '02-357-8***',
#   '--',
#   '-',
#   '9 인승',
#   '1.5 M/MIN',
#   '16',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B2-14',
#   '122',
#   '12',
#   '-',
#   '034',
#   '61'],
#  ['서울특별시 은평구 불광로 55',
#   '(불광동)',
#   '2022-05-24',
#   '2023-05-23',
#   '01',
#   '122',
#   '3060',
#   'CML큐브',
#   '단독주택-다가구주택',
#   '6',
#   '0',
#   '0129256',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '6108',
#   'WBSS2',
#   '--',
#   '운행중',
#   '2018-05-24',
#   '한국승강기안전공단 서울서부지사',
#   '2018-05-24',
#   '1-1',
#   '2022-07-28',
#   '정기',
#   '합격',
#   '550 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920180023',
#   '현대엘리베이터(주)강서지사',
#   '02-6920-7805',
#   'N',
#   '문현아(승강기담당자)',
#   '010-8728-0***',
#   '--',
#   '-',
#   '8 인승',
#   '1.5 M/MIN',
#   '6',
#   '-',
#   '1-6',
#   '122',
#   '03',
#   '-',
#   '033',
#   '58'],
#  ['서울특별시 은평구 응암로 308',
#   '(응암동)',
#   '2021-06-24',
#   '2022-06-23',
#   '01',
#   '122',
#   '1744',
#   'CM빌딩',
#   '제2종근린생활시설-기타',
#   '5',
#   '0',
#   '0080675',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '4101',
#   'SSVF7',
#   '--',
#   '운행중',
#   '2013-06-24',
#   '한국승강기안전공단 서울서부지사',
#   '2013-06-24',
#   '1-1',
#   '2021-07-29',
#   '정기',
#   '조건부합격',
#   '900 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919930409',
#   '현대엘리베이터(주)서울사무소',
#   '1577-0603',
#   'N',
#   '신화숙',
#   '02-354-9***',
#   '--',
#   '-',
#   '13 인승',
#   '1 M/MIN',
#   '5',
#   '-',
#   '1-5',
#   '122',
#   '3',
#   '정우엘리베이터(주)',
#   '034',
#   '64'],
#  ['서울특별시 은평구 갈현로 141',
#   '(구산동)',
#   '2022-05-19',
#   '2023-05-18',
#   '01',
#   '122',
#   '858',
#   'CN빌',
#   '공동주택-분양',
#   '6',
#   '0',
#   '0006130',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '1640',
#   'Si1',
#   '--',
#   '운행중',
#   '2005-03-30',
#   '(재)승강기안전기술연구원 서울지원',
#   '2005-03-30',
#   '1-1',
#   '2022-06-20',
#   '정기',
#   '합격',
#   '550 KG',
#   '오티스엘리베이터(유)창원공장',
#   '055-289-8235',
#   '919990124',
#   '920040051',
#   '(주)쉰들러엘리베이터 서울',
#   '02-3470-2509',
#   'Y',
#   '장경순(승강기담당)',
#   '010-9054-2***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '6',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-6',
#   '122',
#   '5',
#   '-',
#   '034',
#   '29'],
#  ['서울특별시 은평구 연서로20길 13',
#   '(대조동, 씨티뷰)',
#   '2021-12-07',
#   '2022-12-06',
#   '01',
#   '122',
#   '1982',
#   'CN씨티뷰',
#   '공동주택-분양',
#   '6',
#   '0',
#   '0073834',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '4427',
#   'TK-50CS',
#   '--',
#   '운행중',
#   '2014-09-29',
#   '한국승강기안전공단 서울서부지사',
#   '2014-09-29',
#   '1-1',
#   '2022-05-09',
#   '정기',
#   '조건후합격',
#   '550 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'N',
#   '승강기담당자(박세규)',
#   '010-8722-9***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '6',
#   '-',
#   '1-6',
#   '122',
#   '3',
#   '성도엘리베이터(주)',
#   '033',
#   '87'],
#  ['서울특별시 은평구 진흥로 183',
#   '(대조동)',
#   '2021-12-06',
#   '2022-12-05',
#   '01',
#   '122',
#   '322',
#   'CS모텔',
#   '숙박시설-숙박시설',
#   '7',
#   '1',
#   '0084992',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '597',
#   'Di1',
#   '--',
#   '운행중',
#   '2000-12-15',
#   '한국승강기안전공단 서울서부지사',
#   '2000-12-15',
#   '1-1',
#   '2022-04-04',
#   '정기',
#   '조건후합격',
#   '550 KG',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   '919920075',
#   '920050036',
#   '(주)승조엔지니어링',
#   '02-2698-6007',
#   'Y',
#   '승강기담당자',
#   '(02)353-0***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '7',
#   '선임(운행관리자정보없음)',
#   '-',
#   '1-7',
#   '122',
#   '1',
#   '-',
#   '033',
#   '97'],
#  ['서울특별시 은평구 진흥로9길 8-4',
#   '(역촌동)',
#   '2022-04-22',
#   '2023-04-21',
#   '01',
#   '122',
#   '2452',
#   'CS아르체',
#   '공동주택-분양',
#   '8',
#   '0',
#   '0089125',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '5031',
#   'TK-50CS',
#   '--',
#   '운행중',
#   '2016-04-22',
#   '한국승강기안전공단 서울서부지사',
#   '2016-04-22',
#   '1-1',
#   '2022-09-22',
#   '정기',
#   '조건부합격',
#   '630 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919950932',
#   '티센크루프엘리베이터코리아(주)',
#   '02-2610-7777',
#   'N',
#   '김영훈',
#   '***',
#   '--',
#   '-',
#   '9 인승',
#   '1 M/MIN',
#   '8',
#   '-',
#   '1-8',
#   '122',
#   '3',
#   '성도엘리베이터(주)',
#   '034',
#   '04'],
#  ['서울특별시 은평구 역말로9가길 8-1',
#   '(대조동)',
#   '2022-06-14',
#   '2023-06-13',
#   '01',
#   '122',
#   '2495',
#   'CS아르체',
#   '공동주택-분양',
#   '6',
#   '0',
#   '0116380',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '5082',
#   'TK-50CS',
#   '--',
#   '운행중',
#   '2016-06-14',
#   '한국승강기안전공단 서울서부지사',
#   '2016-06-14',
#   '1-1',
#   '2022-09-07',
#   '정기',
#   '합격',
#   '550 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919950932',
#   '티센크루프엘리베이터코리아(주)',
#   '02-2610-7777',
#   'N',
#   '반장님',
#   '***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '6',
#   '-',
#   '1-6',
#   '122',
#   '3',
#   '성도엘리베이터(주)',
#   '033',
#   '89'],
#  ['서울특별시 은평구 응암로21가길 1-7',
#   '(응암동)',
#   '2022-03-25',
#   '2023-03-24',
#   '01',
#   '122',
#   '2417',
#   'CS아르체',
#   '공동주택-분양',
#   '8',
#   '0',
#   '0088931',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '4987',
#   'TK-50CS',
#   '--',
#   '운행중',
#   '2016-03-25',
#   '한국승강기안전공단 서울서부지사',
#   '2016-03-25',
#   '1-1',
#   '2022-08-09',
#   '정기',
#   '합격',
#   '630 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'N',
#   '입주자대표',
#   '010-8080-5***',
#   '--',
#   '-',
#   '9 인승',
#   '1 M/MIN',
#   '8',
#   '-',
#   '1-8',
#   '122',
#   '03',
#   '성도엘리베이터(주)',
#   '034',
#   '56'],
#  ['서울특별시 은평구 불광동 281-76',
#   '',
#   '2022-03-18',
#   '2023-03-17',
#   '01',
#   '122',
#   '3639',
#   'D&J아파트',
#   '공동주택-분양',
#   '12',
#   '0',
#   '0152633',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '7284',
#   'WBSS-GY-2(M)',
#   '--',
#   '운행중',
#   '2022-03-18',
#   '한국승강기안전공단 서울서부지사',
#   '2022-03-18',
#   '1-1',
#   '2022-03-18',
#   '설치',
#   '보완후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'N',
#   '조영대(건축소장)',
#   '***',
#   '--',
#   '-',
#   '13 인승',
#   '1.5 M/MIN',
#   '12',
#   '-',
#   '1-12',
#   '122',
#   '3',
#   '-',
#   '033',
#   '68'],
#  ['서울특별시 은평구 불광로 50-5',
#   '(불광동)',
#   '2022-05-02',
#   '2023-05-01',
#   '01',
#   '122',
#   '3241',
#   'D&J하우징',
#   '업무시설-기타',
#   '10',
#   '0',
#   '0136892',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '6542',
#   'WBSS2',
#   '--',
#   '운행중',
#   '2019-05-02',
#   '한국승강기안전공단 서울서부지사',
#   '2019-05-02',
#   '1-1',
#   '2022-09-27',
#   '정기',
#   '합격',
#   '900 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '919920035',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   'N',
#   '승강기담당자',
#   '***',
#   '--',
#   '-',
#   '13 인승',
#   '1.5 M/MIN',
#   '10',
#   '-',
#   '1-10',
#   '122',
#   '3',
#   '-',
#   '033',
#   '68'],
#  ['서울특별시 은평구 통일로78길 11-7',
#   '(불광동)',
#   '2022-07-31',
#   '2023-07-30',
#   '01',
#   '122',
#   '2848',
#   'D&J하우징',
#   '업무시설-기타',
#   '11',
#   '0',
#   '0125354',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '5807',
#   'WBSS2',
#   '--',
#   '운행중',
#   '2017-07-31',
#   '한국승강기안전공단 서울서부지사',
#   '2017-07-31',
#   '1-1',
#   '2022-10-19',
#   '정기',
#   '조건부합격',
#   '900 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920180023',
#   '현대엘리베이터(주)강서지사',
#   '02-6920-7805',
#   'N',
#   '김락영(승강기담당자)',
#   '02-383-2***',
#   '--',
#   '-',
#   '13 인승',
#   '1.5 M/MIN',
#   '11',
#   '-',
#   '1-11',
#   '122',
#   '3',
#   '-',
#   '033',
#   '50'],
#  ['서울특별시 은평구 통일로 708-7',
#   '(불광동)',
#   '2021-12-20',
#   '2022-12-19',
#   '01',
#   '122',
#   '386',
#   'D.U 모텔',
#   '숙박시설-숙박시설',
#   '8',
#   '1',
#   '0084748',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '883',
#   'Di1',
#   '--',
#   '운행중',
#   '2001-11-26',
#   '(재)승강기안전기술연구원 서울지원',
#   '2001-11-26',
#   '1-1',
#   '2022-01-11',
#   '정기',
#   '합격',
#   '450 KG',
#   '오티스엘리베이터(유)창원공장',
#   '055-289-8235',
#   '919990124',
#   '920010024',
#   '승우엘레텍(주)',
#   '02-2642-2893',
#   'Y',
#   '승강기담당자',
#   '(02)351-3***',
#   '--',
#   '-',
#   '6 인승',
#   '1 M/MIN',
#   '8',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B1-7',
#   '122',
#   '1',
#   '-',
#   '033',
#   '68'],
#  ['서울특별시 은평구 서오릉로 12',
#   '(녹번동)',
#   '2022-08-14',
#   '2023-08-13',
#   '01',
#   '122',
#   '3425',
#   'DH PALACE TOWER',
#   '공동주택-기타',
#   '13',
#   '2',
#   '0146060',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '6901',
#   'WBSS-GY-2(M)',
#   '--',
#   '운행중',
#   '2020-08-14',
#   '한국승강기안전공단 서울서부지사',
#   '2020-08-14',
#   '1-1',
#   '2022-10-13',
#   '정기',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920220019',
#   '대영엘리베이터(주)',
#   '0220633496',
#   'N',
#   '승강기담당자',
#   '02-6928-7***',
#   '-',
#   '-',
#   '13 인승',
#   '1.75 M/MIN',
#   '15',
#   '-',
#   'B2-13',
#   '122',
#   '3',
#   '-',
#   '033',
#   '84'],
#  ['서울특별시 은평구 갈현로15길 20',
#   '(구산동, DH팰리스)',
#   '2021-10-10',
#   '2022-10-09',
#   '01',
#   '122',
#   '2203',
#   'DH팰리스',
#   '공동주택-분양',
#   '6',
#   '0',
#   '0113823',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '4740',
#   'GPR',
#   '--',
#   '운행중',
#   '2015-08-19',
#   '(재)승강기안전기술연구원 서울지원',
#   '2015-08-19',
#   '1-1',
#   '2022-11-01',
#   '정기',
#   '조건부합격',
#   '750 KG',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   '919920075',
#   '919920075',
#   '오티스엘리베이터(유)서울',
#   '02-2007-5800',
#   'N',
#   '승강기담당',
#   '***',
#   '--',
#   '-',
#   '11 인승',
#   '1 M/MIN',
#   '6',
#   '-',
#   '1-6',
#   '122',
#   '03',
#   '-',
#   '034',
#   '29'],
#  ['서울특별시 은평구 은평로21길 16-1',
#   '(녹번동)',
#   '2021-06-08',
#   '2022-06-07',
#   '01',
#   '122',
#   '2502',
#   'DH팰리스 A동',
#   '공동주택-분양',
#   '7',
#   '0',
#   '0116397',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '5094',
#   'TK-50CS',
#   '--',
#   '운행중',
#   '2016-06-08',
#   '한국승강기안전공단 서울서부지사',
#   '2016-06-08',
#   'A동',
#   '2021-07-16',
#   '정기',
#   '합격',
#   '550 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919950932',
#   '티센크루프엘리베이터코리아(주)',
#   '02-2610-7777',
#   'N',
#   'A동 대표',
#   '010-2352-3***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '7',
#   '-',
#   '1-7',
#   '122',
#   '3',
#   '성도엘리베이터(주)',
#   '033',
#   '82'],
#  ['서울특별시 은평구 은평로21길 16',
#   '',
#   '2022-09-17',
#   '2023-09-16',
#   '01',
#   '122',
#   '3363',
#   'DH팰리스 B동',
#   '공동주택-분양',
#   '7',
#   '0',
#   '0116398',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '승객용',
#   '122',
#   '5095',
#   'TK-50CS',
#   '--',
#   '운행중',
#   '2016-06-08',
#   '(재)승강기안전기술연구원 서울지원',
#   '2016-06-08',
#   'B동',
#   '2022-10-20',
#   '정기',
#   '조건후합격',
#   '550 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '920050038',
#   '대명엘리베이터(주)',
#   '02-2043-9950',
#   'N',
#   '승강기담당',
#   '***',
#   '--',
#   '-',
#   '8 인승',
#   '1 M/MIN',
#   '7',
#   '-',
#   '1-7',
#   '122',
#   '3',
#   '-',
#   '033',
#   '82'],
#  ['서울특별시 은평구 역말로 37-6',
#   '(역촌동)',
#   '2022-06-27',
#   '2023-06-26',
#   '01',
#   '122',
#   '589',
#   'DK아파트',
#   '공동주택-분양',
#   '7',
#   '1',
#   '0038838',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '1205',
#   'DY-30A',
#   '--',
#   '운행중',
#   '2003-06-27',
#   '한국승강기안전공단 서울서부지사',
#   '2003-06-27',
#   '1-1',
#   '2022-08-10',
#   '정밀',
#   '합격',
#   '1000 KG',
#   '동양중공업(주)',
#   '031-498-7777',
#   '919930173',
#   '919981684',
#   '성도엘리베이터(주)',
#   '02-324-3567',
#   'Y',
#   '승강기담당자',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '8',
#   '선임(운행관리자정보없음)',
#   '-',
#   'B1-7',
#   '122',
#   '12',
#   '-',
#   '034',
#   '16'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-23',
#   '2022-08-22',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '26',
#   '4',
#   '0150066',
#   '2',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7070',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '101-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B4-26',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-23',
#   '2022-08-22',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '26',
#   '4',
#   '0150067',
#   '3',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7071',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '101-3',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B4-26',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-23',
#   '2022-08-22',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '24',
#   '3',
#   '0150065',
#   '4',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7072',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '102-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '27',
#   '-',
#   'B3-24',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '27',
#   '3',
#   '0150016',
#   '7',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7073',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '103-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '30',
#   '-',
#   'B3-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '27',
#   '3',
#   '0150017',
#   '8',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7074',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '103-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '30',
#   '-',
#   'B3-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '19',
#   '4',
#   '0150018',
#   '9',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7075',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '104-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '23',
#   '-',
#   'B3-19',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '19',
#   '4',
#   '0150019',
#   '10',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7076',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '104-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '23',
#   '-',
#   'B3-19',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-25',
#   '2022-08-24',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '18',
#   '3',
#   '0150041',
#   '13',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7077',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '105-3',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '21',
#   '-',
#   'B3-18',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-25',
#   '2022-08-24',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '16',
#   '4',
#   '0150042',
#   '16',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7080',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '106-3',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '19',
#   '-',
#   'B4-16',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '30',
#   '4',
#   '0150136',
#   '5',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7103',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-05-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-13',
#   '102-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '33',
#   '-',
#   'B4-30',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '30',
#   '4',
#   '0150137',
#   '6',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7104',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-05-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-13',
#   '102-3',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '33',
#   '-',
#   'B4-30',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '27',
#   '3',
#   '0150138',
#   '11',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7105',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-05-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-13',
#   '105-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B3-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-24',
#   '2022-08-23',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '27',
#   '3',
#   '0150139',
#   '12',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7106',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-05-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-13',
#   '105-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B3-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-25',
#   '2022-08-24',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '19',
#   '4',
#   '0150068',
#   '14',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7050',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '106-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '22',
#   '-',
#   'B4-19',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-25',
#   '2022-08-24',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '19',
#   '4',
#   '0150069',
#   '15',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7051',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '106-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '22',
#   '-',
#   'B4-19',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-08-23',
#   '2022-08-22',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '24',
#   '4',
#   '0150046',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7042',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-04-21',
#   '한국승강기안전공단 서울서부지사',
#   '2021-04-21',
#   '101-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '27',
#   '-',
#   'B4-24',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰1단지아파트',
#   '2021-09-30',
#   '2022-08-24',
#   '01',
#   '122',
#   '3504',
#   'DMC SK뷰1단지아파트',
#   '공동주택-분양',
#   '1',
#   '2',
#   '0150343',
#   '17',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '7173',
#   'EVO1(M)',
#   '--',
#   '운행중',
#   '2021-09-30',
#   '한국승강기안전공단 서울서부지사',
#   '2021-09-30',
#   '102커뮤니티',
#   '2021-09-30',
#   '설치',
#   '보완후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'N',
#   '장세진',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '3',
#   '-',
#   'B2-1',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰2단지주상복합',
#   '2021-08-26',
#   '2022-08-25',
#   '01',
#   '122',
#   '3633',
#   'DMC SK뷰2단지주상복합',
#   '공동주택-분양',
#   '21',
#   '5',
#   '0150181',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7120',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-06-03',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-03',
#   '201-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '승강기담당자',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '25',
#   '-',
#   'B5-21',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰2단지주상복합',
#   '2021-08-26',
#   '2022-08-25',
#   '01',
#   '122',
#   '3633',
#   'DMC SK뷰2단지주상복합',
#   '공동주택-분양',
#   '21',
#   '5',
#   '0150182',
#   '2',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7121',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-06-03',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-03',
#   '201-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '승강기담당자',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '25',
#   '-',
#   'B5-21',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰2단지주상복합',
#   '2021-08-26',
#   '2022-08-25',
#   '01',
#   '122',
#   '3633',
#   'DMC SK뷰2단지주상복합',
#   '공동주택-분양',
#   '22',
#   '5',
#   '0150183',
#   '3',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7122',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-06-03',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-03',
#   '202-1',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '승강기담당자',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '26',
#   '-',
#   'B5-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰2단지주상복합',
#   '2021-08-26',
#   '2022-08-25',
#   '01',
#   '122',
#   '3633',
#   'DMC SK뷰2단지주상복합',
#   '공동주택-분양',
#   '22',
#   '5',
#   '0150184',
#   '4',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7123',
#   'GL1(M)',
#   '--',
#   '운행중',
#   '2021-06-03',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-03',
#   '202-2',
#   '2021-09-15',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'Y',
#   '승강기담당자',
#   '02-303-0***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '26',
#   '-',
#   'B5-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 216',
#   'DMC SK뷰2단지주상복합',
#   '2021-09-30',
#   '2022-09-29',
#   '01',
#   '122',
#   '3633',
#   'DMC SK뷰2단지주상복합',
#   '공동주택-분양',
#   '3',
#   '1',
#   '0150344',
#   '5',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '7174',
#   'EVO1(M)',
#   '--',
#   '운행중',
#   '2021-09-30',
#   '한국승강기안전공단 서울서부지사',
#   '2021-09-30',
#   '201커뮤니티',
#   '2021-09-30',
#   '설치',
#   '합격',
#   '1000 KG',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   '919920034',
#   '919920034',
#   '티케이엘리베이터코리아(주)',
#   '02-2610-7869',
#   'N',
#   '승강기담당자',
#   '02-303-0***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '5',
#   '-',
#   'B1-3',
#   '122',
#   '3',
#   '-',
#   '035',
#   '05'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-03-08',
#   '2023-03-07',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '1',
#   '1',
#   '0152585',
#   '08',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '7254',
#   'WBSS(E)(M)',
#   '--',
#   '운행중',
#   '2022-03-08',
#   '한국승강기안전공단 서울서부지사',
#   '2022-03-08',
#   '1단지-외부2',
#   '2022-03-08',
#   '설치',
#   '보완후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920180023',
#   '현대엘리베이터(주)강서지사',
#   '02-6920-7805',
#   'N',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '2',
#   '-',
#   'B1-1',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-03-08',
#   '2023-03-07',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '1',
#   '1',
#   '0152587',
#   '022',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '7255',
#   'WBSS(E)(M)',
#   '--',
#   '운행중',
#   '2022-03-08',
#   '한국승강기안전공단 서울서부지사',
#   '2022-03-08',
#   '2단지-외부2',
#   '2022-03-08',
#   '설치',
#   '보완후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920180023',
#   '현대엘리베이터(주)강서지사',
#   '02-6920-7805',
#   'N',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '1 M/MIN',
#   '2',
#   '-',
#   'B1-1',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-03-08',
#   '2023-03-07',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '1',
#   '1',
#   '0152584',
#   '07',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애/전망용',
#   '122',
#   '7251',
#   'WBSS(E)(M)',
#   '--',
#   '운행중',
#   '2022-03-08',
#   '한국승강기안전공단 서울서부지사',
#   '2022-03-08',
#   '1단지-외부1',
#   '2022-03-08',
#   '설치',
#   '보완후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920180023',
#   '현대엘리베이터(주)강서지사',
#   '02-6920-7805',
#   'N',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '2',
#   '-',
#   'B1-1',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-03-08',
#   '2023-03-07',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '1',
#   '1',
#   '0152586',
#   '021',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '7252',
#   'WBSS(E)(M)',
#   '--',
#   '운행중',
#   '2022-03-08',
#   '한국승강기안전공단 서울서부지사',
#   '2022-03-08',
#   '2단지-외부1',
#   '2022-03-08',
#   '설치',
#   '보완후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920180023',
#   '현대엘리베이터(주)강서지사',
#   '02-6920-7805',
#   'N',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '1 M/MIN',
#   '2',
#   '-',
#   '1-2',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-03-08',
#   '2023-03-07',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '1',
#   '2',
#   '0152612',
#   '035',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애/전망용',
#   '122',
#   '7253',
#   'WBSS(E)(M)',
#   '--',
#   '운행중',
#   '2022-03-08',
#   '한국승강기안전공단 서울서부지사',
#   '2022-03-08',
#   '썬큰',
#   '2022-03-08',
#   '설치',
#   '보완후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920180023',
#   '현대엘리베이터(주)강서지사',
#   '02-6920-7805',
#   'N',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1 M/MIN',
#   '3',
#   '-',
#   'B2-1',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '20',
#   '3',
#   '0150171',
#   '01',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7124',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-05-27',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-27',
#   '101-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '23',
#   '-',
#   'B3-20',
#   '122',
#   '03',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '20',
#   '3',
#   '0150172',
#   '02',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7125',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-05-27',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-27',
#   '101-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '23',
#   '-',
#   'B3-20',
#   '122',
#   '03',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '18',
#   '3',
#   '0150173',
#   '05',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7126',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-05-27',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-27',
#   '103-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '21',
#   '-',
#   'B3-18',
#   '122',
#   '03',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '18',
#   '3',
#   '0150174',
#   '06',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7127',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-05-27',
#   '한국승강기안전공단 서울서부지사',
#   '2021-05-27',
#   '103-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '21',
#   '-',
#   'B3-18',
#   '122',
#   '03',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '22',
#   '3',
#   '0150193',
#   '03',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7133',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-09',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-09',
#   '102-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '25',
#   '-',
#   'B3-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '22',
#   '3',
#   '0150194',
#   '04',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7134',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-09',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-09',
#   '102-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '25',
#   '-',
#   'B3-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '12',
#   '3',
#   '0150188',
#   '015',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7135',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-09',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-09',
#   '204-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '14',
#   '-',
#   'B3-12',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '12',
#   '3',
#   '0150189',
#   '016',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7136',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-09',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-09',
#   '204-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '14',
#   '-',
#   'B3-12',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '7',
#   '3',
#   '0150190',
#   '017',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7137',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-09',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-09',
#   '205-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '9',
#   '-',
#   'B3-7',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-20',
#   '2023-01-19',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '7',
#   '3',
#   '0150191',
#   '019',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7138',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-09',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-09',
#   '206-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '9',
#   '-',
#   'B3-7',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '9',
#   '3',
#   '0150235',
#   '018',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7139',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-29',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-29',
#   '205-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '11',
#   '-',
#   'B3-9',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-20',
#   '2023-01-19',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '12',
#   '3',
#   '0150236',
#   '020',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7140',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-29',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-29',
#   '206-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '14',
#   '-',
#   'B3-12',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '22',
#   '3',
#   '0150233',
#   '013',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7148',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-29',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-29',
#   '203-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '25',
#   '-',
#   'B3-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-19',
#   '2023-01-18',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '22',
#   '3',
#   '0150234',
#   '014',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7149',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-06-29',
#   '한국승강기안전공단 서울서부지사',
#   '2021-06-29',
#   '203-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '25',
#   '-',
#   'B3-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '20',
#   '3',
#   '0150414',
#   '09',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7179',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-10-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-10-13',
#   '201-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '23',
#   '-',
#   'B3-20',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '20',
#   '3',
#   '0150415',
#   '010',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7180',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-10-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-10-13',
#   '201-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '23',
#   '-',
#   'B3-20',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '22',
#   '3',
#   '0150416',
#   '011',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7181',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-10-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-10-13',
#   '202-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '25',
#   '-',
#   'B3-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-18',
#   '2023-01-17',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '22',
#   '3',
#   '0150417',
#   '012',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7182',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-10-13',
#   '한국승강기안전공단 서울서부지사',
#   '2021-10-13',
#   '202-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '1.75 M/MIN',
#   '25',
#   '-',
#   'B3-22',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-20',
#   '2023-01-19',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '30',
#   '2',
#   '0150418',
#   '23',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7183',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-10-14',
#   '한국승강기안전공단 서울서부지사',
#   '2021-10-14',
#   '301-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '32',
#   '-',
#   'B2-30',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-20',
#   '2023-01-19',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '30',
#   '2',
#   '0150419',
#   '24',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7184',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-10-14',
#   '한국승강기안전공단 서울서부지사',
#   '2021-10-14',
#   '301-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '32',
#   '-',
#   'B2-30',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-21',
#   '2023-01-20',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '29',
#   '2',
#   '0150420',
#   '25',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7185',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-10-14',
#   '한국승강기안전공단 서울서부지사',
#   '2021-10-14',
#   '301-3',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '31',
#   '-',
#   'B2-29',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-21',
#   '2023-01-20',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '30',
#   '2',
#   '0150491',
#   '26',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7186',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-11-04',
#   '한국승강기안전공단 서울서부지사',
#   '2021-11-04',
#   '302-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '32',
#   '-',
#   'B2-30',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-21',
#   '2023-01-20',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '30',
#   '2',
#   '0150492',
#   '27',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7187',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-11-04',
#   '한국승강기안전공단 서울서부지사',
#   '2021-11-04',
#   '302-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '32',
#   '-',
#   'B2-30',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-21',
#   '2023-01-20',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '30',
#   '2',
#   '0150493',
#   '28',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7188',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-11-04',
#   '한국승강기안전공단 서울서부지사',
#   '2021-11-04',
#   '302-3',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '32',
#   '-',
#   'B2-30',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-24',
#   '2023-01-23',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '27',
#   '2',
#   '0150486',
#   '29',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7189',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-11-04',
#   '한국승강기안전공단 서울서부지사',
#   '2021-11-04',
#   '303-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B2-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-26',
#   '2023-01-25',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '27',
#   '2',
#   '0150487',
#   '30',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7190',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-11-04',
#   '한국승강기안전공단 서울서부지사',
#   '2021-11-04',
#   '303-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B2-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-26',
#   '2023-01-25',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '27',
#   '2',
#   '0150488',
#   '31',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7191',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-11-04',
#   '한국승강기안전공단 서울서부지사',
#   '2021-11-04',
#   '303-3',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B2-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-26',
#   '2023-01-25',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '26',
#   '2',
#   '0150331',
#   '32',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7192',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-08-18',
#   '한국승강기안전공단 서울서부지사',
#   '2021-08-18',
#   '304-1',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1150 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '17 인승',
#   '2 M/MIN',
#   '28',
#   '-',
#   'B2-26',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-24',
#   '2023-01-23',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '27',
#   '2',
#   '0150332',
#   '33',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7193',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-08-24',
#   '한국승강기안전공단 서울서부지사',
#   '2021-08-24',
#   '304-2',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B2-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로 200',
#   '',
#   '2022-01-24',
#   '2023-01-23',
#   '01',
#   '122',
#   '3536',
#   'DMC 센트럴자이',
#   '공동주택-분양',
#   '27',
#   '2',
#   '0150333',
#   '34',
#   '엘리베이터',
#   '권상식-VVVF',
#   '소방구조/장애인용',
#   '122',
#   '7194',
#   'WBLX(E)(M)',
#   '--',
#   '운행중',
#   '2021-08-24',
#   '한국승강기안전공단 서울서부지사',
#   '2021-08-24',
#   '304-3',
#   '2022-03-08',
#   '수시',
#   '조건후합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920070053',
#   '현대엘리베이터(주)서울',
#   '1577-0603',
#   'Y',
#   '현성일',
#   '***',
#   '--',
#   '-',
#   '15 인승',
#   '2 M/MIN',
#   '29',
#   '-',
#   'B2-27',
#   '122',
#   '3',
#   '-',
#   '035',
#   '06'],
#  ['서울특별시 은평구 수색로22가길 5-1',
#   '(수색동, DMC 갤러리아 B)',
#   '2022-08-26',
#   '2023-08-25',
#   '01',
#   '122',
#   '3433',
#   'DMC갤러리아B동',
#   '공동주택-분양',
#   '5',
#   '0',
#   '0146088',
#   '1',
#   '엘리베이터',
#   '권상식-VVVF',
#   '장애인용',
#   '122',
#   '6918',
#   'WBSS-GY-2(M)',
#   '--',
#   '운행중',
#   '2020-08-26',
#   '한국승강기안전공단 서울서부지사',
#   '2020-08-26',
#   '1-1',
#   '2022-11-02',
#   '정기',
#   '합격',
#   '1000 KG',
#   '현대엘리베이터(주)',
#   '043-722-1000',
#   '919920035',
#   '920010079',
#   '정우엘리베이터(주)',
#   '02-306-9483',
#   'N',
#   '(주)위듀 부동산종합관리',
#   '02-356-8***',
#   '--',
#   '-',
#   '13 인승',
#   '1 M/MIN',
#   '5',
#   '-',
#   '1-5',
#   '122',
#   '03',
#   '-',
#   '034',
#   '87']]

# %%
data[0]
# Out:
# ['서울특별시 은평구 연서로 71',
#  '(역촌동)',
#  '2022-05-24',
#  '2023-05-23',
#  '01',
#  '122',
#  '236',
#  '(재)살림이',
#  '제2종근린생활시설-기타',
#  '5',
#  '1',
#  '0081201',
#  '1',
#  '엘리베이터',
#  '권상식-VVVF',
#  '승객용',
#  '122',
#  '440',
#  'SCN5NKZi(412,S)',
#  '--',
#  '운행중',
#  '1998-01-15',
#  '한국승강기안전공단 서울서부지사',
#  '1998-01-15',
#  '1-1',
#  '2022-05-24',
#  '수시',
#  '합격',
#  '550 KG',
#  '엘지산전(주) 창원공장',
#  '055-269-4114',
#  '919920032',
#  '919990047',
#  '(주)제일승강기',
#  '031-908-8681',
#  'Y',
#  '승강기 담당자',
#  '010-9884-1***',
#  '--',
#  '-',
#  '8 인승',
#  '1 M/MIN',
#  '6',
#  '선임(운행관리자정보없음)',
#  '-',
#  'B1-5',
#  '122',
#  '1',
#  '-',
#  '034',
#  '17']

# %%
df = pd.DataFrame(data, columns = col_names)

# %%
df
# Out:
#                  address1           address2   applcBeDt   applcEnDt areaNo  \
# 0        서울특별시 은평구 연서로 71              (역촌동)  2022-05-24  2023-05-23     01
# 1     서울특별시 은평구 통일로71길 16              (대조동)  2022-09-29  2023-09-28     01
# 2     서울특별시 은평구 통일로71길 16              (대조동)  2022-09-29  2023-09-28     01
# 3   서울특별시 은평구 은평로13길 12-1         해명빌딩 (녹번동)  2022-04-14  2022-10-13     01
# 4   서울특별시 은평구 은평로13길 12-1         해명빌딩 (녹번동)  2022-03-27  2022-09-26     01
# ..                    ...                ...         ...         ...    ...
# 95      서울특별시 은평구 수색로 200                     2022-01-26  2023-01-25     01
# 96      서울특별시 은평구 수색로 200                     2022-01-26  2023-01-25     01
# 97      서울특별시 은평구 수색로 200                     2022-01-24  2023-01-23     01
# 98      서울특별시 은평구 수색로 200                     2022-01-24  2023-01-23     01
# 99  서울특별시 은평구 수색로22가길 5-1  (수색동, DMC 갤러리아 B)  2022-08-26  2023-08-25     01
#
#    buldMgtNo1 buldMgtNo2         buldNm     buldPrpos divGroundFloorCnt  ...  \
# 0         122        236         (재)살림이  제2종근린생활시설-기타                 5  ...
# 1         122        889     (주)KT 은평지사       업무시설-기타                 4  ...
# 2         122        889     (주)KT 은평지사       업무시설-기타                 4  ...
# 3         122         43  (주)녹번해명(해명빌딩)  제2종근린생활시설-기타                 5  ...
# 4         122         43  (주)녹번해명(해명빌딩)  제2종근린생활시설-기타                 5  ...
# ..        ...        ...            ...           ...               ...  ...
# 95        122       3536      DMC 센트럴자이       공동주택-분양                27  ...
# 96        122       3536      DMC 센트럴자이       공동주택-분양                26  ...
# 97        122       3536      DMC 센트럴자이       공동주택-분양                27  ...
# 98        122       3536      DMC 센트럴자이       공동주택-분양                27  ...
# 99        122       3433      DMC갤러리아B동       공동주택-분양                 5  ...
#
#    ratedSpeed shuttleFloorCnt  shuttleMngrNm shuttleMngrTelno shuttleSection  \
# 0     1 M/MIN               6  선임(운행관리자정보없음)                -           B1-5
# 1   1.5 M/MIN               4  선임(운행관리자정보없음)                -            1-4
# 2   1.5 M/MIN               5  선임(운행관리자정보없음)                -           B1-4
# 3     1 M/MIN               6  선임(운행관리자정보없음)                -           B1-5
# 4   .33 M/MIN               2  선임(운행관리자정보없음)                -           B1-1
# ..        ...             ...            ...              ...            ...
# 95    2 M/MIN              29              -            B2-27            122
# 96    2 M/MIN              28              -            B2-26            122
# 97    2 M/MIN              29              -            B2-27            122
# 98    2 M/MIN              29              -            B2-27            122
# 99    1 M/MIN               5              -              1-5            122
#
#    sigunguCd standardKey subcntrCpny zipCd1 zipCd2
# 0        122           1           -    034     17
# 1        122           1           -    033     91
# 2        122           1           -    033     91
# 3        122           8           -    034     59
# 4        122           8           -    034     59
# ..       ...         ...         ...    ...    ...
# 95         3           -         035     06   None
# 96         3           -         035     06   None
# 97         3           -         035     06   None
# 98         3           -         035     06   None
# 99        03           -         034     87   None
#
# [100 rows x 51 columns]
